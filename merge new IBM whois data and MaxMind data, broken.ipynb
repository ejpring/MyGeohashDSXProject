# %% [markdown]
# ## merge Internet and IBM internal network geographical data
#
# -----
#
# The code in this notebook merges Internet and IBM network geographical data for use in IBM Streaming Analytics, such as the NetflowViewer demonstration and cyber-security applications:
#
# * Data for the Internet comes from CSV files provided by [MaxMind, Inc.](https://www.maxmind.com/en/home) as [GeoLite2 data](https://dev.maxmind.com/geoip/geoip2/geolite2/). This notebook downloads MaxMind's 'GeoLite2' data, which lists subnets and locations in the Internet, including country, state/province/territory, city, latitude, and longitude.
#
# * Data for the IBM internal network comes from a ['whois' service](http://whois.ibm.com) provided by AT&T. This notebook downloads 'whois' data that lists the subnets and locations in the IBM internal network, including country, state, city, and street address. This data is mapped to longitude and latitude with the Google Maps geocoding service.
#
# The Google Maps geocoding service requires an API key for a Google account. To create a key, do this:
#
# * In a browser, go to [Google](https://www.google.com/) and sign into an existing account or create a new account.
#
# * Go to the [Google Geocoding Service](https://developers.google.com/maps/documentation/javascript/geocoding) page and follow the instructions to create a project and enable the geocoding API.
#
# * Go to [Google Geocoding Service 'Get API Key'](https://developers.google.com/maps/documentation/geocoding/get-api-key), click on 'Get a Key', and then click the 'copy' button.
#
# * paste the copied key into the cell below as the value of the 'googlemapsKey' constant
#
# Google limits usage of their geocoding service to 2,500 requests per day, which is sufficient for two complete runs per day. The responses are cached and reused to avoid unnecessary use of Google's API.
#
# This notebook merges the IBM data into the MaxMind CSV files. It also generates a separate CSV file containing a [geohash code](https://en.wikipedia.org/wiki/Geohash) for each location's latitude/longitude. All of the resulting CSV files are packed into a ZIP file for transfer to Streaming Analytics projects:
#
# * [GeoLite2-City-Blocks-IPv4.csv](merged/GeoLite2-City-Blocks-IPv4.csv)
# * [GeoLite2-City-Blocks-IPv6.csv](merged/GeoLite2-City-Blocks-IPv6.csv)
# * [GeoLite2-City-Locations-en.csv](merged/GeoLite2-City-Locations-en.csv)
# * [GeoLite2-City-Geohashes-en.csv](merged/GeoLite2-City-Geohashes-en.csv)
#
# There are instructions for each step of this notebook in the cells below.

# %% [markdown]
# -----
# Run this cell once to install additional Python packages used in this notebook:

# %%
# !pip install --user googlemaps
# !pip install --user geohash2
# Out:
# Requirement already satisfied (use --upgrade to upgrade): googlemaps in /gpfs/global_fs01/sym_shared/YPProdSpark/user/sa73-1acf9232f65bd2-cf1c60ef4a00/.local/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): requests<3.0,>=2.11.1 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/sa73-1acf9232f65bd2-cf1c60ef4a00/.local/lib/python3.5/site-packages (from googlemaps)
# Requirement already satisfied (use --upgrade to upgrade): urllib3<1.23,>=1.21.1 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/sa73-1acf9232f65bd2-cf1c60ef4a00/.local/lib/python3.5/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# Requirement already satisfied (use --upgrade to upgrade): chardet<3.1.0,>=3.0.2 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/sa73-1acf9232f65bd2-cf1c60ef4a00/.local/lib/python3.5/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# Requirement already satisfied (use --upgrade to upgrade): certifi>=2017.4.17 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/sa73-1acf9232f65bd2-cf1c60ef4a00/.local/lib/python3.5/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# Requirement already satisfied (use --upgrade to upgrade): idna<2.7,>=2.5 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/sa73-1acf9232f65bd2-cf1c60ef4a00/.local/lib/python3.5/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# Requirement already satisfied (use --upgrade to upgrade): geohash2 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/sa73-1acf9232f65bd2-cf1c60ef4a00/.local/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): docutils>=0.3 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/sa73-1acf9232f65bd2-cf1c60ef4a00/.local/lib/python3.5/site-packages (from geohash2)

# %% [markdown]
# -----
# Run this cell each time the notebook is loaded to include Python packages, and define some constants and functions used in this notebook:

# %%
import os
import re
######import math
########import pprint
import requests
from requests_file import FileAdapter
import json
######import shutil
import zipfile
#######import types
import pandas as pd
import numpy as np
from io import BytesIO
from urllib.request import urlopen
#####import ibm_boto3
#######from ibm_botocore.client import Config
import googlemaps
import geohash2

# This constant points to the MaxMind 'GeoLite2' data.

maxmindGeoLite2URL = 'http://geolite.maxmind.com/download/geoip/database/GeoLite2-City-CSV.zip'

# This constant points to the IBM internal 'whois' service.

#whoisLocationURL = 'http://whois.ibm.com:8080/whois/search.json?inverse-attribute=org&type-filter=domain&query-string=ORG-IBM1-IGA'
ibmWhoisLocationURL = 'file:///Users/pring/git/MyGeohashDSXProject/whois.ibm.com_json_2018-03-23/ibm.domain.json'

# This constant contains a key for the Google Maps geocode API. 
# To create a key, follow the instructions at the top of this notebook.

googlemapsKey = 'AIzaSyAXrKyHrMa98L_e_CLtdi4UnQRPjHAEcYg'

# This constant contains the name of the file where responses from the Google Maps
# geocode service are cached for reuse.

googlemapsCacheFilename = 'googlemaps.cache.json'

pd.set_option('max_rows', 15)

# This function iterates through the 'whois.ibm.com' data retrieved from the specified URL, 
# returning a 'dictionary' containing one entry each time it is called, until the end of the 
# data is reached, when it returns None.

def getWhoisEntry(url):
    
    # create an HTTP session that can handle a 'file' URL and send the request
    session = requests.Session()
    session.mount('file://', FileAdapter())
    response = session.get(url, stream=True)

    # if the HTTP response does not specify and encoding, force 'UTF-8'
    if response.encoding is None: response.encoding = 'utf-8'
    
    # read the HTTP response one line at a time, looking for the entry delimiters,
    # and returning one entry, converted to a JSON object, each time the function is called,
    # until the end of the response is reached
    body = ''
    state = 'prefix'
    for line in response.iter_lines(decode_unicode=True):
        if not line: continue
        if line == '  "object" : [ {': # starting delimiter for first entry 
            state = 'body'
        elif line == '  }, {': # delimiter between entries
            if len(body)>0: yield json.loads( '{' + body + '}' )
            body = ''
        elif line == '  } ]': # ending delimiter for last entry 
            if len(body)>0:  yield json.loads( '{' + body + '}' )
            state = 'suffix'
            body = ''
        else:
            if state=='body': body += line + '\n'
            
    # return 'None' when the end of the response is reached
    return None

# This function uses the Google Maps geocode API to map an address
# to location data, including latitude and longitude. Google limits 
# use of the API, so its responses are cached in a local file and 
# reused to avoid unnecessary use.

def getGoogleMapsGeocode(client, address):
    
    ########return None

    # if this address has been found before, return cached data, otherwise ask Google Maps
    # and cache the data
    if address in googlemapsCache: 
        geocode = googlemapsCache[address]
    else:
        print('--------------> geocode(' + address + ')')
        geocode = client.geocode(address)
        googlemapsCache[address] = geocode
        storeObjectToFile(googlemapsCacheFilename, googlemapsCache)
    
    # extract address components from geocode data into simple dictionary
    if geocode and len(geocode)>0 and 'address_components' in geocode[0]: 
        result = { component['types'][0]: component['long_name'] for component in geocode[0]['address_components'] }
        result['latitude'] = geocode[0]['geometry']['location']['lat']
        result['longitude'] = geocode[0]['geometry']['location']['lng']
    else:
        result = None
        
    # return simple dictionary of address and location components
    return result

# This function loads a Python object from a JSON file. It used above
# to cache responses from the Google Maps geocode API.

def loadObjectFromFile(filename):
    if os.path.exists(filename):
        with open(filename, 'r') as file: return json.load(file)
    else:
        return {}

# This function stores a Python object in a JSON file. It used above
# to cache responses from the Google Maps geocode API.

def storeObjectToFile(filename, cache):
    if os.path.exists(filename+'.new'): os.remove(filename+'.new')
    with open(filename+'.new', 'w') as file: json.dump(cache, file)
    if os.path.exists(filename+'.old'): os.remove(filename+'.old')
    if os.path.exists(filename): os.rename(filename, filename+'.old')
    os.rename(filename+'.new', filename)
    
# This function replaces any mis-encoded Unicode characters of the form "\xXX"
# in the specified "UTF-8" string with the corresponding Unicode character, 
# properly encoded for "UTF-8"
    
def fixUnicodeCharacters(xxx):
    yyy = re.sub(r'\\x(..)', lambda match: chr(int(match.group(1),16)), xxx)
    #############if xxx!=yyy: print(xxx,'-->',yyy)
    return yyy

# %%
ibmNetworksIPv4 = []
ibmNetworksIPv6 = []
ibmLocations = []

print('running ...')

googlemapsClient = googlemaps.Client(key=googlemapsKey)

googlemapsCache = loadObjectFromFile(googlemapsCacheFilename)

for whoisEntry in getWhoisEntry(ibmWhoisLocationURL):

    # collect MaxMind location fields in this dictionary
    location = {}

    # skip 'whois' entries that are not IBM locations
    if whoisEntry['type']!='domain': continue
    primaryKey = whoisEntry['primary-key']['attribute'][0]['value']
    if not re.fullmatch(r'[A-Z0-9]{3}', primaryKey): continue
    print(primaryKey)
    
    # extract fields of interest from 'whois' entries into a simple dictionary
    whois = {}
    for whoisAttribute in whoisEntry['attributes']['attribute']:  
        if whoisAttribute['name']=='remarks':
            match = re.fullmatch(r'RESO_(\w+)\.... = (.*)', whoisAttribute['value'])
            if match: whois[match.group(1)] = fixUnicodeCharacters(match.group(2))
            match = re.fullmatch(r'Prefix_List\.(\w+)\.... = (.*)', whoisAttribute['value'])
            if match and not match.group(2).endswith('NO_PREFIXES_FOUND'): whois[match.group(1)] = match.group(2).split(', ')
       
    # skip 'whois' entries that are not actual IBM locations
    if 'Country' not in whois: continue
    ########print(whois)  
    
    # MaxMind location column headers:
    # geoname_id,locale_code,continent_code,continent_name,country_iso_code,country_name,subdivision_1_iso_code,subdivision_1_name,subdivision_2_iso_code,subdivision_2_name,city_name,metro_code,time_zone,is_in_european_union
    
    # copy 'whois' fields that correspond to MaxMind location fields
    location['geoname_id'] = primaryKey
    location['country_iso_code'] = whois['Country']
    if 'State' in whois: location['subdivision_1_iso_code'] = whois['State']
    if 'City' in whois: location['city_name'] = whois['City']

    # construct string representation of location address from 'whois' fields
    address = whois['Country']
    if 'State' in whois: address = whois['State'] + ', ' + address        
    if 'City' in whois and whois['City']!='NO CITY': address = whois['City'] + ', ' + address
    if  'Address1' in whois and not whois['Address1'].startswith('NO IBM LOCATION'):
        if 'Address2' in whois: address = whois['Address2'] + ', ' + address
        if 'Address1' in whois: address = whois['Address1'] + ', ' + address
        if 'PostalCode' in whois: address = address  + ', ' + whois['PostalCode']
        address = 'IBM, ' + address
    print(address)
        
    # get geocode data for location from Google Maps    
    geocode = getGoogleMapsGeocode(googlemapsClient, address)
    if geocode:
        #########print(geocode)
        if 'country' in geocode: location['country_name'] = geocode['country']
        if 'administrative_area_level_1' in geocode: location['subdivision_1_name'] = geocode['administrative_area_level_1']
        #####if 'latitude' in geocode: location['latitude'] = geocode['latitude']
        ##########if 'longitude' in geocode: location['longitude'] = geocode['longitude']
    
    # MaxMind network column headers:
    # network,geoname_id,registered_country_geoname_id,represented_country_geoname_id,is_anonymous_proxy,is_satellite_provider,postal_code,latitude,longitude,accuracy_radius

    # add each IPv4 and IPv6 subnet at this location to their respective lists
    if 'IPv4' in whois:
        for cidr in whois['IPv4']:
            if not cidr.startswith('9.'): continue
            network = { 'network': cidr, 'geoname_id': primaryKey }
            if 'PostalCode' in whois: network['postal_code'] = whois['PostalCode']
            if geocode and 'latitude' in geocode: network['latitude'] = geocode['latitude']
            if geocode and 'longitude' in geocode: network['longitude'] = geocode['longitude']
            ibmNetworksIPv4.append(network)
    if 'IPv6' in whois:
        for cidr in whois['IPv6']:
            if not cidr.startswith('2620:1F7:'): continue
            network = { 'network': cidr, 'geoname_id': primaryKey }
            if 'PostalCode' in whois: network['postal_code'] = whois['PostalCode']
            if geocode and 'latitude' in geocode: network['latitude'] = geocode['latitude']
            if geocode and 'longitude' in geocode: network['longitude'] = geocode['longitude']
            ibmNetworksIPv6.append(network)
            
    # add this location to the list
    ibmLocations.append(location)
        
print('... done')
# Out:
# running ...
# 009
# IBM, RUA DO PROLETARIADO 14/1, ALFRAGIDE, 11, PT, 2795
# 00A
# IBM, AVDA DE LA PALMERA 19, SEVILLA, SE, ES, 41013
# 00H
# IBM, PLAZA CRONOS 1, MADRID, M, ES, 28037
# 00J
# IBM, C/ SAKURA, 8, SAN FRUITÒS DEL BALGÈS, B, ES, 08202
# 00O
# IBM, CALLE YECORA 4, MADRID, M, ES, 28022
# 00T
# IBM, PARCELA PC10601 - PARC DE L'ALBA, CERDANYOLA DEL VALLÉS, BARCELONA, B, ES, 08290
# 00U
# IBM, GRAN VÍA ASIMA 20, OFICINA 35. POLÍGONO SON CASTEL, PALMA DE MALLORCA, PM, ES, 07009
# 00W
# IBM, PLAZA EUSKADI 5, BILBAO, PV, ES, 48009
# 01D
# IBM, AVDA DIAGONAL 571, BARCELONA, B, ES, 08029
# 01E
# IBM, AVDA DE ALGORTA NO 16, GETXO-VIZCAYA, BI, ES, 48990
# 01G
# IBM, AV BRUSELAS, 20, ALCOBENDAS, M, ES, 28108
# 01H
# IBM, TALES DE MILETO 1, ALCALA DE HENARES, M, ES, 28806
# 01I
# IBM, CALLE MARÍA TUBAU 3, MADRID, M, ES, 28050
# 01J
# IBM, CALLE MASQUEFA 58, BAJO DERECHA, VALENCIA, V, ES, 46020
# 01K
# IBM, POLÍGONO DE POCOMACO, SECTOR I-1, N, LA CORUÑA, C, ES, 15190
# 01L
# IBM, POLÍGONO INDUSTRIAL SANTA CLARA, CALLE B, LOCAL 4, AV/ SANTA CLARA DE CUBA, SEVILLA, SE, ES, 15190
# 01M
# IBM, CARRER DE LA MORA 33, VIAL D, NAVE, BADALONA, B, ES, 08918
# 046
# IBM, AVDA ARAGON 30, VALENCIA, V, ES, 46021
# 061
# IBM, 1301 E EUCLID AVE, SUITE C, DES MOINES, IA, US, 50316-1258
# 068
# IBM, J. HUIZINGALAAN 765, AMSTERDAM, NL, 1066 VH
# 083
# IBM, 225 WESTERN AVE, AUGUSTA, ME, US, 04330-6159
# 0AM
# IBM, STA. HORTENSIA 26-28, MADRID, M, ES, 28002
# 0AW
# IBM, 1803 DOUGLAS ST, VICTORIA, BC, CA, V8T 5C3
# 0BE
# IBM, 4611 CANADA WAY, BURNABY, BC, CA, V5G 4X3
# --------------> geocode(IBM, 4611 CANADA WAY, BURNABY, BC, CA, V5G 4X3)
# 0BH
# IBM, 4000 SEYMOUR PL, SAANICH, BC, CA, V8X 4S8
# --------------> geocode(IBM, 4000 SEYMOUR PL, SAANICH, BC, CA, V8X 4S8)
# 0BR
# IBM, 3-1-36 NORITAKESHINMACHI, NISHI-KU, NAGOYA, JP, 451-0051
# --------------> geocode(IBM, 3-1-36 NORITAKESHINMACHI, NISHI-KU, NAGOYA, JP, 451-0051)
# 0BY
# IBM, 3-25-9 MEIEKI, NAKAMURA-KU, NAGOYA, JP, 450-0002
# --------------> geocode(IBM, 3-25-9 MEIEKI, NAKAMURA-KU, NAGOYA, JP, 450-0002)
# 0BZ
# IBM, 1 KOKANCHO, FUKUYAMA, JP, 720-0931
# --------------> geocode(IBM, 1 KOKANCHO, FUKUYAMA, JP, 720-0931)
# 0CA
# IBM, RDA PONIENTE 18, TRES CANTOS, TRES CANTOS, M, ES, 28760
# --------------> geocode(IBM, RDA PONIENTE 18, TRES CANTOS, TRES CANTOS, M, ES, 28760)
# 0CB
# IBM, 3-5-24 MIYAHARA, YODOGAWA-KU,, OSAKA, JP, 532-0003
# --------------> geocode(IBM, 3-5-24 MIYAHARA, YODOGAWA-KU,, OSAKA, JP, 532-0003)
# 0CG
# IBM, 1-1 MINAMIWATARIDACHO, KAWASAKI-KU, KAWASAKI, JP, 210-0855
# --------------> geocode(IBM, 1-1 MINAMIWATARIDACHO, KAWASAKI-KU, KAWASAKI, JP, 210-0855)
# 0CT
# IBM, MAR ADRIATICO 2, SAN FERNANDO DE HENARES, M, ES, 28830
# --------------> geocode(IBM, MAR ADRIATICO 2, SAN FERNANDO DE HENARES, M, ES, 28830)
# 0CU
# IBM, 1 UZUMASA TATSUMICHO, UKYO-KU, KYOTO, JP, 616-8114
# --------------> geocode(IBM, 1 UZUMASA TATSUMICHO, UKYO-KU, KYOTO, JP, 616-8114)
# 0CV
# IBM, 1-1 MIZUSHIMA KAIGANDORI, KURASHIKI, JP, 712-8071
# --------------> geocode(IBM, 1-1 MIZUSHIMA KAIGANDORI, KURASHIKI, JP, 712-8071)
# 0CX
# IBM, 1 HASHIME CHOAZA NAKASHINKIRI, OKAZAKI, JP, 444-0908
# --------------> geocode(IBM, 1 HASHIME CHOAZA NAKASHINKIRI, OKAZAKI, JP, 444-0908)
# 0DB
# IBM, 4-2-7 IWAYANAKAMACHI, NADA-KU, KOBE, JP, 657-0845
# --------------> geocode(IBM, 4-2-7 IWAYANAKAMACHI, NADA-KU, KOBE, JP, 657-0845)
# 0DD
# IBM, 5-9-12 KITASHINAGAWA, SHINAGAWA-KU, TOKYO, JP, 141-0001
# --------------> geocode(IBM, 5-9-12 KITASHINAGAWA, SHINAGAWA-KU, TOKYO, JP, 141-0001)
# 0DE
# IBM, 1-5-5 TAKATSUKADAI, NISHI-KU, KOBE, JP, 651-2271
# --------------> geocode(IBM, 1-5-5 TAKATSUKADAI, NISHI-KU, KOBE, JP, 651-2271)
# 0DF
# IBM, 1 KANAZAWACHO, KAKOGAWA, JP, 675-0137
# --------------> geocode(IBM, 1 KANAZAWACHO, KAKOGAWA, JP, 675-0137)
# 0DG
# IBM, 2 NADAHAMAHIGASHICHO, NADA-KU, KOBE, JP, 657-0863
# --------------> geocode(IBM, 2 NADAHAMAHIGASHICHO, NADA-KU, KOBE, JP, 657-0863)
# 0DH
# IBM, 2-3-1 SHINHAMA, ARAICHO, TAKASAGO, JP, 676-0008
# --------------> geocode(IBM, 2-3-1 SHINHAMA, ARAICHO, TAKASAGO, JP, 676-0008)
# 0DI
# IBM, 740 YAGI, OKUBO CHO, AKASHI, JP, 674-0063
# --------------> geocode(IBM, 740 YAGI, OKUBO CHO, AKASHI, JP, 674-0063)
# 0DK
# IBM, 2-19 HIGASHIUNOBECHO, IBARAKI, JP, 545-0000
# --------------> geocode(IBM, 2-19 HIGASHIUNOBECHO, IBARAKI, JP, 545-0000)
# 0DL
# IBM, 15 KINUGAOKA, MOKA, JP, 321-4367
# --------------> geocode(IBM, 15 KINUGAOKA, MOKA, JP, 321-4367)
# 0DM
# IBM, 14-1 CHOFUMINATOMACHI, SHIMONOSEKI, JP, 752-0953
# --------------> geocode(IBM, 14-1 CHOFUMINATOMACHI, SHIMONOSEKI, JP, 752-0953)
# 0EA
# IBM, STOCKHOLMER ALLEE 30 A, DORTMUND, DE, 44269
# --------------> geocode(IBM, STOCKHOLMER ALLEE 30 A, DORTMUND, DE, 44269)
# 0EJ
# IBM, CONCEJAL GARCIA FEO Nº 12, LAS PALMAS, GC, ES, 35011
# --------------> geocode(IBM, CONCEJAL GARCIA FEO Nº 12, LAS PALMAS, GC, ES, 35011)
# 0EL
# IBM, 5-33-8 SHIBA MINATO-KU, TOKYO, JP, 108-0014
# --------------> geocode(IBM, 5-33-8 SHIBA MINATO-KU, TOKYO, JP, 108-0014)
# 0EN
# IBM, 4-15-1 SHIBAURA,, MINATO-KU, TOKYO, JP, 108-0023
# --------------> geocode(IBM, 4-15-1 SHIBAURA,, MINATO-KU, TOKYO, JP, 108-0023)
# 0EO
# IBM, PLOT NO. 44-A P.E.C.H.S. BLOCK 6 S, 5-6 FLOOR, NICE TRADE ORBIT BUILDING, KARACHI, PK, 74200
# --------------> geocode(IBM, PLOT NO. 44-A P.E.C.H.S. BLOCK 6 S, 5-6 FLOOR, NICE TRADE ORBIT BUILDING, KARACHI, PK, 74200)
# 0EP
# IBM, 7 CHANGI BUSINESS PARK CENTRAL 1, SINGAPORE, SG, 486072
# --------------> geocode(IBM, 7 CHANGI BUSINESS PARK CENTRAL 1, SINGAPORE, SG, 486072)
# 0FB
# IBM, PYRAMIDS HEIGHTS OFFICE PARK - C09, ALEXANDRIA DESERT ROAD, KM 22 - PO BOX 166 EL-AHRAM GIZA, CAIRO, EG, 9999
# --------------> geocode(IBM, PYRAMIDS HEIGHTS OFFICE PARK - C09, ALEXANDRIA DESERT ROAD, KM 22 - PO BOX 166 EL-AHRAM GIZA, CAIRO, EG, 9999)
# 0FS
# IBM, MARUTHI IND ESTATE - SHED NO 1,2&3, HOODY VILLAGE, WHITE FIELD RD, BANGALORE, KA, IN, 560066
# --------------> geocode(IBM, MARUTHI IND ESTATE - SHED NO 1,2&3, HOODY VILLAGE, WHITE FIELD RD, BANGALORE, KA, IN, 560066)
# 0GM
# IBM, METROPOLITIAN TOWER, 68 ZOURONG LU, UNIT 10 & 11 OF 30/F, CHONGQING, 50, CN, 400010
# --------------> geocode(IBM, METROPOLITIAN TOWER, 68 ZOURONG LU, UNIT 10 & 11 OF 30/F, CHONGQING, 50, CN, 400010)
# 0HF
# IBM, HAIFA UNIVERSITY, MOUNT CARMEL, HAIFA, HA, IL, 31905
# --------------> geocode(IBM, HAIFA UNIVERSITY, MOUNT CARMEL, HAIFA, HA, IL, 31905)
# 0HS
# IBM, 2, SQUARE RENE CASSIN, RENNES, FR, 35700
# --------------> geocode(IBM, 2, SQUARE RENE CASSIN, RENNES, FR, 35700)
# 0IB
# IBM, SHEIKH ZAYED ROAD, DUBAI INTERNET CITY, BUILDING 5, DUBAI, AE, 27242
# --------------> geocode(IBM, SHEIKH ZAYED ROAD, DUBAI INTERNET CITY, BUILDING 5, DUBAI, AE, 27242)
# 0IO
# IBM, SUBRAMANYA ARCADE, GRD-3RD FLRS, NO 12 BANNERGHATTA MAIN ROAD, BANGALORE, KA, IN, 560029
# --------------> geocode(IBM, SUBRAMANYA ARCADE, GRD-3RD FLRS, NO 12 BANNERGHATTA MAIN ROAD, BANGALORE, KA, IN, 560029)
# 0IP
# IBM, 281 T T K ROAD, 2ND-4TH FLRS, CHENNAI, TN, IN, 600018
# --------------> geocode(IBM, 281 T T K ROAD, 2ND-4TH FLRS, CHENNAI, TN, IN, 600018)
# 0IR
# IBM, 16 CAMAC STREET, L&T CHAMBERS, 2ND FLR, KOLKATA, WB, IN, 700017
# --------------> geocode(IBM, 16 CAMAC STREET, L&T CHAMBERS, 2ND FLR, KOLKATA, WB, IN, 700017)
# 0IV
# IBM, THE IL&FS FINANCIAL CENTER, 4TH FLR, BANDRA KURLA COMPLEX, BANDRA (E), MUMBAI, MH, IN, 400051
# --------------> geocode(IBM, THE IL&FS FINANCIAL CENTER, 4TH FLR, BANDRA KURLA COMPLEX, BANDRA (E), MUMBAI, MH, IN, 400051)
# 0JB
# IBM, C/ CANTON PEQUENO NO 13, LA CORUÑA, C, ES, 15003
# --------------> geocode(IBM, C/ CANTON PEQUENO NO 13, LA CORUÑA, C, ES, 15003)
# 0JS
# IBM, PIAZZA BORGO PILA 38, CORTE LAMBRUSCHINI, GENOVA, GE, IT, 16129
# --------------> geocode(IBM, PIAZZA BORGO PILA 38, CORTE LAMBRUSCHINI, GENOVA, GE, IT, 16129)
# 125
# IBM, 2-2 KITA 5 NISHI 6, CHUO-KU, SAPPORO, JP, 060-0005
# --------------> geocode(IBM, 2-2 KITA 5 NISHI 6, CHUO-KU, SAPPORO, JP, 060-0005)
# 1AO
# IBM, 227 - 11TH AVENUE SW, CALGARY, AB, CA, T2R 1R9
# --------------> geocode(IBM, 227 - 11TH AVENUE SW, CALGARY, AB, CA, T2R 1R9)
# 1AU
# IBM, 10044-108 ST NW, SUITE, EDMONTON, AB, CA, T5J 3S7
# --------------> geocode(IBM, 10044-108 ST NW, SUITE, EDMONTON, AB, CA, T5J 3S7)
# 1MA
# IBM, 2-1-10 SHIMONOPPORO TEKUNO PARK, AT, SAPPORO, JP, 004-0015
# --------------> geocode(IBM, 2-1-10 SHIMONOPPORO TEKUNO PARK, AT, SAPPORO, JP, 004-0015)
# 238
# IBM, 1-4-32 NAKATOURI, AKITA, JP, 010-0001
# --------------> geocode(IBM, 1-4-32 NAKATOURI, AKITA, JP, 010-0001)
# 2AC
# IBM, ONE RESEARCH DR, REGINA, SK, CA, S4S 7H1
# --------------> geocode(IBM, ONE RESEARCH DR, REGINA, SK, CA, S4S 7H1)
# 2AD
# IBM, 1801 HAMILTON ST, REGINA, SK, CA, S4P 4B4
# --------------> geocode(IBM, 1801 HAMILTON ST, REGINA, SK, CA, S4P 4B4)
# 2M8
# IBM, 2-13-5 HASHIMOTO, AOMORI, JP, 030-0823
# --------------> geocode(IBM, 2-13-5 HASHIMOTO, AOMORI, JP, 030-0823)
# 2P1
# IBM, 15-20 MORIOKAEKIMAEDORI, MORIOKA, JP, 020-0034
# --------------> geocode(IBM, 15-20 MORIOKAEKIMAEDORI, MORIOKA, JP, 020-0034)
# 341
# IBM, 1-7-15 SOGAWA, TOYAMA, JP, 930-0083
# --------------> geocode(IBM, 1-7-15 SOGAWA, TOYAMA, JP, 930-0083)
# 343
# IBM, 2-1-18 HIGASHIODORI, CHUO-KU, NIIGATA, JP, 950-0087
# --------------> geocode(IBM, 2-1-18 HIGASHIODORI, CHUO-KU, NIIGATA, JP, 950-0087)
# 344
# IBM, 3-1-1 HIROOKA, KANAZAWA, JP, 920-0031
# --------------> geocode(IBM, 3-1-1 HIROOKA, KANAZAWA, JP, 920-0031)
# 345
# IBM, 2-7-15 OHTE, FUKUI, JP, 910-0005
# --------------> geocode(IBM, 2-7-15 OHTE, FUKUI, JP, 910-0005)
# 3AE
# IBM, 400 ELLICE AVE, WINNIPEG, MB, CA, R3B 3M3
# --------------> geocode(IBM, 400 ELLICE AVE, WINNIPEG, MB, CA, R3B 3M3)
# 408
# IBM, 1-12-1 DOUGENZAKA SHIBUYA-KU, 18FLR SHIBUYA MARK CITY BLDG, TOKYO, JP, 150-0043
# --------------> geocode(IBM, 1-12-1 DOUGENZAKA SHIBUYA-KU, 18FLR SHIBUYA MARK CITY BLDG, TOKYO, JP, 150-0043)
# 423
# IBM, 1-4-73 SANNOMARU, MITO, JP, 310-0011
# --------------> geocode(IBM, 1-4-73 SANNOMARU, MITO, JP, 310-0011)
# 427
# IBM, 4-7-11 ONOHARA, KAMISU, JP, 314-0144
# --------------> geocode(IBM, 4-7-11 ONOHARA, KAMISU, JP, 314-0144)
# 4AI
# IBM, 690 DALTON ST., KINGSTON, ON, CA, K7M 8N8
# --------------> geocode(IBM, 690 DALTON ST., KINGSTON, ON, CA, K7M 8N8)
# 4AM
# IBM, 3500 STEELES AVE EAST, MARKHAM, ON, CA, L3R 0X1
# --------------> geocode(IBM, 3500 STEELES AVE EAST, MARKHAM, ON, CA, L3R 0X1)
# 4AN
# IBM, 3600 STEELES AVE EAST, MARKHAM, ON, CA, L3R 9Z7
# --------------> geocode(IBM, 3600 STEELES AVE EAST, MARKHAM, ON, CA, L3R 9Z7)
# 4AO
# IBM, 4175 14TH AVENUE, MARKHAM, ON, CA, L3R 5R5
# --------------> geocode(IBM, 4175 14TH AVENUE, MARKHAM, ON, CA, L3R 5R5)
# 4BY
# IBM, 100 WYNFORD DR., 2ND FLOOR, TORONTO, ON, CA, M3C 1K4
# --------------> geocode(IBM, 100 WYNFORD DR., 2ND FLOOR, TORONTO, ON, CA, M3C 1K4)
# 4CG
# IBM, 151 FRONT STREET, SUITE 200, TORONTO, ON, CA, M5J 2N1
# --------------> geocode(IBM, 151 FRONT STREET, SUITE 200, TORONTO, ON, CA, M5J 2N1)
# 4CH
# IBM, 245 CONSUMERS RD, NORTH YORK, ON, CA, M2J 1R3
# --------------> geocode(IBM, 245 CONSUMERS RD, NORTH YORK, ON, CA, M2J 1R3)
# 4CQ
# IBM, 79 WELLINGTON ST. W., TORONTO, ON, CA, M5K 1B1
# --------------> geocode(IBM, 79 WELLINGTON ST. W., TORONTO, ON, CA, M5K 1B1)
# 4EK
# IBM, 120 BLOOR ST E, GROUND FLOOR, TORONTO, ON, CA, M4W 1B7
# --------------> geocode(IBM, 120 BLOOR ST E, GROUND FLOOR, TORONTO, ON, CA, M4W 1B7)
# 4EM
# IBM, 8200 WARDEN AVE, TORONTO LAB, MARKHAM, ON, CA, L6G 1C7
# --------------> geocode(IBM, 8200 WARDEN AVE, TORONTO LAB, MARKHAM, ON, CA, L6G 1C7)
# 4EO
# IBM, 100 GOUGH ROAD, MARKHAM, ON, CA, L3R 4B7
# --------------> geocode(IBM, 100 GOUGH ROAD, MARKHAM, ON, CA, L3R 4B7)
# 4K2
# IBM, 733 UEMATSUCHO, SHIMOGYO-KU, KYOTO, JP, 600-8028
# --------------> geocode(IBM, 733 UEMATSUCHO, SHIMOGYO-KU, KYOTO, JP, 600-8028)
# 4MM
# IBM, 2-6-1 NAKASE,, MIHAMA-KU, CHIBA, JP, 261-7110
# --------------> geocode(IBM, 2-6-1 NAKASE,, MIHAMA-KU, CHIBA, JP, 261-7110)
# 4N2
# IBM, 4-1-18 ODORI, UTSUNOMIYA, JP, 320-0811
# --------------> geocode(IBM, 4-1-18 ODORI, UTSUNOMIYA, JP, 320-0811)
# 4N5
# IBM, 1-11-3 SAKURAGICHO OHMIYA-KU, SAITAMA, JP, 330-0854
# --------------> geocode(IBM, 1-11-3 SAKURAGICHO OHMIYA-KU, SAITAMA, JP, 330-0854)
# 4S6
# IBM, 19-21 NIHONBASHI-HAKOZAKICHO, CHUO-KU, TOKYO, JP, 103-8510
# --------------> geocode(IBM, 19-21 NIHONBASHI-HAKOZAKICHO, CHUO-KU, TOKYO, JP, 103-8510)
# 4S8
# IBM, 1-1 NAKASE, MIHAMAKU, CHIBA, JP, 261-8522
# --------------> geocode(IBM, 1-1 NAKASE, MIHAMAKU, CHIBA, JP, 261-8522)
# 4T3
# IBM, 1-24-13 ASAHICHO, ATSUGI, JP, 243-0014
# --------------> geocode(IBM, 1-24-13 ASAHICHO, ATSUGI, JP, 243-0014)
# 4T8
# IBM, 1-204 TSUKUBA, KUMAGAYA, JP, 360-0037
# --------------> geocode(IBM, 1-204 TSUKUBA, KUMAGAYA, JP, 360-0037)
# 4T9
# IBM, 58-1 YASHIMACHO, TAKASAKI, JP, 370-0849
# --------------> geocode(IBM, 58-1 YASHIMACHO, TAKASAKI, JP, 370-0849)
# 4W2
# IBM, 1-6-1 TAKEZONO, TSUKUBA, JP, 305-0032
# --------------> geocode(IBM, 1-6-1 TAKEZONO, TSUKUBA, JP, 305-0032)
# 4WR
# IBM, 1-1 NIKKOCHO, TOKYO, JP, 183-0044
# --------------> geocode(IBM, 1-1 NIKKOCHO, TOKYO, JP, 183-0044)
# 4WS
# IBM, 1-15-2 OCHIAI, TAMA, JP, 206-0033
# --------------> geocode(IBM, 1-15-2 OCHIAI, TAMA, JP, 206-0033)
# 4Z5
# IBM, 14-23 WAKITAHONCHO, KAWAGOE, JP, 350-1123
# --------------> geocode(IBM, 14-23 WAKITAHONCHO, KAWAGOE, JP, 350-1123)
# 502
# IBM, 3001 HENDERSON DR, SUITE J, CHEYENNE, WY, US, 82001-5840
# --------------> geocode(IBM, 3001 HENDERSON DR, SUITE J, CHEYENNE, WY, US, 82001-5840)
# 530
# IBM, 1524-80 HIEKAWA, IZU, JP, 410-2507
# --------------> geocode(IBM, 1524-80 HIEKAWA, IZU, JP, 410-2507)
# 535
# IBM, 319-28 KAJIMACHI, NAKA-KU, HAMAMATSU, JP, 430-0933
# --------------> geocode(IBM, 319-28 KAJIMACHI, NAKA-KU, HAMAMATSU, JP, 430-0933)
# 539
# IBM, 3-1-1 NISHIKI NAKA-KU, NAGOYA, JP, 460-0003
# --------------> geocode(IBM, 3-1-1 NISHIKI NAKA-KU, NAGOYA, JP, 460-0003)
# 542
# IBM, 2-13-1 TOKIWACHO AOI-KU, SHIZUOKA, JP, 420-0034
# --------------> geocode(IBM, 2-13-1 TOKIWACHO AOI-KU, SHIZUOKA, JP, 420-0034)
# 575
# IBM, 4 ALLIANCE BOULEVARD, BARRIE, ON, CA, L4M 5J1
# --------------> geocode(IBM, 4 ALLIANCE BOULEVARD, BARRIE, ON, CA, L4M 5J1)
# 5AA
# IBM, 23 BOULEVARD DE L'AEROPORT, BROMONT, QC, CA, J2L 1A3
# --------------> geocode(IBM, 23 BOULEVARD DE L'AEROPORT, BROMONT, QC, CA, J2L 1A3)
# 5AB
# IBM, 200 BOUL BOUCHARD, ROOM 650A, DORVAL, QC, CA, H9S 1A8
# --------------> geocode(IBM, 200 BOUL BOUCHARD, ROOM 650A, DORVAL, QC, CA, H9S 1A8)
# 5AF
# IBM, 275 RUE VIGER EST, MONTREAL, QC, CA, H2X 3R7
# --------------> geocode(IBM, 275 RUE VIGER EST, MONTREAL, QC, CA, H2X 3R7)
# 5AI
# IBM, 2700 LAURIER BLVD., TOUR CHAMPLAIN, SAINTE-FOY, QC, CA, G1V 4J9
# --------------> geocode(IBM, 2700 LAURIER BLVD., TOUR CHAMPLAIN, SAINTE-FOY, QC, CA, G1V 4J9)
# 5AP
# IBM, 140 GRANDE ALLEE EAST, QUEBEC CITY, QC, CA, G1R 5N6
# --------------> geocode(IBM, 140 GRANDE ALLEE EAST, QUEBEC CITY, QC, CA, G1R 5N6)
# 5N4
# IBM, 1-2658-2 JONAN, SUWA, JP, 392-0017
# --------------> geocode(IBM, 1-2658-2 JONAN, SUWA, JP, 392-0017)
# 5P8
# IBM, 1-1 SUWASAKAEMACHI, YOKKAICHI, JP, 510-0086
# --------------> geocode(IBM, 1-1 SUWASAKAEMACHI, YOKKAICHI, JP, 510-0086)
# 5U0
# IBM, 2-5-2 FUKASHI, MATSUMOTO, JP, 390-0815
# --------------> geocode(IBM, 2-5-2 FUKASHI, MATSUMOTO, JP, 390-0815)
# 5U5
# IBM, 1-179 MIYUKIHONMACHI, TOYOTA, JP, 473-0901
# --------------> geocode(IBM, 1-179 MIYUKIHONMACHI, TOYOTA, JP, 473-0901)
# 5V1
# IBM, 1-1 SHIBAHONCHO, MISHIMA, JP, 411-0857
# --------------> geocode(IBM, 1-1 SHIBAHONCHO, MISHIMA, JP, 411-0857)
# 5V4
# IBM, 2-8 HASHIMOTOCHO, GIFU, JP, 500-8856
# --------------> geocode(IBM, 2-8 HASHIMOTOCHO, GIFU, JP, 500-8856)
# 612
# IBM, SECOND TERRACE & COLLINS AVENUE, NASSAU, BS
# --------------> geocode(IBM, SECOND TERRACE & COLLINS AVENUE, NASSAU, BS)
# 613
# IBM, COLLYMORE ROCK, ST MICHAEL, BB
# --------------> geocode(IBM, COLLYMORE ROCK, ST MICHAEL, BB)
# 614
# IBM, ANASASTRAAT 8, ORANJESTAD, AW
# --------------> geocode(IBM, ANASASTRAAT 8, ORANJESTAD, AW)
# 616
# IBM, 52-56 KNUTSFORD BLVD, KINGSTON, JM
# --------------> geocode(IBM, 52-56 KNUTSFORD BLVD, KINGSTON, JM)
# 617
# IBM, VAN'T HOGERHUYSSTRAAT 9-11, PARAMARIBO, SR
# --------------> geocode(IBM, VAN'T HOGERHUYSSTRAAT 9-11, PARAMARIBO, SR)
# 618
# IBM, 91-93 ST VINCENT STREET, FLOORS 1 AND 2, PORT-OF-SPAIN, TT
# --------------> geocode(IBM, 91-93 ST VINCENT STREET, FLOORS 1 AND 2, PORT-OF-SPAIN, TT)
# 646
# IBM, 1-7 KAKOGAWACHO KIMURA, KAKOGAWA, JP, 675-0038
# --------------> geocode(IBM, 1-7 KAKOGAWACHO KIMURA, KAKOGAWA, JP, 675-0038)
# 648
# IBM, 1-10-10 UTSUBOHONMACHI NISHI-KU, OSAKA, JP, 550-0004
# --------------> geocode(IBM, 1-10-10 UTSUBOHONMACHI NISHI-KU, OSAKA, JP, 550-0004)
# 652
# IBM, 7-1-1 ONOEDOURI CHUOH-KU, KOBE, JP, 651-0088
# --------------> geocode(IBM, 7-1-1 ONOEDOURI CHUOH-KU, KOBE, JP, 651-0088)
# 654
# IBM, 614 HIGASHISHIOKOJICHO, SHIMOGYO-KU, KYOTO, JP, 600-8216
# --------------> geocode(IBM, 614 HIGASHISHIOKOJICHO, SHIMOGYO-KU, KYOTO, JP, 600-8216)
# 659
# IBM, 1-6-27 NANKOKITA SUMINOE-KU, OSAKA, JP, 559-0034
# --------------> geocode(IBM, 1-6-27 NANKOKITA SUMINOE-KU, OSAKA, JP, 559-0034)
# 6AH
# IBM, 400 MAIN ST, SAINT JOHN, NB, CA, E2K 4N5
# --------------> geocode(IBM, 400 MAIN ST, SAINT JOHN, NB, CA, E2K 4N5)
# 6U6
# IBM, 1-1-5 SHINSENRI HIGASHIMACHI, TOYONAKA, JP, 560-0082
# --------------> geocode(IBM, 1-1-5 SHINSENRI HIGASHIMACHI, TOYONAKA, JP, 560-0082)
# 71Y
# IBM, 4 & 6 AVE GUTTEMBERG, BUSSY-SAINT-GEORGES, FR, 77600
# --------------> geocode(IBM, 4 & 6 AVE GUTTEMBERG, BUSSY-SAINT-GEORGES, FR, 77600)
# 71Z
# IBM, 137 BLVD VOLTAIRE, PARIS, FR, 75011
# --------------> geocode(IBM, 137 BLVD VOLTAIRE, PARIS, FR, 75011)
# 72A
# IBM, CHAUSSÉE DE LERY, VAL DE REUIL, FR, 27701
# --------------> geocode(IBM, CHAUSSÉE DE LERY, VAL DE REUIL, FR, 27701)
# 753
# IBM, 240-5 DAIMONCHOTSUNOSHITA,, FUKUYAMA, JP, 721-0927
# --------------> geocode(IBM, 240-5 DAIMONCHOTSUNOSHITA,, FUKUYAMA, JP, 721-0927)
# 754
# IBM, 519-1 ISEMIYACHO, MATSUE, JP, 690-0006
# --------------> geocode(IBM, 519-1 ISEMIYACHO, MATSUE, JP, 690-0006)
# 755
# IBM, 1-1-3 SHIMOISHII, OKAYAMA, JP, 700-0907
# --------------> geocode(IBM, 1-1-3 SHIMOISHII, OKAYAMA, JP, 700-0907)
# 760
# IBM, 2-16 INARIMACHI, MINAMI-KU, HIROSHIMA, JP, 732-0827
# --------------> geocode(IBM, 2-16 INARIMACHI, MINAMI-KU, HIROSHIMA, JP, 732-0827)
# 761
# IBM, 1-10 YOYOGIDOURI TOKUYAMA, SHUNAN, JP, 745-0043
# --------------> geocode(IBM, 1-10 YOYOGIDOURI TOKUYAMA, SHUNAN, JP, 745-0043)
# 7AB
# IBM, 1969 UPPER WATER ST, 17TH FLR, PURDY'S WHARF, HALIFAX, NS, CA, B3J 3R7
# --------------> geocode(IBM, 1969 UPPER WATER ST, 17TH FLR, PURDY'S WHARF, HALIFAX, NS, CA, B3J 3R7)
# 7V3
# IBM, 2-201 MOTOUOMACHI, TOTTORI, JP, 680-0034
# --------------> geocode(IBM, 2-201 MOTOUOMACHI, TOTTORI, JP, 680-0034)
# 871
# IBM, 3-2-11 ICHIBANCHO, MATSUYAMA, JP, 790-0001
# --------------> geocode(IBM, 3-2-11 ICHIBANCHO, MATSUYAMA, JP, 790-0001)
# 872
# IBM, 2-26 SAKAIMACHI, KOCHI, JP, 780-0834
# --------------> geocode(IBM, 2-26 SAKAIMACHI, KOCHI, JP, 780-0834)
# 8V6
# IBM, 3-5-4 BANDAICHO, TOKUSHIMA, JP, 770-0941
# --------------> geocode(IBM, 3-5-4 BANDAICHO, TOKUSHIMA, JP, 770-0941)
# 980
# IBM, 3-26-29 HAKATAEKIMAE, HAKATA-KU, FUKUOKA, JP, 812-0011
# --------------> geocode(IBM, 3-26-29 HAKATAEKIMAE, HAKATA-KU, FUKUOKA, JP, 812-0011)
# 981
# IBM, 2-14-2 ASANO KOKURAKITA-KU, KITAKYUSHU, JP, 802-0001
# --------------> geocode(IBM, 2-14-2 ASANO KOKURAKITA-KU, KITAKYUSHU, JP, 802-0001)
# 982
# IBM, 2-21 KOZENMACHI, NAGASAKI, JP, 850-0032
# --------------> geocode(IBM, 2-21 KOZENMACHI, NAGASAKI, JP, 850-0032)
# 984
# IBM, 2-5-32 TAKACHIHODOURI, MIYAZAKI, JP, 880-0812
# --------------> geocode(IBM, 2-5-32 TAKACHIHODOURI, MIYAZAKI, JP, 880-0812)
# 9WD
# IBM, 2-27 MOMIJICHO, FUKUYAMA, JP, 720-0811
# --------------> geocode(IBM, 2-27 MOMIJICHO, FUKUYAMA, JP, 720-0811)
# 9WX
# IBM, 164 HAGADAI HAGAMACHI, HAGAGUN, JP, 321-3325
# --------------> geocode(IBM, 164 HAGADAI HAGAMACHI, HAGAGUN, JP, 321-3325)
# 9ZG
# IBM, 5-11-10 OZU, MINAMI-KU, HIROSHIMA, JP, 732-0802
# --------------> geocode(IBM, 5-11-10 OZU, MINAMI-KU, HIROSHIMA, JP, 732-0802)
# 9ZH
# IBM, 5-1-78 HIGASHIHARA, ZAMA, JP, 228-0004
# --------------> geocode(IBM, 5-1-78 HIGASHIHARA, ZAMA, JP, 228-0004)
# 9ZJ
# IBM, 4-9-15 OZU, MINAMI-KU, HIROSHIMA, JP, 732-0802
# --------------> geocode(IBM, 4-9-15 OZU, MINAMI-KU, HIROSHIMA, JP, 732-0802)
# 9ZL
# IBM, 3 HIKARI, KASHIMA, JP, 314-0014
# --------------> geocode(IBM, 3 HIKARI, KASHIMA, JP, 314-0014)
# 9ZZ
# IBM, 580 HORIKAWACHO, SAIWAI-KU, KAWASAKI, JP, 212-8555
# --------------> geocode(IBM, 580 HORIKAWACHO, SAIWAI-KU, KAWASAKI, JP, 212-8555)
# A1P
# IBM, 117 FARNBOROUGH ROAD, FARNBOROUGH, GB, GU14 7JG
# --------------> geocode(IBM, 117 FARNBOROUGH ROAD, FARNBOROUGH, GB, GU14 7JG)
# A20
# IBM, 521 S BOSTON, TULSA, OK, US, 74103-4602
# --------------> geocode(IBM, 521 S BOSTON, TULSA, OK, US, 74103-4602)
# A2X
# IBM, LOVSTADVEIEN 7, 2312 OTTESTAD, MAILDADRESS: 2325 HAMAR, HAMAR, NO, 2325
# --------------> geocode(IBM, LOVSTADVEIEN 7, 2312 OTTESTAD, MAILDADRESS: 2325 HAMAR, HAMAR, NO, 2325)
# A43
# IBM, 8888 KEYSTONE CROSSING, SUITE 925, INDIANAPOLIS, IN, US, 46240
# --------------> geocode(IBM, 8888 KEYSTONE CROSSING, SUITE 925, INDIANAPOLIS, IN, US, 46240)
# A49
# IBM, 30 S 17TH ST, PHILADELPHIA, PA, US, 19103-4001
# --------------> geocode(IBM, 30 S 17TH ST, PHILADELPHIA, PA, US, 19103-4001)
# A4U
# IBM, 102 RUE DES BERGES DU LAC, TUNIS, TN, 2045
# --------------> geocode(IBM, 102 RUE DES BERGES DU LAC, TUNIS, TN, 2045)
# A4W
# IBM, 35, ALLEE DU CLOS DES CHARMES, LE POIRIER DE LA BUTTE, COLLEGIEN, FR, 77400
# --------------> geocode(IBM, 35, ALLEE DU CLOS DES CHARMES, LE POIRIER DE LA BUTTE, COLLEGIEN, FR, 77400)
# A56
# IBM, 8000 GRAINGER COURT, SPRINGFIELD, VA, US, 22153-3130
# --------------> geocode(IBM, 8000 GRAINGER COURT, SPRINGFIELD, VA, US, 22153-3130)
# A5Y
# IBM, 348 EDWARD STREET, BRISBANE, QLD, AU, 4000
# --------------> geocode(IBM, 348 EDWARD STREET, BRISBANE, QLD, AU, 4000)
# A6S
# IBM, CNR GEELONG RD & GEAR AVENUE, MT HELEN, BALLARAT, VIC, AU, 3350
# --------------> geocode(IBM, CNR GEELONG RD & GEAR AVENUE, MT HELEN, BALLARAT, VIC, AU, 3350)
# A6X
# IBM, LAATZENER STR. 1, HANNOVER, DE, 30539
# --------------> geocode(IBM, LAATZENER STR. 1, HANNOVER, DE, 30539)
# A78
# IBM, PLOT NO XI-7, KOLKATA, WB, IN, 700091
# --------------> geocode(IBM, PLOT NO XI-7, KOLKATA, WB, IN, 700091)
# A7X
# IBM, CARL-BENZ RING 22, GAIMERSHEIM, DE, 85080
# --------------> geocode(IBM, CARL-BENZ RING 22, GAIMERSHEIM, DE, 85080)
# A94
# IBM, GENERAAL LEMANSTRAAT 69, ANTWERP, BE, 2018
# --------------> geocode(IBM, GENERAAL LEMANSTRAAT 69, ANTWERP, BE, 2018)
# A9Q
# IBM, 48 NAVAM MAWATHA, THAAKSHANA MANDIRAYA, COLOMBO, LK, DIST II
# --------------> geocode(IBM, 48 NAVAM MAWATHA, THAAKSHANA MANDIRAYA, COLOMBO, LK, DIST II)
# A9V
# IBM, 23, KASR EL NIL, CAIRO, EG, 9999
# --------------> geocode(IBM, 23, KASR EL NIL, CAIRO, EG, 9999)
# AAG
# IBM, IBM-ALLEE 1, EHNINGEN, DE, 71139
# --------------> geocode(IBM, IBM-ALLEE 1, EHNINGEN, DE, 71139)
# AAH
# IBM, NEUMANN JANOS U.1, BUDAPEST, HU, 1117
# --------------> geocode(IBM, NEUMANN JANOS U.1, BUDAPEST, HU, 1117)
# AAM
# IBM, ALTROTTSTR.31, WALLDORF, DE, 69190
# --------------> geocode(IBM, ALTROTTSTR.31, WALLDORF, DE, 69190)
# AAY
# IBM, SITTARDER STRASSE 31, AACHEN, DE, 52078
# --------------> geocode(IBM, SITTARDER STRASSE 31, AACHEN, DE, 52078)
# ACT
# IBM, PJE. ING. ENRIQUE BUTTY 275, CAPITAL FEDERAL, C, AR, C1001AFA
# --------------> geocode(IBM, PJE. ING. ENRIQUE BUTTY 275, CAPITAL FEDERAL, C, AR, C1001AFA)
# ADA
# IBM, 180 GREENHILL ROAD, PARKSIDE, SA, AU, 5063
# --------------> geocode(IBM, 180 GREENHILL ROAD, PARKSIDE, SA, AU, 5063)
# ADI
# IBM, 4600 MCAULEY PLACE, SUITE 200, CINCINNATI, OH, US, 45242-4765
# --------------> geocode(IBM, 4600 MCAULEY PLACE, SUITE 200, CINCINNATI, OH, US, 45242-4765)
# ADS
# IBM, BEIM STROHHAUSE 17, HAMBURG, DE, 20097
# --------------> geocode(IBM, BEIM STROHHAUSE 17, HAMBURG, DE, 20097)
# ADT
# IBM, 1000 BELLEVIEW ST, DALLAS, TX, US, 75215-1870
# --------------> geocode(IBM, 1000 BELLEVIEW ST, DALLAS, TX, US, 75215-1870)
# AFO
# IBM, 4499 FISHER RD, COLUMBUS, OH, US, 43228-9509
# --------------> geocode(IBM, 4499 FISHER RD, COLUMBUS, OH, US, 43228-9509)
# AIR
# IBM, 160 AIRPORT RD, WESCHESTER COUNTY AIRPORT, WHITE PLAINS, NY, US, 10604-1219
# --------------> geocode(IBM, 160 AIRPORT RD, WESCHESTER COUNTY AIRPORT, WHITE PLAINS, NY, US, 10604-1219)
# ALA
# IBM, 3500 BLUE LAKE DR, BIRMINGHAM, AL, US, 35243-1900
# --------------> geocode(IBM, 3500 BLUE LAKE DR, BIRMINGHAM, AL, US, 35243-1900)
# ALX
# IBM, 5, MAHMOUD ABDEL MOMEIM SHAKER, ST, ALEXANDRIA, EG, 9999
# --------------> geocode(IBM, 5, MAHMOUD ABDEL MOMEIM SHAKER, ST, ALEXANDRIA, EG, 9999)
# AMA
# IBM, PTE. HIPOLITO YRIGOYEN 2149, MARTINEZ / SAN ISIDRO, BUENOS AIRES, B, AR, B1640HFQ
# --------------> geocode(IBM, PTE. HIPOLITO YRIGOYEN 2149, MARTINEZ / SAN ISIDRO, BUENOS AIRES, B, AR, B1640HFQ)
# ANY
# IBM, 80 STATE ST, 4TH FL, ALBANY, NY, US, 12207-2543
# --------------> geocode(IBM, 80 STATE ST, 4TH FL, ALBANY, NY, US, 12207-2543)
# APM
# IBM, 1000 REPUBLIC DR, SUITE 685, ALLEN PARK, MI, US, 48101-3636
# --------------> geocode(IBM, 1000 REPUBLIC DR, SUITE 685, ALLEN PARK, MI, US, 48101-3636)
# ASK
# IBM, MLYNSKE NIVY 49, APOLLO BC II, BLOCK H, BRATISLAVA, SK, 82109
# --------------> geocode(IBM, MLYNSKE NIVY 49, APOLLO BC II, BLOCK H, BRATISLAVA, SK, 82109)
# B6C
# IBM, VIA SCIANGAI 53, ROMA, RM, IT, 00144
# --------------> geocode(IBM, VIA SCIANGAI 53, ROMA, RM, IT, 00144)
# BAC
# IBM, 5100 CALIFORNIA AVE, BAKERSFIELD, CA, US, 93309-0715
# --------------> geocode(IBM, 5100 CALIFORNIA AVE, BAKERSFIELD, CA, US, 93309-0715)
# BAW
# IBM, RUA ENG. FRANCISCO DE PITTA BRITO 1, FLOOR SS, TE, 1, 4, & 5, SAO PAULO, SP, BR, 04753-080
# --------------> geocode(IBM, RUA ENG. FRANCISCO DE PITTA BRITO 1, FLOOR SS, TE, 1, 4, & 5, SAO PAULO, SP, BR, 04753-080)
# BBN
# IBM, AL. ARAGUAIA 2044 - 9? ANDAR, CENTRO EMPRESARIAL ARAGUAIA, BARUERI, SP, BR, 06455-000
# --------------> geocode(IBM, AL. ARAGUAIA 2044 - 9? ANDAR, CENTRO EMPRESARIAL ARAGUAIA, BARUERI, SP, BR, 06455-000)
# BBS
# IBM, SCN QUADRA 4, BLOCO B, N.100, SALA 601 E 701, BRASILIA, DF, BR, 70714-900
# --------------> geocode(IBM, SCN QUADRA 4, BLOCO B, N.100, SALA 601 E 701, BRASILIA, DF, BR, 70714-900)
# BBU
# IBM, AV. DOLORES ALCARAZ CALDAS, 7, 10 &11 FLOORS, PORTO ALEGRE, RS, BR, 90110-180
# --------------> geocode(IBM, AV. DOLORES ALCARAZ CALDAS, 7, 10 &11 FLOORS, PORTO ALEGRE, RS, BR, 90110-180)
# BCD
# IBM, RUA PLACIDO GOMES, BAIRRO ANITA GARIBALDI, JOINVILLE, SC, BR, 89202-050
# --------------> geocode(IBM, RUA PLACIDO GOMES, BAIRRO ANITA GARIBALDI, JOINVILLE, SC, BR, 89202-050)
# BCY
# IBM, RUA MARIA LUIZA SANTIAGO 200, 3? E 5? ANDARES, BELO HORIZONTE, MG, BR, 30360-740
# --------------> geocode(IBM, RUA MARIA LUIZA SANTIAGO 200, 3? E 5? ANDARES, BELO HORIZONTE, MG, BR, 30360-740)
# BDF
# IBM, 3 NEW SQUARE, BEDFONT LAKES, FELTHAM, GB, TW14 8HB
# --------------> geocode(IBM, 3 NEW SQUARE, BEDFONT LAKES, FELTHAM, GB, TW14 8HB)
# BDO
# IBM, AV. MINISTRO IVAN LINS, 300, 2O ANDAR, RIO DE JANEIRO, RJ, BR, 22620-110
# --------------> geocode(IBM, AV. MINISTRO IVAN LINS, 300, 2O ANDAR, RIO DE JANEIRO, RJ, BR, 22620-110)
# BDP
# IBM, RUA EZEQUIEL RAMOS 3-33, 2 ANDAR - CENTRO BAURU, BAURU, SP, BR, 17010-021
# --------------> geocode(IBM, RUA EZEQUIEL RAMOS 3-33, 2 ANDAR - CENTRO BAURU, BAURU, SP, BR, 17010-021)
# BDQ
# IBM, RUA GASPAR VIANA 324, ANDAR SUPERIOR, CAMPINA, BELEM, PA, BR, 66053-090
# --------------> geocode(IBM, RUA GASPAR VIANA 324, ANDAR SUPERIOR, CAMPINA, BELEM, PA, BR, 66053-090)
# BDT
# IBM, RUA RIO DE JANEIRO, 328, 4 ANDAR - CENTRO, BELO HORIZONTE, MG, BR, 30160-040
# --------------> geocode(IBM, RUA RIO DE JANEIRO, 328, 4 ANDAR - CENTRO, BELO HORIZONTE, MG, BR, 30160-040)
# BDU
# IBM, SCS QUADRA 2 ED. BRADESCO, BLOCO B-81, 2?. ANDAR, BRASILIA, DF, BR, 7039-900
# --------------> geocode(IBM, SCS QUADRA 2 ED. BRADESCO, BLOCO B-81, 2?. ANDAR, BRASILIA, DF, BR, 7039-900)
# BDV
# IBM, AV. DR. MORAES SALES, 668, 4? ANDAR - CENTRO, CAMPINAS, SP, BR, 13010-001
# --------------> geocode(IBM, AV. DR. MORAES SALES, 668, 4? ANDAR - CENTRO, CAMPINAS, SP, BR, 13010-001)
# BDW
# IBM, ESTRADA CAMPO LIMPO 4519, 1? ANDAR - PIRAJUSSARA, SAO PAULO, SP, BR, 05787-000
# --------------> geocode(IBM, ESTRADA CAMPO LIMPO 4519, 1? ANDAR - PIRAJUSSARA, SAO PAULO, SP, BR, 05787-000)
# BDX
# IBM, RUA BARAO DE ITAPAGIPE 225, BLOCO D, T?RREO - R. COMPRIDO, RIO DE JANEIRO, RJ, BR, 20261-005
# --------------> geocode(IBM, RUA BARAO DE ITAPAGIPE 225, BLOCO D, T?RREO - R. COMPRIDO, RIO DE JANEIRO, RJ, BR, 20261-005)
# BDZ
# IBM, AV. YARA S/N, CIDADE DE DEUS, PR?DIO AZUL - ANDAR INTERMED., OSASCO, SP, BR, 06000
# --------------> geocode(IBM, AV. YARA S/N, CIDADE DE DEUS, PR?DIO AZUL - ANDAR INTERMED., OSASCO, SP, BR, 06000)
# BEC
# IBM, NAHMITZER DAMM 12, BERLIN, DE, 12277
# --------------> geocode(IBM, NAHMITZER DAMM 12, BERLIN, DE, 12277)
# BEG
# IBM, AV. XV DE NOVEMBRO 772, 1? ANDAR - PORTO, CUIAB?, MT, BR, 78020-300
# --------------> geocode(IBM, AV. XV DE NOVEMBRO 772, 1? ANDAR - PORTO, CUIAB?, MT, BR, 78020-300)
# BEH
# IBM, AV. PRESIDENTE AFFONSO CAMARGO 177, 2? ANDAR, JARDIM BOT?NICO, CURITIBA, PAR, BR, 80060-090
# --------------> geocode(IBM, AV. PRESIDENTE AFFONSO CAMARGO 177, 2? ANDAR, JARDIM BOT?NICO, CURITIBA, PAR, BR, 80060-090)
# BEI
# IBM, RUA FULVIO ADUCCI 809, 1? ANDAR - CENTRO, FLORIANOPOLIS, SC, BR, 88075-001
# --------------> geocode(IBM, RUA FULVIO ADUCCI 809, 1? ANDAR - CENTRO, FLORIANOPOLIS, SC, BR, 88075-001)
# BEJ
# IBM, RUA FLORIANO PEIXOTO 875, 2? ANDAR - CENTRO, FORTALEZA, CE, BR, 60025-1
# --------------> geocode(IBM, RUA FLORIANO PEIXOTO 875, 2? ANDAR - CENTRO, FORTALEZA, CE, BR, 60025-1)
# BEK
# IBM, AV. GOIAS, 414, 3? ANDAR CENTRO, GOIANIA, GO, BR, 74010-010
# --------------> geocode(IBM, AV. GOIAS, 414, 3? ANDAR CENTRO, GOIANIA, GO, BR, 74010-010)
# BEM
# IBM, AV. SETE DE SETEMBRO 1652/1698, 2? ANDAR - VILA GALV?O, GUARULHOS, SP, BR, 07064-002
# --------------> geocode(IBM, AV. SETE DE SETEMBRO 1652/1698, 2? ANDAR - VILA GALV?O, GUARULHOS, SP, BR, 07064-002)
# BEN
# IBM, RUA 12 DE OUTUBRO 125, 4? ANDAR, SAO PAULO, SP, BR, 05073-001
# --------------> geocode(IBM, RUA 12 DE OUTUBRO 125, 4? ANDAR, SAO PAULO, SP, BR, 05073-001)
# BEO
# IBM, RUA SILVA RAMOS, 368 - CENTRO, MANAUS, AM, BR, 69025-030
# --------------> geocode(IBM, RUA SILVA RAMOS, 368 - CENTRO, MANAUS, AM, BR, 69025-030)
# BEP
# IBM, AV. GETULIO VARGAS 115, FUNDOS, 1? ANDAR - CENTRO, MARINGA, PAR, BR, 87013-130
# --------------> geocode(IBM, AV. GETULIO VARGAS 115, FUNDOS, 1? ANDAR - CENTRO, MARINGA, PAR, BR, 87013-130)
# BEQ
# IBM, AV. ERNANI DO AMARAL PEIXOTO 211, 2 ANDAR - CENTRO, NITEROI, RJ, BR, 24020-071
# --------------> geocode(IBM, AV. ERNANI DO AMARAL PEIXOTO 211, 2 ANDAR - CENTRO, NITEROI, RJ, BR, 24020-071)
# BER
# IBM, AV. RIO BRANCO 112, 1? E 2? ANDS - CAMPOS EL?SEOS, SAO PAULO, SP, BR, 01206-00
# --------------> geocode(IBM, AV. RIO BRANCO 112, 1? E 2? ANDS - CAMPOS EL?SEOS, SAO PAULO, SP, BR, 01206-00)
# BES
# IBM, AV. NOSSA SRA. DA PENHA, 1255, SALAS 101 / 102, VIT?RIA, ES, BR, 29055-131
# --------------> geocode(IBM, AV. NOSSA SRA. DA PENHA, 1255, SALAS 101 / 102, VIT?RIA, ES, BR, 29055-131)
# BEU
# IBM, AV. LINS DE VASCONCELOS 2362, 1 ANDAR, VILA MARIANA., SAO PAULO, SP, BR, 04112-001
# --------------> geocode(IBM, AV. LINS DE VASCONCELOS 2362, 1 ANDAR, VILA MARIANA., SAO PAULO, SP, BR, 04112-001)
# BEW
# IBM, BRADESCO. RUA SAO CRISTOVAO 600, 2? E 3? ANDS - S?O CRISTOVAM, RIO DE JANEIRO, RJ, BR, 20940-000
# --------------> geocode(IBM, BRADESCO. RUA SAO CRISTOVAO 600, 2? E 3? ANDS - S?O CRISTOVAM, RIO DE JANEIRO, RJ, BR, 20940-000)
# BEX
# IBM, AV DA FRANCA, 409 10 ANDAR, ED. ABELARDO PARENTE COM?RCIO, SALVADOR, BA, BR, 40010-000
# --------------> geocode(IBM, AV DA FRANCA, 409 10 ANDAR, ED. ABELARDO PARENTE COM?RCIO, SALVADOR, BA, BR, 40010-000)
# BEY
# IBM, AV. DR. PEDRO LESSA, 847, 1? ANDAR, BAIRRO PONTA DA PRAIA, SANTOS, SP, BR, 11025-001
# --------------> geocode(IBM, AV. DR. PEDRO LESSA, 847, 1? ANDAR, BAIRRO PONTA DA PRAIA, SANTOS, SP, BR, 11025-001)
# BEZ
# IBM, AV. DR. RUDGE RAMOS 155, 1?ANDAR - RUDGE RAMOS, SAO BERNARDO DO CAMPO, SP, BR, 09637-000
# --------------> geocode(IBM, AV. DR. RUDGE RAMOS 155, 1?ANDAR - RUDGE RAMOS, SAO BERNARDO DO CAMPO, SP, BR, 09637-000)
# BFA
# IBM, AV. BENEDITO FRIGGI 3330, FUNDOS - BAIRRO VISTA VERDE, SAO JOSE DOS CAMPOS, SP, BR, 12200
# --------------> geocode(IBM, AV. BENEDITO FRIGGI 3330, FUNDOS - BAIRRO VISTA VERDE, SAO JOSE DOS CAMPOS, SP, BR, 12200)
# BFB
# IBM, AV. FARRAPOS 3852, 1? ANDAR - NAVEGANTES, PORTO ALEGRE, RS, BR, 90220-003
# --------------> geocode(IBM, AV. FARRAPOS 3852, 1? ANDAR - NAVEGANTES, PORTO ALEGRE, RS, BR, 90220-003)
# BFC
# IBM, R. DO MUNIZ, 162? 2? ANDAR, S?O JOS?, RECIFE, PE, BR, 50020-1
# --------------> geocode(IBM, R. DO MUNIZ, 162? 2? ANDAR, S?O JOS?, RECIFE, PE, BR, 50020-1)
# BFD
# IBM, AV. SAUDADE 935, 2? ANDAR, CAMPOS EL?SIOS, RIBEIRAO PRETO, SP, BR, 14080
# --------------> geocode(IBM, AV. SAUDADE 935, 2? ANDAR, CAMPOS EL?SIOS, RIBEIRAO PRETO, SP, BR, 14080)
# BFE
# IBM, R. GENERAL OS?RIO 124, 2? ANDAR - CENTRO, VIT?RIA, ES, BR, 29010-035
# --------------> geocode(IBM, R. GENERAL OS?RIO 124, 2? ANDAR - CENTRO, VIT?RIA, ES, BR, 29010-035)
# BFG
# IBM, AVENIDA PRESIDENTE JUSCELINO KUBITS, SAO PAULO, SP, BR, 04543-907
# --------------> geocode(IBM, AVENIDA PRESIDENTE JUSCELINO KUBITS, SAO PAULO, SP, BR, 04543-907)
# BGN
# IBM, RUA 6, N.370, 15 ANDAR, SALAS 1506/1507/1508, GOIANIA, GO, BR, 74115-070
# --------------> geocode(IBM, RUA 6, N.370, 15 ANDAR, SALAS 1506/1507/1508, GOIANIA, GO, BR, 74115-070)
# BHA
# IBM, 3 BROOKHOLLOW AVENUE, NORWEST BUSINESS PARK, BAULKHAM HILLS, NSW, AU, 2153
# --------------> geocode(IBM, 3 BROOKHOLLOW AVENUE, NORWEST BUSINESS PARK, BAULKHAM HILLS, NSW, AU, 2153)
# BLA
# IBM, AV. NACOES UNIDAS 12901, 20? E 21? ANDARES - CENU, SAO PAULO, SP, BR, 04578-000
# --------------> geocode(IBM, AV. NACOES UNIDAS 12901, 20? E 21? ANDARES - CENU, SAO PAULO, SP, BR, 04578-000)
# BLD
# BLI
# IBM, AV. SANTOS DUMONT 1789 S.213, FORTALEZA, CE, BR, 61150-060
# --------------> geocode(IBM, AV. SANTOS DUMONT 1789 S.213, FORTALEZA, CE, BR, 61150-060)
# BLO
# IBM, 1615 COMMERCE PKWY, BLOOMINGTON, IL, US, 61704-9608
# --------------> geocode(IBM, 1615 COMMERCE PKWY, BLOOMINGTON, IL, US, 61704-9608)
# BLS
# IBM, AVENUE DU BOURGET, 42, BRUSSELS, BE, 1130
# --------------> geocode(IBM, AVENUE DU BOURGET, 42, BRUSSELS, BE, 1130)
# BMA
# IBM, AV. PASTEUR 146 & 138, RIO DE JANEIRO, RJ, BR, 22290-240
# --------------> geocode(IBM, AV. PASTEUR 146 & 138, RIO DE JANEIRO, RJ, BR, 22290-240)
# BME
# IBM, 6710 ROCKLEDGE DR, BETHESDA, MD, US, 20817-1827
# --------------> geocode(IBM, 6710 ROCKLEDGE DR, BETHESDA, MD, US, 20817-1827)
# BMM
# IBM, RD J FCO AGUIRRE PROENCA KM 9, SP101. CHACARA ASSAY, HORTOLANDIA, SP, BR, 13186-900
# --------------> geocode(IBM, RD J FCO AGUIRRE PROENCA KM 9, SP101. CHACARA ASSAY, HORTOLANDIA, SP, BR, 13186-900)
# BMN
# IBM, AVE. CONSTANTINO NERY 4165, SALA 104, MANAUS, AM, BR, 69058-795
# --------------> geocode(IBM, AVE. CONSTANTINO NERY 4165, SALA 104, MANAUS, AM, BR, 69058-795)
# BNT
# IBM, 11501 BURNET RD, AUSTIN, TX, US, 78758-3400
# --------------> geocode(IBM, 11501 BURNET RD, AUSTIN, TX, US, 78758-3400)
# BOA
# IBM, SCHOENAICHER STR. 220, BOEBLINGEN, DE, 71032
# --------------> geocode(IBM, SCHOENAICHER STR. 220, BOEBLINGEN, DE, 71032)
# BOL
# IBM, 6300 DIAGONAL HWY, BOULDER, CO, US, 80301-6108
# --------------> geocode(IBM, 6300 DIAGONAL HWY, BOULDER, CO, US, 80301-6108)
# BPA
# IBM, AV. GOVERNADOR JOSE MALCHER, BELEM, PA, BR, 66055-260
# --------------> geocode(IBM, AV. GOVERNADOR JOSE MALCHER, BELEM, PA, BR, 66055-260)
# BPR
# IBM, AV. MARECHAL DEODORO, 10? ANDAR, CURITIBA, PR, BR, 80020-320
# --------------> geocode(IBM, AV. MARECHAL DEODORO, 10? ANDAR, CURITIBA, PR, BR, 80020-320)
# BSC
# IBM, RUA ADOLFO MELO, SALAS 101 / 102, FLORIANOPOLIS, SC, BR, 88015-090
# --------------> geocode(IBM, RUA ADOLFO MELO, SALAS 101 / 102, FLORIANOPOLIS, SC, BR, 88015-090)
# BTU
# IBM, RUA TUTOIA 1157, SAO PAULO, SP, BR, 04007-900
# --------------> geocode(IBM, RUA TUTOIA 1157, SAO PAULO, SP, BR, 04007-900)
# BTV
# BUS
# BVA
# IBM, 2501 SE J ST, BENTONVILLE, AR, US, 72712-3724
# --------------> geocode(IBM, 2501 SE J ST, BENTONVILLE, AR, US, 72712-3724)
# C0A
# IBM, BORUPVANG 1, BALLERUP, DK, 2750
# --------------> geocode(IBM, BORUPVANG 1, BALLERUP, DK, 2750)
# C0Z
# IBM, AV. TANCREDO NEVES 450, SALA 3201 AND 3202, SALVADOR, BA, BR, 41820-020
# --------------> geocode(IBM, AV. TANCREDO NEVES 450, SALA 3201 AND 3202, SALVADOR, BA, BR, 41820-020)
# C1C
# IBM, AVE. LIBRAMIENTO APOD, STA ROSA 111, COL. FUTURO APODACA, MONTERREY, NLE, MX, 66600
# --------------> geocode(IBM, AVE. LIBRAMIENTO APOD, STA ROSA 111, COL. FUTURO APODACA, MONTERREY, NLE, MX, 66600)
# C1E
# IBM, RUA CAIS DO APOLO, 14? ANDAR - RECIFE, RECIFE, PE, BR, 50030-905
# --------------> geocode(IBM, RUA CAIS DO APOLO, 14? ANDAR - RECIFE, RECIFE, PE, BR, 50030-905)
# C1F
# IBM, 505 DOTA, KANI, JP, 509-0206
# --------------> geocode(IBM, 505 DOTA, KANI, JP, 509-0206)
# C1G
# IBM, 5-2-48 INOKUCHI, NISHI-KU, HIROSHIMA, JP, 733-0842
# --------------> geocode(IBM, 5-2-48 INOKUCHI, NISHI-KU, HIROSHIMA, JP, 733-0842)
# C1L
# IBM, J. HUIZINGALAAN 759, AMSTERDAM, NL, 1066 VH
# --------------> geocode(IBM, J. HUIZINGALAAN 759, AMSTERDAM, NL, 1066 VH)
# C1M
# IBM, DAVID RICARDOSTRAAT 2-4, AMSTERDAM, NL, 1066 JS
# --------------> geocode(IBM, DAVID RICARDOSTRAAT 2-4, AMSTERDAM, NL, 1066 JS)
# C1N
# IBM, TECHNICKA 23, BRNO, CZ, 61600
# --------------> geocode(IBM, TECHNICKA 23, BRNO, CZ, 61600)
# C1S
# IBM, GROUND FLOOR OF SUB-STATION BUILDIN, 1 MINTO ROAD,DHAKA-1000BANGLADESH, DHAKA, BD, 1000
# --------------> geocode(IBM, GROUND FLOOR OF SUB-STATION BUILDIN, 1 MINTO ROAD,DHAKA-1000BANGLADESH, DHAKA, BD, 1000)
# C1U
# IBM, WILHELM-FAY-STR. 30-34, FRANKFURT, DE, 65936
# --------------> geocode(IBM, WILHELM-FAY-STR. 30-34, FRANKFURT, DE, 65936)
# C1V
# IBM, HOLLERITHSTR. 1, MÜNCHEN, DE, 81829
# --------------> geocode(IBM, HOLLERITHSTR. 1, MÜNCHEN, DE, 81829)
# C1Y
# IBM, KE JI NAN YI LU, SHENZHEN HI-TECH IND PARK, LIMING BUILDING, NANSHAN DISTRICT, SHENZHEN, 44, CN, 518057
# --------------> geocode(IBM, KE JI NAN YI LU, SHENZHEN HI-TECH IND PARK, LIMING BUILDING, NANSHAN DISTRICT, SHENZHEN, 44, CN, 518057)
# C3B
# IBM, THE ESTUARIES, CENTURY CITY, NO. 1 OXBOW CRESCENT, CAPE TOWN, ZA, 7441
# --------------> geocode(IBM, THE ESTUARIES, CENTURY CITY, NO. 1 OXBOW CRESCENT, CAPE TOWN, ZA, 7441)
# C3C
# IBM, COMMONWEALTH AVENUE, BARANGAY UP DI, UP AYALA LAND TECHNO HUB, QUEZON CITY, 0, PH, 1121
# --------------> geocode(IBM, COMMONWEALTH AVENUE, BARANGAY UP DI, UP AYALA LAND TECHNO HUB, QUEZON CITY, 0, PH, 1121)
# C3G
# ALL, VI
# --------------> geocode(ALL, VI)
# C3Q
# IBM, 9 CHANGI BUSINESS PARK CENTRAL 1, SINGAPORE, SG, 486048
# --------------> geocode(IBM, 9 CHANGI BUSINESS PARK CENTRAL 1, SINGAPORE, SG, 486048)
# C3R
# IBM, KOEZTELEK U. 6, CITY GATE, BUDAPEST, HU, 1092
# --------------> geocode(IBM, KOEZTELEK U. 6, CITY GATE, BUDAPEST, HU, 1092)
# C3T
# IBM, NO 7 SONG REN ROAD, 3/F & 4/F, CATHAY FINANCIAL CENTER, TAIPEI, TW, 110
# --------------> geocode(IBM, NO 7 SONG REN ROAD, 3/F & 4/F, CATHAY FINANCIAL CENTER, TAIPEI, TW, 110)
# C3V
# IBM, 2 KE FA RD, GREAT WALL TECH BLDG,, NORTH AREA, SHENZHEN HI-TECH INDUSTRIAL PARK, NANSHAN DISTRICT,, SHENZHEN, 44, CN, 518057
# --------------> geocode(IBM, 2 KE FA RD, GREAT WALL TECH BLDG,, NORTH AREA, SHENZHEN HI-TECH INDUSTRIAL PARK, NANSHAN DISTRICT,, SHENZHEN, 44, CN, 518057)
# C4H
# IBM, 1 THE SQUARE, TEMPLE QUAY, BRISTOL, GB, BS1 6DG
# --------------> geocode(IBM, 1 THE SQUARE, TEMPLE QUAY, BRISTOL, GB, BS1 6DG)
# C4I
# IBM, 9 ALLEE ALAN TURING, PARC TECHNOLOGIQUE DE LA PARDIEU, AUBIERE, FR, 63170
# --------------> geocode(IBM, 9 ALLEE ALAN TURING, PARC TECHNOLOGIQUE DE LA PARDIEU, AUBIERE, FR, 63170)
# C4J
# IBM, RUE DE CHANTEMERLE, ZI DE LA COMBAUDE, CLERMONT-FERRAND, FR, 63000
# --------------> geocode(IBM, RUE DE CHANTEMERLE, ZI DE LA COMBAUDE, CLERMONT-FERRAND, FR, 63000)
# C4L
# IBM, EXPLORER, INFORMATION TECHNOLOGY PK, 4TH & 5TH FLRS, WHITEFIELD, BANGALORE, KA, IN, 560066
# --------------> geocode(IBM, EXPLORER, INFORMATION TECHNOLOGY PK, 4TH & 5TH FLRS, WHITEFIELD, BANGALORE, KA, IN, 560066)
# C4N
# IBM, OZONE - 3, SP INFOCITY, SASWAD RD, FURSUNGI VILLAGE, HADAPSAR, PUNE, MH, IN, 412308
# --------------> geocode(IBM, OZONE - 3, SP INFOCITY, SASWAD RD, FURSUNGI VILLAGE, HADAPSAR, PUNE, MH, IN, 412308)
# C4P
# IBM, EMBASSY LINKS, EMBASSY CYPRESS PT, INDIRANAGAR-KORAMANGALA, INTERMEDIATE RING RD, BANGALORE, KA, IN, 560071
# --------------> geocode(IBM, EMBASSY LINKS, EMBASSY CYPRESS PT, INDIRANAGAR-KORAMANGALA, INTERMEDIATE RING RD, BANGALORE, KA, IN, 560071)
# C4S
# IBM, 102 BOULEVARD DE LA WOLUWE, BRUSSELS, BE, 1200
# --------------> geocode(IBM, 102 BOULEVARD DE LA WOLUWE, BRUSSELS, BE, 1200)
# C4U
# IBM, KARLSROGATAN 2, SOLNA, SE, 17065
# --------------> geocode(IBM, KARLSROGATAN 2, SOLNA, SE, 17065)
# C5D
# IBM, AVE. JOAQUIN ORRANTIA & JUAN TANCA, EXECUTIVE BUILDING, GUAYAQUIL, G, EC, 3686
# --------------> geocode(IBM, AVE. JOAQUIN ORRANTIA & JUAN TANCA, EXECUTIVE BUILDING, GUAYAQUIL, G, EC, 3686)
# C5N
# IBM, VIA DARWIN,85, SETTIMO MILANESE, MI, IT, 20019
# --------------> geocode(IBM, VIA DARWIN,85, SETTIMO MILANESE, MI, IT, 20019)
# C5P
# IBM, DLF SILOKHERA, VILLAGE SILOKHERA, NATIONALL HIGHWAY - 8, HARYANA, GURGAON, HR, IN, 122002
# --------------> geocode(IBM, DLF SILOKHERA, VILLAGE SILOKHERA, NATIONALL HIGHWAY - 8, HARYANA, GURGAON, HR, IN, 122002)
# C6G
# IBM, SAMPSON HOUSE, 64 HOPTON STREET, LONDON, GB, SE1 9JH
# --------------> geocode(IBM, SAMPSON HOUSE, 64 HOPTON STREET, LONDON, GB, SE1 9JH)
# C6N
# IBM, BUILDING 2, KELBURN COURT, DATEN PARK, BIRCHWOOD, WARRINGTON, GB, WA3 6JA
# --------------> geocode(IBM, BUILDING 2, KELBURN COURT, DATEN PARK, BIRCHWOOD, WARRINGTON, GB, WA3 6JA)
# C7C
# IBM, 3-1-1 KARAKIDA, TAMA, JP, 206-0035
# --------------> geocode(IBM, 3-1-1 KARAKIDA, TAMA, JP, 206-0035)
# C7D
# IBM, 10 PLACE DE LA JOLIETTE, MARSEILLE, FR, 13002
# --------------> geocode(IBM, 10 PLACE DE LA JOLIETTE, MARSEILLE, FR, 13002)
# C7E
# IBM, 10 PRESNENSKAYA NABEREZHNAYA, MOSCOW, RU, 123112
# --------------> geocode(IBM, 10 PRESNENSKAYA NABEREZHNAYA, MOSCOW, RU, 123112)
# C7J
# IBM, NO 6 SZU WEI 3RD ROAD, 26/F, CATHAY SZU WEI FINANCIAL BLDG, KAOHSIUNG, TW, 802
# --------------> geocode(IBM, NO 6 SZU WEI 3RD ROAD, 26/F, CATHAY SZU WEI FINANCIAL BLDG, KAOHSIUNG, TW, 802)
# C7K
# IBM, SHEFA TAL ST. GIVATAYIM, TEL AVIV, TA, IL
# --------------> geocode(IBM, SHEFA TAL ST. GIVATAYIM, TEL AVIV, TA, IL)
# C7P
# IBM, ROAD NUMBER 1702, AL JASRAH TOWER BUILDING 95, 14TH FLOOR, OFFICE 1403, MANAMA, BH, 3214
# --------------> geocode(IBM, ROAD NUMBER 1702, AL JASRAH TOWER BUILDING 95, 14TH FLOOR, OFFICE 1403, MANAMA, BH, 3214)
# C7S
# IBM, 1-2-13 SHINSENRI NISHIMACHI, TOYONAKA, JP, 560-0083
# --------------> geocode(IBM, 1-2-13 SHINSENRI NISHIMACHI, TOYONAKA, JP, 560-0083)
# C7T
# IBM, 1-1-25 SHINURASHIMACHO, KANAGAWA-KU, YOKOHAMA, JP, 221-8520
# --------------> geocode(IBM, 1-1-25 SHINURASHIMACHO, KANAGAWA-KU, YOKOHAMA, JP, 221-8520)
# C7U
# IBM, 7-2-14 TOYO, KOTO-KU, TOKYO, JP, 135-0016
# --------------> geocode(IBM, 7-2-14 TOYO, KOTO-KU, TOKYO, JP, 135-0016)
# C7V
# IBM, 8-18 AZUMA KAMI-CHOU, KASHIWA, JP, 277-0011
# --------------> geocode(IBM, 8-18 AZUMA KAMI-CHOU, KASHIWA, JP, 277-0011)
# C7W
# IBM, 3-4-1 MARUNOUCHI, CHIYODA-KU, TOKYO, JP, 100-0005
# --------------> geocode(IBM, 3-4-1 MARUNOUCHI, CHIYODA-KU, TOKYO, JP, 100-0005)
# C7Y
# IBM, 2-14-1 KUMOJI, NAHA, JP, 900-0015
# --------------> geocode(IBM, 2-14-1 KUMOJI, NAHA, JP, 900-0015)
# C7Z
# IBM, CIRCONVALLAZIONE IDROSCALO, SEGRATE, MI, IT, 20090
# --------------> geocode(IBM, CIRCONVALLAZIONE IDROSCALO, SEGRATE, MI, IT, 20090)
# C8A
# IBM, 1-1 HONKOMORICHO, NARA, JP, 630-8231
# --------------> geocode(IBM, 1-1 HONKOMORICHO, NARA, JP, 630-8231)
# C8O
# IBM, 804-805 LEVEL 8, JL. PEMUDA 60-70, SURABAYA, JI, ID, 60271
# --------------> geocode(IBM, 804-805 LEVEL 8, JL. PEMUDA 60-70, SURABAYA, JI, ID, 60271)
# C8R
# IBM, NO. 8 NEW LINK RD, 5/F, MAGNUS TOWERS, MINDSPACE, MALAD (WEST), MUMBAI, MH, IN, 400064
# --------------> geocode(IBM, NO. 8 NEW LINK RD, 5/F, MAGNUS TOWERS, MINDSPACE, MALAD (WEST), MUMBAI, MH, IN, 400064)
# C8X
# IBM, DEAKVARI FASOR 16-18, VAC, HU, 2600
# --------------> geocode(IBM, DEAKVARI FASOR 16-18, VAC, HU, 2600)
# C9G
# IBM, 2-6-6 HAKATAEKIMAE, HAKATA-KU, FUKUOKA, JP, 812-0011
# --------------> geocode(IBM, 2-6-6 HAKATAEKIMAE, HAKATA-KU, FUKUOKA, JP, 812-0011)
# C9H
# IBM, 2-16-4,KOHNAN,MINATO-KU, TOKYO, JP, 180-0075
# --------------> geocode(IBM, 2-16-4,KOHNAN,MINATO-KU, TOKYO, JP, 180-0075)
# C9L
# IBM, 1-20-1 IWAMURADAKITA,, SAKU, JP, 385-0023
# --------------> geocode(IBM, 1-20-1 IWAMURADAKITA,, SAKU, JP, 385-0023)
# C9Y
# IBM, PRØVENSVEJ 1, BRØNDBY, DK, 2605
# --------------> geocode(IBM, PRØVENSVEJ 1, BRØNDBY, DK, 2605)
# CAM
# IBM, VIA MAMELI 191, CAGLIARI, CA, IT, 09100
# --------------> geocode(IBM, VIA MAMELI 191, CAGLIARI, CA, IT, 09100)
# CB1
# IBM, 1302 CONCOURSE DR, STE 110, LINTHICUM, MD, US, 21090-1022
# --------------> geocode(IBM, 1302 CONCOURSE DR, STE 110, LINTHICUM, MD, US, 21090-1022)
# CBO
# IBM, CARRERA 53 NUMERO 100-25, BOGOTA, CO, 11001000
# --------------> geocode(IBM, CARRERA 53 NUMERO 100-25, BOGOTA, CO, 11001000)
# CC5
# IBM, 333 JOHN CARLYLE ST, SUITE 635, ALEXANDRIA, VA, US, 22314-5767
# --------------> geocode(IBM, 333 JOHN CARLYLE ST, SUITE 635, ALEXANDRIA, VA, US, 22314-5767)
# CC6
# IBM, 2101 EXECUTIVE DR, HAMPTON, VA, US, 23666-2404
# --------------> geocode(IBM, 2101 EXECUTIVE DR, HAMPTON, VA, US, 23666-2404)
# CD1
# IBM, 2500 TECHNOLOGY CIRCLE, SUITE 2, BENTONVILLE, AR, US, 72712-7102
# --------------> geocode(IBM, 2500 TECHNOLOGY CIRCLE, SUITE 2, BENTONVILLE, AR, US, 72712-7102)
# CE2
# IBM, 30501 AGOURA RD, SUITE 100, AGOURA HILLS, CA, US, 91301-4323
# --------------> geocode(IBM, 30501 AGOURA RD, SUITE 100, AGOURA HILLS, CA, US, 91301-4323)
# CE5
# IBM, 194 WOOD AVE, ISELIN, NJ, US, 08830-1527
# --------------> geocode(IBM, 194 WOOD AVE, ISELIN, NJ, US, 08830-1527)
# CEF
# IBM, 2070 ROUTE 52, HOPEWELL JUNCTION, NY, US, 12533-6683
# --------------> geocode(IBM, 2070 ROUTE 52, HOPEWELL JUNCTION, NY, US, 12533-6683)
# CF0
# IBM, 11511 LUNA ROAD, FARMERS BRANCH, TX, US, 75234-6022
# --------------> geocode(IBM, 11511 LUNA ROAD, FARMERS BRANCH, TX, US, 75234-6022)
# CF3
# IBM, 2300 15TH STREET, SUITE 400, DENVER, CO, US, 80202-6106
# --------------> geocode(IBM, 2300 15TH STREET, SUITE 400, DENVER, CO, US, 80202-6106)
# CF5
# IBM, 14001 NORTH DALLAS PARKWAY, SUITE M100, DALLAS, TX, US, 75240-4350
# --------------> geocode(IBM, 14001 NORTH DALLAS PARKWAY, SUITE M100, DALLAS, TX, US, 75240-4350)
# CF6
# IBM, 4040 LAFAYETTE CENTER DRIVE, CHANTILLY, VA, US, 20151
# --------------> geocode(IBM, 4040 LAFAYETTE CENTER DRIVE, CHANTILLY, VA, US, 20151)
# CF8
# IBM, 44060 DIGITAL LOUDOUN, ASHBURN, VA, US, 20147
# --------------> geocode(IBM, 44060 DIGITAL LOUDOUN, ASHBURN, VA, US, 20147)
# CFA
# IBM, 55 COONARA AVENUE, WEST PENNANT HILLS, NSW, AU, 2125
# --------------> geocode(IBM, 55 COONARA AVENUE, WEST PENNANT HILLS, NSW, AU, 2125)
# CG2
# IBM, 550 ASSEMBLY ST, COLUMBIA, SC, US, 29201-4144
# --------------> geocode(IBM, 550 ASSEMBLY ST, COLUMBIA, SC, US, 29201-4144)
# CG6
# IBM, 505 HOWARD ST, SUITE 600, 700, & 850, SAN FRANCISCO, CA, US, 94105
# --------------> geocode(IBM, 505 HOWARD ST, SUITE 600, 700, & 850, SAN FRANCISCO, CA, US, 94105)
# CG9
# IBM, 1100 SPACE PARK DRIVE, SANTA CLARA, CA, US, 95054
# --------------> geocode(IBM, 1100 SPACE PARK DRIVE, SANTA CLARA, CA, US, 95054)
# CH0
# IBM, 75 BINNEY ST, CAMBRIDGE, MA, US, 02142-1123
# --------------> geocode(IBM, 75 BINNEY ST, CAMBRIDGE, MA, US, 02142-1123)
# CH1
# IBM, 1500 NORTH 19TH STREET, MONROE, LA, US, 71201
# --------------> geocode(IBM, 1500 NORTH 19TH STREET, MONROE, LA, US, 71201)
# CH3
# IBM, 10140 MESA RIM RD, SAN DIEGO, CA, US, 92121
# --------------> geocode(IBM, 10140 MESA RIM RD, SAN DIEGO, CA, US, 92121)
# CH4
# IBM, 325 BILL FRANCE BLVD, DAYTONA BEACH, FL, US, 32114-1301
# --------------> geocode(IBM, 325 BILL FRANCE BLVD, DAYTONA BEACH, FL, US, 32114-1301)
# CH5
# IBM, 900 WALNUT RIDGE DRIVE, HARTLAND, WI, US, 53029
# --------------> geocode(IBM, 900 WALNUT RIDGE DRIVE, HARTLAND, WI, US, 53029)
# CH8
# IBM, 260 FRANKLIN ST, BOSTON, MA, US, 02110
# --------------> geocode(IBM, 260 FRANKLIN ST, BOSTON, MA, US, 02110)
# CH9
# IBM, 111 WEST JACKSON BLVD, SUITE 2120, CHICAGO, IL, US, 60604
# --------------> geocode(IBM, 111 WEST JACKSON BLVD, SUITE 2120, CHICAGO, IL, US, 60604)
# CHE
# IBM, RATHAUSSTR. 7, CHEMNITZ, DE, 09111
# --------------> geocode(IBM, RATHAUSSTR. 7, CHEMNITZ, DE, 09111)
# CHQ
# IBM, 1 NEW ORCHARD RD, ARMONK, NY, US, 10504-1722
# --------------> geocode(IBM, 1 NEW ORCHARD RD, ARMONK, NY, US, 10504-1722)
# CI0
# IBM, 222 SOUTH RIVERSIDE PLAZA, SUITES 170 & 182, CHICAGO, IL, US, 60606
# --------------> geocode(IBM, 222 SOUTH RIVERSIDE PLAZA, SUITES 170 & 182, CHICAGO, IL, US, 60606)
# CI6
# IBM, 10 NORTH MARTINGALE RD, WOODFIELD PRESERVE, SCHAUMBURG, IL, US, 60173-2099
# --------------> geocode(IBM, 10 NORTH MARTINGALE RD, WOODFIELD PRESERVE, SCHAUMBURG, IL, US, 60173-2099)
# CMA
# IBM, ONE ROGERS ST, CAMBRIDGE, MA, US, 02142-1203
# --------------> geocode(IBM, ONE ROGERS ST, CAMBRIDGE, MA, US, 02142-1203)
# CMS
# IBM, 600 ANTON BLVD, COSTA MESA, CA, US, 92626-7221
# ...
# LVL
# IBM, 9780 ORMSBY STATION RD, SUITE 1400, LOUISVILLE, KY, US, 40223-4049
# --------------> geocode(IBM, 9780 ORMSBY STATION RD, SUITE 1400, LOUISVILLE, KY, US, 40223-4049)
# MDC
# IBM, 20 OLD POST RD, ARMONK, NY, US, 10504-1300
# --------------> geocode(IBM, 20 OLD POST RD, ARMONK, NY, US, 10504-1300)
# MDM
# IBM, 2125 RIDGEWOOD DR, SUITE 102, MIDLAND, MI, US, 48642-5863
# --------------> geocode(IBM, 2125 RIDGEWOOD DR, SUITE 102, MIDLAND, MI, US, 48642-5863)
# MJH
# IBM, JACKSON HOUSE, SIBSON ROAD, SALE, MANCHESTER, GB, M33 7RR
# --------------> geocode(IBM, JACKSON HOUSE, SIBSON ROAD, SALE, MANCHESTER, GB, M33 7RR)
# MLG
# IBM, CALZADA LEGARIA NRO. 853. COLONIA I, MEXICO CITY, DIF, MX, 11500
# --------------> geocode(IBM, CALZADA LEGARIA NRO. 853. COLONIA I, MEXICO CITY, DIF, MX, 11500)
# MLN
# IBM, 33 MAIDEN LANE, NEW YORK, NY, US, 10038-4518
# --------------> geocode(IBM, 33 MAIDEN LANE, NEW YORK, NY, US, 10038-4518)
# MLV
# IBM, 1 PLACE J.B CLEMENT, NOISY-LE-GRAND, FR, 93881
# --------------> geocode(IBM, 1 PLACE J.B CLEMENT, NOISY-LE-GRAND, FR, 93881)
# MMM
# IBM, GOTTLIEB-DAIMLER-STR. 12, MANNHEIM, DE, 68165
# --------------> geocode(IBM, GOTTLIEB-DAIMLER-STR. 12, MANNHEIM, DE, 68165)
# MOL
# IBM, 1701 RIVER DR, MOLINE, IL, US, 61265-1384
# --------------> geocode(IBM, 1701 RIVER DR, MOLINE, IL, US, 61265-1384)
# MOP
# IBM, RUE DE LA VIEILLE POSTE, PARC IND.LA POMPIGNANE, MONTPELLIER CEDEX 01, FR, 34006
# --------------> geocode(IBM, RUE DE LA VIEILLE POSTE, PARC IND.LA POMPIGNANE, MONTPELLIER CEDEX 01, FR, 34006)
# MPG
# IBM, 2200 CAMINO A EL CASTILLO, GUADALAJARA, JAL, MX, 45680
# --------------> geocode(IBM, 2200 CAMINO A EL CASTILLO, GUADALAJARA, JAL, MX, 45680)
# MSF
# IBM, ALFONSO NAPOLES GANDARA 3111, MEXICO CITY, DIF, MX, 01210
# --------------> geocode(IBM, ALFONSO NAPOLES GANDARA 3111, MEXICO CITY, DIF, MX, 01210)
# MUN
# IBM, NEVINGHOFF 3, MÜNSTER, DE, 48147
# --------------> geocode(IBM, NEVINGHOFF 3, MÜNSTER, DE, 48147)
# NAD
# IBM, VIA G.PORZIO 4, NAPOLI, NA, IT, 80143
# --------------> geocode(IBM, VIA G.PORZIO 4, NAPOLI, NA, IT, 80143)
# NCA
# IBM, 21 AVENUE SIMONE VEIL, NICE MERIDIA, FR, 06200
# --------------> geocode(IBM, 21 AVENUE SIMONE VEIL, NICE MERIDIA, FR, 06200)
# NCI
# IBM, AV.PROF.DR.CAVACO SILVA-TAGUS PARK, PORTO SALVO, 11, PT, 2744-002
# --------------> geocode(IBM, AV.PROF.DR.CAVACO SILVA-TAGUS PARK, PORTO SALVO, 11, PT, 2744-002)
# NHA
# IBM, 601 PACIFIC HIGHWAY, ST LEONARDS, NSW, AU, 2065
# --------------> geocode(IBM, 601 PACIFIC HIGHWAY, ST LEONARDS, NSW, AU, 2065)
# NHB
# IBM, WESTERN ROAD, NORTH HARBOUR, PORTSMOUTH, GB, PO6 3AU
# --------------> geocode(IBM, WESTERN ROAD, NORTH HARBOUR, PORTSMOUTH, GB, PO6 3AU)
# NIC
# IBM, 42-44 GRIVA DIGHENI AV., NICOSIA, 1, CY, 1096
# --------------> geocode(IBM, 42-44 GRIVA DIGHENI AV., NICOSIA, 1, CY, 1096)
# NMA
# IBM, 36,RUE EUGENE PORCHERON, IMM.ROGER BERARD, NOUMEA, NC, 98845
# --------------> geocode(IBM, 36,RUE EUGENE PORCHERON, IMM.ROGER BERARD, NOUMEA, NC, 98845)
# NOI
# IBM, ROSENHOLMVEIEN 25, (MAIL ADDRESS: P.O BOX 500, 1411 KOLBOTN), TROLLASEN, NO, 1414
# --------------> geocode(IBM, ROSENHOLMVEIEN 25, (MAIL ADDRESS: P.O BOX 500, 1411 KOLBOTN), TROLLASEN, NO, 1414)
# NOS
# IBM, MERCURIUSSTRAAT 27, NOSSEGEM, BE, 1930
# --------------> geocode(IBM, MERCURIUSSTRAAT 27, NOSSEGEM, BE, 1930)
# O65
# IBM, 33, RUE DES VIEILLES VIGNES, CROISSY-BEAUBOURG, FR, 77370
# --------------> geocode(IBM, 33, RUE DES VIEILLES VIGNES, CROISSY-BEAUBOURG, FR, 77370)
# OCP
# IBM, ONE FINANCIAL PLAZA, HARTFORD, CT, US, 06103-2618
# --------------> geocode(IBM, ONE FINANCIAL PLAZA, HARTFORD, CT, US, 06103-2618)
# OCS
# IBM, LAXENBURGERSTR. 252, WIEN, AT, 1232
# --------------> geocode(IBM, LAXENBURGERSTR. 252, WIEN, AT, 1232)
# ONP
# IBM, 150 4TH AVE N, SUITE 450, ONE NASHVILLE PLACE, NASHVILLE, TN, US, 37219-2486
# --------------> geocode(IBM, 150 4TH AVE N, SUITE 450, ONE NASHVILLE PLACE, NASHVILLE, TN, US, 37219-2486)
# OSA
# IBM, HAVLICKOVO NABREZI 38, OSTRAVA, CZ, 73016
# --------------> geocode(IBM, HAVLICKOVO NABREZI 38, OSTRAVA, CZ, 73016)
# PAP
# IBM, RUE FERDINAND FOREST, ZI.JARRY-HOUELBOURG, POINTE A PITRE, GP, 97110
# --------------> geocode(IBM, RUE FERDINAND FOREST, ZI.JARRY-HOUELBOURG, POINTE A PITRE, GP, 97110)
# PAS
# IBM, VIA M.STABILE 160, PALERMO, PA, IT, 90139
# --------------> geocode(IBM, VIA M.STABILE 160, PALERMO, PA, IT, 90139)
# PDM
# IBM, VIA MASINI 8, PADOVA, PD, IT, 35129
# --------------> geocode(IBM, VIA MASINI 8, PADOVA, PD, IT, 35129)
# PEA
# IBM, 1060 HAY STREET, WEST PERTH, WA, AU, 6005
# --------------> geocode(IBM, 1060 HAY STREET, WEST PERTH, WA, AU, 6005)
# PEI
# IBM, 401 SW WATER ST SUITE 401, FOSTER & GALLAGHER BLDG, PEORIA, IL, US, 61602-1588
# --------------> geocode(IBM, 401 SW WATER ST SUITE 401, FOSTER & GALLAGHER BLDG, PEORIA, IL, US, 61602-1588)
# PHB
# IBM, 188 E. RODRIGUEZ JR. AVENUE, EASTWOOD CITY CYBERPARK, BAGUMBAYAN, QUEZON CITY, 0, PH, 1110
# --------------> geocode(IBM, 188 E. RODRIGUEZ JR. AVENUE, EASTWOOD CITY CYBERPARK, BAGUMBAYAN, QUEZON CITY, 0, PH, 1110)
# PIC
# IBM, 1551 S WASHINGTON AVE, PISCATAWAY, NJ, US, 08854-6700
# --------------> geocode(IBM, 1551 S WASHINGTON AVE, PISCATAWAY, NJ, US, 08854-6700)
# PKS
# IBM, 145 BOARDMAN RD, POUGHKEEPSIE, NY, US, 12603
# --------------> geocode(IBM, 145 BOARDMAN RD, POUGHKEEPSIE, NY, US, 12603)
# PLA
# IBM, 11400 BURNET RD, AUSTIN, TX, US, 78758-3493
# --------------> geocode(IBM, 11400 BURNET RD, AUSTIN, TX, US, 78758-3493)
# PLB
# IBM, 1000 RIVER ST, ESSEX JUNCTION, VT, US, 05452-4299
# --------------> geocode(IBM, 1000 RIVER ST, ESSEX JUNCTION, VT, US, 05452-4299)
# PLE
# IBM, IBM 1701 NORTH ST, ENDICOTT, NY, US, 13760-5553
# --------------> geocode(IBM, IBM 1701 NORTH ST, ENDICOTT, NY, US, 13760-5553)
# PLL
# IBM, 745 WEST NEW CIRCLE RD, BUILDING 200 & BUILDING 202, LEXINGTON, KY, US, 40511-1846
# --------------> geocode(IBM, 745 WEST NEW CIRCLE RD, BUILDING 200 & BUILDING 202, LEXINGTON, KY, US, 40511-1846)
# PLM
# IBM, AV. PROLONGACION JAVIER PRADO ESTE, LA MOLINA, LIMA, LIM, PE, 6230
# --------------> geocode(IBM, AV. PROLONGACION JAVIER PRADO ESTE, LA MOLINA, LIMA, LIM, PE, 6230)
# PLP
# IBM, 2455 SOUTH RD, POUGHKEEPSIE, NY, US, 12601-5400
# --------------> geocode(IBM, 2455 SOUTH RD, POUGHKEEPSIE, NY, US, 12601-5400)
# PLR
# IBM, 3605 HWY 52 N, ROCHESTER, MN, US, 55901-1407
# --------------> geocode(IBM, 3605 HWY 52 N, ROCHESTER, MN, US, 55901-1407)
# PLT
# IBM, 9000 S RITA RD, TUCSON, AZ, US, 85744-0002
# --------------> geocode(IBM, 9000 S RITA RD, TUCSON, AZ, US, 85744-0002)
# PNO
# IBM, 1515 POYDRAS ST, SUITE, NEW ORLEANS, LA, US, 70112-3723
# --------------> geocode(IBM, 1515 POYDRAS ST, SUITE, NEW ORLEANS, LA, US, 70112-3723)
# PNY
# IBM, 334 ROUTE 9W, PALISADES, NY, US, 10964-1200
# --------------> geocode(IBM, 334 ROUTE 9W, PALISADES, NY, US, 10964-1200)
# POK
# POZ
# IBM, ZIEBIECKA 35, POZNAN, PL, 60164
# --------------> geocode(IBM, ZIEBIECKA 35, POZNAN, PL, 60164)
# PPT
# IBM, BOULEVARD POMARE, RESIDENCE PAOFAI, PAPEETE, PF, 98713
# --------------> geocode(IBM, BOULEVARD POMARE, RESIDENCE PAOFAI, PAPEETE, PF, 98713)
# PTK
# IBM, RUA GONCALO SAMPAIO 157, PORTO, 13, PT, 4150-367
# --------------> geocode(IBM, RUA GONCALO SAMPAIO 157, PORTO, 13, PT, 4150-367)
# PTT
# IBM, 11 STANWIX ST, FLOOR 9, PITTSBURGH, PA, US, 15222-1312
# --------------> geocode(IBM, 11 STANWIX ST, FLOOR 9, PITTSBURGH, PA, US, 15222-1312)
# PUR
# IBM, 654 MUNOZ RIVERA AVE, 8TH FL, STE 805, HATO REY, PR, 00918
# --------------> geocode(IBM, 654 MUNOZ RIVERA AVE, 8TH FL, STE 805, HATO REY, PR, 00918)
# QIC
# IBM, ROCADE DE ZEPHIR, CENTRE CIAL DE LA ROCADE, CAYENNE, GF, 97300
# --------------> geocode(IBM, ROCADE DE ZEPHIR, CENTRE CIAL DE LA ROCADE, CAYENNE, GF, 97300)
# RCH
# RCX
# IBM, PO BOX 218, 1101 KITCHAWAN RD, YORKTOWN HEIGHTS, NY, US, 10598
# --------------> geocode(IBM, PO BOX 218, 1101 KITCHAWAN RD, YORKTOWN HEIGHTS, NY, US, 10598)
# RDS
# IBM, 201 W NORTH RIVER DR, SPOKANE, WA, US, 99201-2284
# --------------> geocode(IBM, 201 W NORTH RIVER DR, SPOKANE, WA, US, 99201-2284)
# RET
# IBM, 11107 SUNSET HILLS RD, RESTON, VA, US, 20190-5309
# --------------> geocode(IBM, 11107 SUNSET HILLS RD, RESTON, VA, US, 20190-5309)
# RHT
# IBM, 3222 40TH AVE NW, ROCHESTER, MN, US, 55901-1767
# --------------> geocode(IBM, 3222 40TH AVE NW, ROCHESTER, MN, US, 55901-1767)
# RIC
# IBM, 9201 ARBORETUM PKWY, SUITE 300, RICHMOND, VA, US, 23236-5402
# --------------> geocode(IBM, 9201 ARBORETUM PKWY, SUITE 300, RICHMOND, VA, US, 23236-5402)
# RIG
# IBM, BAUSKAS STR 58A, RIGA, LV, 1004
# --------------> geocode(IBM, BAUSKAS STR 58A, RIGA, LV, 1004)
# RLO
# IBM, 8401 GREENSBORO DR, 1ST FL, MCLEAN, VA, US, 22102-3598
# --------------> geocode(IBM, 8401 GREENSBORO DR, 1ST FL, MCLEAN, VA, US, 22102-3598)
# RML
# IBM, VIA DEI LUCCHESI 26, ROMA, RM, IT, 00187
# --------------> geocode(IBM, VIA DEI LUCCHESI 26, ROMA, RM, IT, 00187)
# RMS
# IBM, 95/97 BD DU GENERAL LECLERC, REIMS, FR, 51097
# --------------> geocode(IBM, 95/97 BD DU GENERAL LECLERC, REIMS, FR, 51097)
# RPL
# IBM, 3039 E CORNWALLIS RD, P.O. BOX 12195, RESEARCH TRIANGLE PARK, NC, US, 27709-2195
# --------------> geocode(IBM, 3039 E CORNWALLIS RD, P.O. BOX 12195, RESEARCH TRIANGLE PARK, NC, US, 27709-2195)
# RSA
# IBM, 590 MADISON AVE, NEW YORK, NY, US, 10022-2524
# --------------> geocode(IBM, 590 MADISON AVE, NEW YORK, NY, US, 10022-2524)
# RTP
# RV3
# IBM, MUROOR STREET, BUILDING "C" ; 1ST FLOOR, ABU DHABI, AE, 2720
# --------------> geocode(IBM, MUROOR STREET, BUILDING "C" ; 1ST FLOOR, ABU DHABI, AE, 2720)
# SAN
# IBM, 911 CENTRAL PKWY N, SUITE 100, SAN ANTONIO, TX, US, 78232-5053
# --------------> geocode(IBM, 911 CENTRAL PKWY N, SUITE 100, SAN ANTONIO, TX, US, 78232-5053)
# SBK
# IBM, 76 UPPER GROUND, LONDON, GB, SE19PZ
# --------------> geocode(IBM, 76 UPPER GROUND, LONDON, GB, SE19PZ)
# SBR
# IBM, 150 KETTLETOWN RD, SOUTHBURY, CT, US, 06488-2600
# --------------> geocode(IBM, 150 KETTLETOWN RD, SOUTHBURY, CT, US, 06488-2600)
# SDN
# IBM, 65 RUE STE MARIE, SAINT-DENIS DE LA REUNION, RE, 97477
# --------------> geocode(IBM, 65 RUE STE MARIE, SAINT-DENIS DE LA REUNION, RE, 97477)
# SEA
# IBM, 1200 5TH AVE, SEATTLE, WA, US, 98101-3132
# --------------> geocode(IBM, 1200 5TH AVE, SEATTLE, WA, US, 98101-3132)
# SEC
# IBM, LINDHOLMSALLEN 10, (MAIL ADDRESS:BOX 195, 40123 GÖTEBORG), GÖTEBORG, SE, 41755
# --------------> geocode(IBM, LINDHOLMSALLEN 10, (MAIL ADDRESS:BOX 195, 40123 GÖTEBORG), GÖTEBORG, SE, 41755)
# SEI
# IBM, KISTA ALLÉVÄG 60, (MAIL ADDRESS: 16492 STOCKHOLM), KISTA, SE, 16455
# --------------> geocode(IBM, KISTA ALLÉVÄG 60, (MAIL ADDRESS: 16492 STOCKHOLM), KISTA, SE, 16455)
# SEK
# IBM, STORGATAN 44, (MAIL ADDRESS: 85173 SUNDSVALL), SUNDSVALL, SE, 85230
# --------------> geocode(IBM, STORGATAN 44, (MAIL ADDRESS: 85173 SUNDSVALL), SUNDSVALL, SE, 85230)
# SFC
# IBM, 425 MARKET ST, SAN FRANCISCO, CA, US, 94105-2406
# --------------> geocode(IBM, 425 MARKET ST, SAN FRANCISCO, CA, US, 94105-2406)
# SGA
# IBM, W TOWER, 60 CITY RD, SOUTHGATE, MELBOURNE, VIC, AU, 3006
# --------------> geocode(IBM, W TOWER, 60 CITY RD, SOUTHGATE, MELBOURNE, VIC, AU, 3006)
# SHC
# IBM, 389 GANG AO ROAD, WAI GAO QIAO FREE TRADE ZONE, SHANGHAI, 31, CN, 200131
# --------------> geocode(IBM, 389 GANG AO ROAD, WAI GAO QIAO FREE TRADE ZONE, SHANGHAI, 31, CN, 200131)
# SHE
# IBM, ISTC/ITPC/CPC, GREAT WALL COMPUTER, SCIENCE & INDUSTRY PARK, NANSHAN DIST, SHENZHEN, 44, CN, 518057
# --------------> geocode(IBM, ISTC/ITPC/CPC, GREAT WALL COMPUTER, SCIENCE & INDUSTRY PARK, NANSHAN DIST, SHENZHEN, 44, CN, 518057)
# SIO
# IBM, 4916 TECHNOPOLIS DR, BUILDING, SIOUX FALLS, SD, US, 57106-4230
# --------------> geocode(IBM, 4916 TECHNOPOLIS DR, BUILDING, SIOUX FALLS, SD, US, 57106-4230)
# SJH
# IBM, 650 HARRY ROAD, ALMADEN RESEARCH CENTER, SAN JOSE, CA, US, 95120-6099
# --------------> geocode(IBM, 650 HARRY ROAD, ALMADEN RESEARCH CENTER, SAN JOSE, CA, US, 95120-6099)
# SJS
# IBM, 555 BAILEY AVE, SAN JOSE, CA, US, 95141-1003
# --------------> geocode(IBM, 555 BAILEY AVE, SAN JOSE, CA, US, 95141-1003)
# SLM
# IBM, 325 JAMES S MCDONNELL BLVD, HAZELWOOD, MO, US, 63042-2513
# --------------> geocode(IBM, 325 JAMES S MCDONNELL BLVD, HAZELWOOD, MO, US, 63042-2513)
# SMB
# IBM, 4205 S MIAMI BLVD, DURHAM, NC, US, 27703-9141
# --------------> geocode(IBM, 4205 S MIAMI BLVD, DURHAM, NC, US, 27703-9141)
# SMT
# IBM, 2710 S GATEWAY OAKS DR, SUITE 200, SACRAMENTO, CA, US, 95833-4307
# --------------> geocode(IBM, 2710 S GATEWAY OAKS DR, SUITE 200, SACRAMENTO, CA, US, 95833-4307)
# SOB
# IBM, 36, DRAGAN TZANKOV BLVD, INTERPRED WORLD TRADE CENTER, SOFIA, BG, 1057
# --------------> geocode(IBM, 36, DRAGAN TZANKOV BLVD, INTERPRED WORLD TRADE CENTER, SOFIA, BG, 1057)
# SPM
# IBM, 3315 E RIDGEVIEW, SPRINGFIELD, MO, US, 65804-4083
# --------------> geocode(IBM, 3315 E RIDGEVIEW, SPRINGFIELD, MO, US, 65804-4083)
# SRN
# IBM, 4000 EXECUTIVE PKWY, SAN RAMON, CA, US, 94583-2457
# --------------> geocode(IBM, 4000 EXECUTIVE PKWY, SAN RAMON, CA, US, 94583-2457)
# STR
# IBM, 48 RUE DU FAUBOURG DE SAVERNE, IMMEUBLE L'AVANCE, STRASBOURG, FR, 67084
# --------------> geocode(IBM, 48 RUE DU FAUBOURG DE SAVERNE, IMMEUBLE L'AVANCE, STRASBOURG, FR, 67084)
# SUF
# IBM, P.O. BOX 700, 299-300 LONG MEADOW RD, STERLING FOREST, NY, US, 10979-0700
# --------------> geocode(IBM, P.O. BOX 700, 299-300 LONG MEADOW RD, STERLING FOREST, NY, US, 10979-0700)
# SUM
# IBM, 1650 SUMMIT LAKE DR, TALLAHASSEE, FL, US, 32317-7936
# --------------> geocode(IBM, 1650 SUMMIT LAKE DR, TALLAHASSEE, FL, US, 32317-7936)
# SW5
# IBM, 486 SIN-DONG, YOUNGTONG-GU, 3F, DIGITAL EMPIRE2 BUILDING, SUWON, 41, KR, 443734
# --------------> geocode(IBM, 486 SIN-DONG, YOUNGTONG-GU, 3F, DIGITAL EMPIRE2 BUILDING, SUWON, 41, KR, 443734)
# TAA
# IBM, 3031 N ROCKY POINT DR WEST, SUITE 500, TAMPA, FL, US, 33607-5878
# --------------> geocode(IBM, 3031 N ROCKY POINT DR WEST, SUITE 500, TAMPA, FL, US, 33607-5878)
# TAL
# IBM, TOOMPUIESTEE 33A, TALLIN, EE, 10149
# --------------> geocode(IBM, TOOMPUIESTEE 33A, TALLIN, EE, 10149)
# THA
# IBM, SP BLDG, 388 PHAHOLYOTHIN ROAD, PHAYATHAI, BANGKOK, 10, TH, 10400
# --------------> geocode(IBM, SP BLDG, 388 PHAHOLYOTHIN ROAD, PHAYATHAI, BANGKOK, 10, TH, 10400)
# TKA
# IBM, 618 S KANSAS AVE, TOPEKA, KS, US, 66603-3839
# --------------> geocode(IBM, 618 S KANSAS AVE, TOPEKA, KS, US, 66603-3839)
# TRF
# IBM, BUYUKDERE CADDESI LEVENT, ISTANBUL, 34, TR, 34330
# --------------> geocode(IBM, BUYUKDERE CADDESI LEVENT, ISTANBUL, 34, TR, 34330)
# TTT
# IBM, 6,RUE BRINDEJONC-DES-MOULINAIS, TOULOUSE, FR, 31505
# --------------> geocode(IBM, 6,RUE BRINDEJONC-DES-MOULINAIS, TOULOUSE, FR, 31505)
# ULS
# IBM, SYRLINSTRASSE 38, ULM, DE, 89073
# --------------> geocode(IBM, SYRLINSTRASSE 38, ULM, DE, 89073)
# UPL
# IBM, PLAZA INDEPENDENCIA 721, MONTEVIDEO, MO, UY, 11000
# --------------> geocode(IBM, PLAZA INDEPENDENCIA 721, MONTEVIDEO, MO, UY, 11000)
# UX5
# IBM, VIA DEL CARROCCIO 6, PERO, MI, IT, 20016
# --------------> geocode(IBM, VIA DEL CARROCCIO 6, PERO, MI, IT, 20016)
# VCH
# IBM, AV. ERNESTO BLOHM, EDIFICIO IBM, CHUAO, CARACAS, M, VE, 1060
# --------------> geocode(IBM, AV. ERNESTO BLOHM, EDIFICIO IBM, CHUAO, CARACAS, M, VE, 1060)
# VIL
# IBM, SEIMYNISKIU STR 3, VILNIUS, LT, 09312
# --------------> geocode(IBM, SEIMYNISKIU STR 3, VILNIUS, LT, 09312)
# W97
# IBM, 59 RUE DE LA REPUBLIQUE, VALMY, MONTREUIL-SOUS-BOIS, FR, 93100
# --------------> geocode(IBM, 59 RUE DE LA REPUBLIQUE, VALMY, MONTREUIL-SOUS-BOIS, FR, 93100)
# WI3
# IBM, PAULSTRASSE 12, WINTERTHUR, CH, 8400
# --------------> geocode(IBM, PAULSTRASSE 12, WINTERTHUR, CH, 8400)
# WNM
# IBM, 18000 W 9 MILE RD, SOUTHFIELD, MI, US, 48075-4009
# --------------> geocode(IBM, 18000 W 9 MILE RD, SOUTHFIELD, MI, US, 48075-4009)
# WWK
# IBM, BIRMINGHAM ROAD, WARWICK, GB, CV34 5AH
# --------------> geocode(IBM, BIRMINGHAM ROAD, WARWICK, GB, CV34 5AH)
# Z1A
# IBM, PARK AZORIM 94 EM HAMOSHAVOT ROAD, KYRIAT ARIE - PETACH TIKVA, PETACH TIKVA, M, IL, 49527
# --------------> geocode(IBM, PARK AZORIM 94 EM HAMOSHAVOT ROAD, KYRIAT ARIE - PETACH TIKVA, PETACH TIKVA, M, IL, 49527)
# Z1J
# IBM, L11 & L7 SEABANK, 12-14 MARINE PARADE, SOUTHPORT, QLD, AU, 4215
# --------------> geocode(IBM, L11 & L7 SEABANK, 12-14 MARINE PARADE, SOUTHPORT, QLD, AU, 4215)
# Z3O
# IBM, NAN KANG (SOFTWARE PARK), E9W&E/E10W,, TAIPEI, TW, 115
# --------------> geocode(IBM, NAN KANG (SOFTWARE PARK), E9W&E/E10W,, TAIPEI, TW, 115)
# ZRL
# IBM, SAEUMERSTRASSE 4, RUESCHLIKON, CH, 8803
# --------------> geocode(IBM, SAEUMERSTRASSE 4, RUESCHLIKON, CH, 8803)
# ... done

# %%
# store IBM location data in a CSV file
c = ['geoname_id','country_iso_code','country_name','subdivision_1_iso_code','subdivision_1_name','city_name']
pd.DataFrame(ibmLocations).to_csv('test.ibmLocations.csv', index=False, float_format='%.9g', columns=c)

# store IBM network data in a CSV file
c = ['network','geoname_id','latitude','longitude','postal_code']
pd.DataFrame(ibmNetworksIPv4).to_csv('test.ibmNetworksIPv4.csv', index=False, float_format='%.9g', columns=c)
pd.DataFrame(ibmNetworksIPv6).to_csv('test.ibmNetworksIPv6.csv', index=False, float_format='%.9g', columns=c)

# %% [markdown]
# -----
# Run the next cell to load Internet network and location data from MaxMind:

# %%
print('running ...')

with urlopen(maxmindURL) as response:
    with zipfile.ZipFile(BytesIO(response.read())) as file:
        file.extractall()

# find the newest directory, in case there are old directories left over from previous runs
maxmindDirectory = sorted( [ f for f in os.listdir() if os.path.isdir(f) and f.startswith('GeoLite2-City-CSV') ] )[-1]

# load the MaxMind network and location data 
maxmindNetworksIPv4 = pd.read_csv(maxmindDirectory + '/GeoLite2-City-Blocks-IPv4.csv', header=0, dtype=str)
maxmindNetworksIPv6 = pd.read_csv(maxmindDirectory + '/GeoLite2-City-Blocks-IPv6.csv', header=0, dtype=str)
maxmindLocations = pd.read_csv(maxmindDirectory + '/GeoLite2-City-Locations-en.csv', header=0, dtype=str)

print('... done')
# Out:
# running ...
# ... done

# %%
maxmindNetworksIPv4
# Out:
#                   network geoname_id registered_country_geoname_id  \
# 0              1.0.0.0/24    2151718                       2077456
# 1              1.0.1.0/24    1810821                       1814991
# 2              1.0.2.0/23    1810821                       1814991
# 3              1.0.4.0/22    2077456                       2077456
# 4              1.0.8.0/21    1809858                       1814991
# 5             1.0.16.0/20    1850147                       1861060
# 6             1.0.32.0/19    1809858                       1814991
# ...                   ...        ...                           ...
# 2662725  223.255.236.0/22    1796236                       1814991
# 2662726  223.255.240.0/22    1819730                       1819730
# 2662727  223.255.244.0/22    1258847                       1269750
# 2662728  223.255.248.0/22    1819730                       1819730
# 2662729  223.255.252.0/23    1814991                       1814991
# 2662730  223.255.254.0/24    1880251                       1880251
# 2662731  223.255.255.0/24    2077456                       2077456
#
#         represented_country_geoname_id is_anonymous_proxy  \
# 0                                  NaN                  0
# 1                                  NaN                  0
# 2                                  NaN                  0
# 3                                  NaN                  0
# 4                                  NaN                  0
# 5                                  NaN                  0
# 6                                  NaN                  0
# ...                                ...                ...
# 2662725                            NaN                  0
# 2662726                            NaN                  0
# 2662727                            NaN                  0
# 2662728                            NaN                  0
# 2662729                            NaN                  0
# 2662730                            NaN                  0
# 2662731                            NaN                  0
#
#         is_satellite_provider postal_code  latitude longitude accuracy_radius
# 0                           0        3095  -37.7000  145.1833            1000
# 1                           0         NaN   26.0614  119.3061              50
# 2                           0         NaN   26.0614  119.3061              50
# 3                           0         NaN  -33.4940  143.2104            1000
# 4                           0         NaN   23.1167  113.2500              50
# 5                           0    102-0082   35.6850  139.7514             500
# 6                           0         NaN   23.1167  113.2500              50
# ...                       ...         ...       ...       ...             ...
# 2662725                     0         NaN   31.0456  121.3997              50
# 2662726                     0         NaN   22.2500  114.1667              50
# 2662727                     0      360001   22.3000   70.7833               1
# 2662728                     0         NaN   22.2500  114.1667              50
# 2662729                     0         NaN   34.7725  113.7266              50
# 2662730                     0         NaN    1.3667  103.8000              50
# 2662731                     0         NaN  -33.4940  143.2104            1000
#
# [2662732 rows x 10 columns]

# %%
maxmindNetworksIPv6
# Out:
#                                            network geoname_id  \
# 0        600:8801:9400:5a1:948b:ab15:dde3:61a3/128    5363990
# 1                                    2000:db8::/32    5332921
# 2                                    2001:200::/49    1850147
# 3                             2001:200:0:8000::/49   11612577
# 4                                  2001:200:1::/48    1861060
# 5                                  2001:200:2::/47    1861060
# 6                                  2001:200:4::/46    1861060
# ...                                            ...        ...
# 2039857                         2c0f:ffd8:800::/37     953987
# 2039858                        2c0f:ffd8:1000::/36     953987
# 2039859                        2c0f:ffd8:2000::/35     953987
# 2039860                        2c0f:ffd8:4000::/34     953987
# 2039861                        2c0f:ffd8:8000::/33     953987
# 2039862                             2c0f:ffe8::/32    2328926
# 2039863                             2c0f:fff0::/32    2328926
#
#         registered_country_geoname_id represented_country_geoname_id  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                             1861060                            NaN
# 3                             1861060                            NaN
# 4                             1861060                            NaN
# 5                             1861060                            NaN
# 6                             1861060                            NaN
# ...                               ...                            ...
# 2039857                        953987                            NaN
# 2039858                        953987                            NaN
# 2039859                        953987                            NaN
# 2039860                        953987                            NaN
# 2039861                        953987                            NaN
# 2039862                       2328926                            NaN
# 2039863                       2328926                            NaN
#
#         is_anonymous_proxy is_satellite_provider postal_code  latitude  \
# 0                        0                     0       91941   32.7596
# 1                        0                     0       93614   37.2502
# 2                        0                     0    102-0082   35.6850
# 3                        0                     0    182-0025   35.6556
# 4                        0                     0         NaN   36.0000
# 5                        0                     0         NaN   36.0000
# 6                        0                     0         NaN   36.0000
# ...                    ...                   ...         ...       ...
# 2039857                  0                     0         NaN  -29.0000
# 2039858                  0                     0         NaN  -29.0000
# 2039859                  0                     0         NaN  -29.0000
# 2039860                  0                     0         NaN  -29.0000
# 2039861                  0                     0         NaN  -29.0000
# 2039862                  0                     0         NaN   10.0000
# 2039863                  0                     0         NaN   10.0000
#
#          longitude accuracy_radius
# 0        -116.9940             100
# 1        -119.7513             100
# 2         139.7514              50
# 3         139.5522              20
# 4         138.0000             100
# 5         138.0000             100
# 6         138.0000             100
# ...            ...             ...
# 2039857    24.0000             100
# 2039858    24.0000             100
# 2039859    24.0000             100
# 2039860    24.0000             100
# 2039861    24.0000             100
# 2039862     8.0000             100
# 2039863     8.0000             100
#
# [2039864 rows x 10 columns]

# %%
maxmindLocations
# Out:
#        geoname_id locale_code continent_code continent_name country_iso_code  \
# 0           18918          en             EU         Europe               CY
# 1           49518          en             AF         Africa               RW
# 2           49747          en             AF         Africa               SO
# 3           51537          en             AF         Africa               SO
# 4           53654          en             AF         Africa               SO
# 5           54225          en             AF         Africa               SO
# 6           55671          en             AF         Africa               SO
# ...           ...         ...            ...            ...              ...
# 103001   11789760          en            NaN  North America               CA
# 103002   11790338          en             EU         Europe               CH
# 103003   11790342          en             AS           Asia               JP
# 103004   11790343          en             AS           Asia               JP
# 103005   11790394          en             AS           Asia               JP
# 103006   11790501          en             EU         Europe               CH
# 103007   11801589          en             AS           Asia               CN
#
#        country_name subdivision_1_iso_code subdivision_1_name  \
# 0            Cyprus                     04        Ammochostos
# 1            Rwanda                    NaN                NaN
# 2           Somalia                     BK             Bakool
# 3           Somalia                    NaN                NaN
# 4           Somalia                     BN           Banaadir
# 5           Somalia                     SH    Lower Shabeelle
# 6           Somalia                     JH         Lower Juba
# ...             ...                    ...                ...
# 103001       Canada                     NB      New Brunswick
# 103002  Switzerland                     VD               Vaud
# 103003        Japan                     13              Tokyo
# 103004        Japan                     13              Tokyo
# 103005        Japan                     13              Tokyo
# 103006  Switzerland                     TI             Ticino
# 103007        China                     ZJ           Zhejiang
#
#        subdivision_2_iso_code subdivision_2_name   city_name metro_code  \
# 0                         NaN                NaN    Protaras        NaN
# 1                         NaN                NaN         NaN        NaN
# 2                         NaN                NaN       Oddur        NaN
# 3                         NaN                NaN         NaN        NaN
# 4                         NaN                NaN   Mogadishu        NaN
# 5                         NaN                NaN       Merca        NaN
# 6                         NaN                NaN     Kismayo        NaN
# ...                       ...                ...         ...        ...
# 103001                    NaN                NaN   Shippagan        NaN
# 103002                    NaN                NaN     Servion        NaN
# 103003                    NaN                NaN    Setagaya        NaN
# 103004                    NaN                NaN      Mitaka        NaN
# 103005                    NaN                NaN      Nerima        NaN
# 103006                    NaN                NaN  Bedigliora        NaN
# 103007                    NaN                NaN      Keqiao        NaN
#
#                time_zone is_in_european_union
# 0         Asia/Famagusta                    1
# 1          Africa/Kigali                    0
# 2       Africa/Mogadishu                    0
# 3       Africa/Mogadishu                    0
# 4       Africa/Mogadishu                    0
# 5       Africa/Mogadishu                    0
# 6       Africa/Mogadishu                    0
# ...                  ...                  ...
# 103001   America/Moncton                    0
# 103002     Europe/Zurich                    0
# 103003        Asia/Tokyo                    0
# 103004        Asia/Tokyo                    0
# 103005        Asia/Tokyo                    0
# 103006     Europe/Zurich                    0
# 103007     Asia/Shanghai                    0
#
# [103008 rows x 14 columns]

# %% [markdown]
# -----
# Run the next cell to merge the MaxMind and IBM locations. The merged data will be written into a CSV file in the 'merged' directory named 'GeoLite2-City-Locations-en.csv'.

# %%
print('running ...')

# create a directory for the merged MaxMind+IBM CSV files
os.makedirs('merged', exist_ok=True)

# merge the MaxMind and IBM network data and store the result in CSV files

maxmindNetworksIPv4 = maxmindNetworksIPv4[ ~ maxmindNetworksIPv4['network'].str.startswith('9.') ]
mergedNetworksIPv4 = maxmindNetworksIPv4.append(ibmNetworksIPv4)
mergedNetworksIPv4.to_csv('merged/GeoLite2-City-Blocks-IPv4.csv', index=False, float_format='%.9g', columns=maxmindNetworksIPv4.columns)

maxmindNetworksIPv6 = maxmindNetworksIPv6[ ~ maxmindNetworksIPv6['network'].str.startswith('2620:1F7:') ]
mergedNetworksIPv6 = maxmindNetworksIPv6.append(ibmNetworksIPv6)
mergedNetworksIPv6.to_csv('merged/GeoLite2-City-Blocks-IPv6.csv', index=False, float_format='%.9g', columns=maxmindNetworksIPv6.columns)

# merge the MaxMind and IBM location data and store the result in a CSV file
mergedLocations = maxmindLocations.append(ibmLocations)
mergedLocations.to_csv('merged/GeoLite2-City-Locations-en.csv', index=False, float_format='%.9g', columns=maxmindLocations.columns)

print('... done')
# Out:
# running ...
# ... done

# %%
resultPackage = 'mergedIBMandInternetGeographyData.zip'

print('running ...')

# pack all result files into a ZIP package
with zipfile.ZipFile(resultPackage, 'w', compression=zipfile.ZIP_DEFLATED) as zipFile:
    for file in os.listdir('merged'):
        zipFile.write('merged/'+file, file)

# write the ZIP file to the notebook's bucket in Cloud Object Storage
##################cosClient.upload_file(Filename=resultPackage, Bucket=credentials['BUCKET'], Key=resultPackage)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# Run the next cell to merge the MaxMind and IBM networks. The merged data will be written into a CSV file in the 'merged' directory named 'GeoLite2-City-Blocks-IPv4.csv'.

# %%
print('running ...')

# create a frame of IBM locations indexed by country, city, and street address
ibmLocationsIndexed = ibmLocations.set_index(['country_name','city_name','street_address'])

# add country, city, street address, and latitude/longitude for each network in the IBM networks frame
ibmNetworksWithLocations = ibmNetworks.join(ibmLocationsIndexed, on=['country_name','city_name','street_address']).dropna(subset=['latitude'])

# merge the MaxMind and IBM network frames and store the result in a CSV file
mergedNetworks = pd.concat([maxmindNetworks,ibmNetworksWithLocations[ list( set(maxmindNetworks.columns) & set(ibmNetworksWithLocations.columns) ) ]])
mergedNetworks.to_csv('merged/GeoLite2-City-Blocks-IPv4.csv', index=False, float_format='%.9g', columns=maxmindNetworks.columns)
                                                        
print('... done')
# Out:
# running ...
# ... done

# %%
mergedNetworks
# Out:
#       accuracy_radius  geoname_id  is_anonymous_proxy  is_satellite_provider  \
# 0              1000.0   2151718.0                 0.0                    0.0
# 1                50.0   1810821.0                 0.0                    0.0
# 2                50.0   1810821.0                 0.0                    0.0
# 3              1000.0   2077456.0                 0.0                    0.0
# 4                50.0   1809858.0                 0.0                    0.0
# 5               500.0   1850147.0                 0.0                    0.0
# 6                50.0   1809858.0                 0.0                    0.0
# ...               ...         ...                 ...                    ...
# 8080              NaN       437.0                 NaN                    NaN
# 8574              NaN       399.0                 NaN                    NaN
# 8633              NaN       430.0                 NaN                    NaN
# 8635              NaN       430.0                 NaN                    NaN
# 8680              NaN       364.0                 NaN                    NaN
# 8698              NaN       438.0                 NaN                    NaN
# 8706              NaN       397.0                 NaN                    NaN
#
#        latitude   longitude         network postal_code  \
# 0    -37.700000  145.183300      1.0.0.0/24        3095
# 1     26.061400  119.306100      1.0.1.0/24         NaN
# 2     26.061400  119.306100      1.0.2.0/23         NaN
# 3    -33.494000  143.210400      1.0.4.0/22         NaN
# 4     23.116700  113.250000      1.0.8.0/21         NaN
# 5     35.685000  139.751400     1.0.16.0/20    190-0031
# 6     23.116700  113.250000     1.0.32.0/19         NaN
# ...         ...         ...             ...         ...
# 8080  32.047356  118.803251   9.112.12.0/22      210002
# 8574  12.983971   77.729418  9.113.140.0/23      560066
# 8633  28.432567   77.152737  9.184.144.0/21      122005
# 8635  28.432567   77.152737  9.184.152.0/22      122005
# 8680  22.535396  113.941911   9.112.32.0/20        None
# 8698  23.124282  113.372670  9.186.168.0/22        None
# 8706  17.422733   78.378025   9.109.85.0/24      500032
#
#       registered_country_geoname_id  represented_country_geoname_id
# 0                         2077456.0                             NaN
# 1                         1814991.0                             NaN
# 2                         1814991.0                             NaN
# 3                         2077456.0                             NaN
# 4                         1814991.0                             NaN
# 5                         1861060.0                             NaN
# 6                         1814991.0                             NaN
# ...                             ...                             ...
# 8080                            NaN                             NaN
# 8574                            NaN                             NaN
# 8633                            NaN                             NaN
# 8635                            NaN                             NaN
# 8680                            NaN                             NaN
# 8698                            NaN                             NaN
# 8706                            NaN                             NaN
#
# [2727786 rows x 10 columns]

# %% [markdown]
# -----
# Run the next cell to calculate [geohash codes](https://en.wikipedia.org/wiki/Geohash) for the latitude/longitude coordinates of merged MaxMind and IBM locations. The geohashes, coordinates, and location data will be written into a CSV file in the 'merged' directory named 'GeoLite2-City-Geohashes-en.csv'.

# %%
print('running ...')

# create a frame of locations indexed by ID number
mergedLocationsIndexed = mergedLocations.set_index('geoname_id')

# create a frame of geographical coordinates, that is, ID number, latitude, and longitude
mergedCoordinates = mergedNetworks[['geoname_id','latitude','longitude']].drop_duplicates()

# merge location and coordinate data and calculate geohash for each location's coordinates
mergedGeohashes = mergedCoordinates.join(mergedLocationsIndexed, on='geoname_id')
mergedGeohashes['geohash'] = mergedGeohashes.apply(lambda row: geohash2.encode(row['latitude'],row['longitude'],precision=6),axis=1)

# store the result in a CSV file
columns = ['geohash','latitude','longitude','geoname_id','country_iso_code','country_name','subdivision_1_iso_code','subdivision_1_name','subdivision_2_iso_code','subdivision_2_name','city_name']
mergedGeohashes.to_csv('merged/GeoLite2-City-Geohashes-en.csv', index=False, float_format='%.9g', columns=columns)
                           
print('... done')
# Out:
# running ...
# ... done

# %%
mergedGeohashes
# Out:
#       geoname_id   latitude   longitude      city_name continent_code  \
# 0      2151718.0 -37.700000  145.183300       Research             OC
# 1      1810821.0  26.061400  119.306100         Fuzhou             AS
# 3      2077456.0 -33.494000  143.210400            nan             OC
# 4      1809858.0  23.116700  113.250000      Guangzhou             AS
# 5      1850147.0  35.685000  139.751400          Tokyo             AS
# 7      1854383.0  34.661700  133.935000        Okayama             AS
# 11     1858311.0  34.583300  133.766700      Kurashiki             AS
# ...          ...        ...         ...            ...            ...
# 6054       431.0  31.299186  120.627245     IBM Suzhou            NaN
# 6665       432.0   2.924300  101.654478  IBM Cyberjaya            NaN
# 6727       433.0  17.414167   78.448979  IBM Hyderabad            NaN
# 6957       434.0  28.543288   77.148184  IBM New Delhi            NaN
# 7685       436.0 -35.312562  149.130389    IBM Forrest            NaN
# 8080       437.0  32.047356  118.803251    IBM Nanjing            NaN
# 8698       438.0  23.124282  113.372670  IBM Guangzhou            NaN
#
#      continent_name country_iso_code country_name locale_code  metro_code  \
# 0           Oceania               AU    Australia          en         NaN
# 1              Asia               CN        China          en         NaN
# 3           Oceania               AU    Australia          en         NaN
# 4              Asia               CN        China          en         NaN
# 5              Asia               JP        Japan          en         NaN
# 7              Asia               JP        Japan          en         NaN
# 11             Asia               JP        Japan          en         NaN
# ...             ...              ...          ...         ...         ...
# 6054            NaN               CN        China         NaN         NaN
# 6665            NaN               MY     Malaysia         NaN         NaN
# 6727            NaN               IN        India         NaN         NaN
# 6957            NaN               IN        India         NaN         NaN
# 7685            NaN               AU    Australia         NaN         NaN
# 8080            NaN               CN        China         NaN         NaN
# 8698            NaN               CN        China         NaN         NaN
#
#      subdivision_1_iso_code            subdivision_1_name  \
# 0                       VIC                      Victoria
# 1                        FJ                        Fujian
# 3                       NaN                           nan
# 4                        GD                     Guangdong
# 5                        13                         Tokyo
# 7                        33                       Okayama
# 11                       33                       Okayama
# ...                     ...                           ...
# 6054                Jiangsu                       Jiangsu
# 6665               Selangor                      Selangor
# 6727              Telangana                     Telangana
# 6957                     DL                         Delhi
# 7685                    ACT  Australian Capital Territory
# 8080                Jiangsu                       Jiangsu
# 8698        Guangdong Sheng               Guangdong Sheng
#
#      subdivision_2_iso_code subdivision_2_name            time_zone geohash
# 0                       NaN                nan  Australia/Melbourne  r1r1x8
# 1                       NaN                nan        Asia/Shanghai  wssu6b
# 3                       NaN                nan                  NaN  r4jc6y
# 4                       NaN                nan        Asia/Shanghai  ws0e90
# 5                       NaN                nan           Asia/Tokyo  xn77h0
# 7                       NaN                nan           Asia/Tokyo  wypjpv
# 11                      NaN                nan           Asia/Tokyo  wyphez
# ...                     ...                ...                  ...     ...
# 6054                   None               None                  NaN  wttf0c
# 6665                   None               None                  NaN  w2829h
# 6727              Hyderabad          Hyderabad                  NaN  tepg14
# 6957                   None               None                  NaN  ttnf7s
# 7685                   None               None                  NaN  r3dp1e
# 8080                   None               None                  NaN  wtsqr6
# 8698                   None               None                  NaN  ws0eec
#
# [121192 rows x 16 columns]

# %% [markdown]
# -----
# Finally, pack all of the merged CSV files into a ZIP package and copy it to the notebook's bucket in Cloud Object Storage ....

# %%
resultPackage = 'mergedIBMandInternetGeographyData.zip'

print('running ...')

# add the MaxMind IPv6 network file to the ZIP package
shutil.copy(maxmindDirectory + '/GeoLite2-City-Blocks-IPv6.csv', 'merged')

# pack all result files into a ZIP package
with zipfile.ZipFile(resultPackage, 'w', compression=zipfile.ZIP_DEFLATED) as zipFile:
    for file in os.listdir('merged'):
        zipFile.write('merged/'+file, file)

# write the ZIP file to the notebook's bucket in Cloud Object Storage
cosClient.upload_file(Filename=resultPackage, Bucket=credentials['BUCKET'], Key=resultPackage)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# To download the ZIP package containing the results of merging IBM and Internet geography data, do this:
#
# * In a browser, go to this notebook's project page
#
# * open the 'Files' panel by clicking the 'Find and Add Data' icon in the upper-right corner of the project page,
#
# * check the box next to 'mergedIBMandInternetGeographyData.zip'
#
# * select 'Download' from the pop-up menu in the 'Files' panel

# %% [markdown]
# \/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/

# %% [markdown]
# -----
# Optionally, run this last cell to clean up the notebook's runtime environment. This is really not necessary.

# %%
#!rm -rf *
#!pip uninstall -y googlemaps geohash2

# %%
ls -al
# Out:
# total 115200
# drwx------  4 sa73-1acf9232f65bd2-cf1c60ef4a00 users     4096 Feb 18 18:57 ./
# drwx------ 11 sa73-1acf9232f65bd2-cf1c60ef4a00 users     4096 Feb 17 20:06 ../
# drwx------  2 sa73-1acf9232f65bd2-cf1c60ef4a00 users     4096 Feb 18 18:51 GeoLite2-City-CSV_20180206/
# drwx------  2 sa73-1acf9232f65bd2-cf1c60ef4a00 users     4096 Feb 18 18:57 merged/
# -rw-------  1 sa73-1acf9232f65bd2-cf1c60ef4a00 users 39541117 Feb 18 18:57 mergedIBMandInternetGeographyData.zip
