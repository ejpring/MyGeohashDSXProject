# %% [markdown]
# ## merge IBM and MaxMind network and location data
#
# -----
#
# The code in this notebook merges Internet and IBM network and location data for use in IBM Streaming Analytics, such as the NetflowViewer demonstration and cyber-security applications:
#
# * Data for the Internet comes from CSV files provided by [MaxMind, Inc.](https://www.maxmind.com/en/home) as [GeoLite2 data](https://dev.maxmind.com/geoip/geoip2/geolite2/). This notebook downloads MaxMind's 'GeoLite2' data that lists subnets and their locations in the Internet, including country, state/province/territory, city, latitude, and longitude.
#
# * Data for the IBM internal network comes from a ['whois' service](http://whois.ibm.com) provided by AT&T. This notebook downloads 'whois' data that lists subnets and their locations in the IBM internal network, including country, state, city, and street address. This data is mapped to longitude and latitude with the Google Maps geocoding service.
#
# The Google Maps geocoding service requires an API key for a Google account. To create a key, do this:
#
# * In a browser, go to [Google](https://www.google.com/) and sign into an existing account or create a new account.
#
# * Go to the [Google Geocoding Service](https://developers.google.com/maps/documentation/javascript/geocoding) page and follow the instructions to create a project and enable the geocoding API.
#
# * Go to [Google Geocoding Service 'Get API Key'](https://developers.google.com/maps/documentation/geocoding/get-api-key), click on 'Get a Key', and then click the 'copy' button.
#
# * paste the copied key into the cell below as the value of the 'googlemapsKey' constant
#
# Google limits usage of their geocoding service to 2,500 requests per day, which is sufficient for two complete runs per day. The responses are cached and reused to avoid unnecessary use of Google's API.
#
# This notebook merges the IBM data into the MaxMind CSV files. It also generates a separate CSV file containing a [geohash code](https://en.wikipedia.org/wiki/Geohash) for each location's latitude/longitude. All of the resulting CSV files are packed into a ZIP file for transfer to Streaming Analytics projects:
#
# * [GeoLite2-City-Blocks-IPv4.csv](merged/GeoLite2-City-Blocks-IPv4.csv)
# * [GeoLite2-City-Blocks-IPv6.csv](merged/GeoLite2-City-Blocks-IPv6.csv)
# * [GeoLite2-City-Locations-en.csv](merged/GeoLite2-City-Locations-en.csv)
# * [GeoLite2-City-Geohashes-en.csv](merged/GeoLite2-City-Geohashes-en.csv)
#
# There are instructions for each step of this notebook in the cells below.

# %% [markdown]
# -----
# Run this cell once to install additional Python packages used in this notebook:

# %%
# !pip install --user googlemaps
# !pip install --user geohash2
# Out:
# Requirement already satisfied: googlemaps in /Users/pring/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: requests<3.0,>=2.11.1 in /Users/pring/anaconda3/lib/python3.6/site-packages (from googlemaps)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/pring/anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/pring/anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/pring/anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pring/anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# You are using pip version 9.0.1, however version 9.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: geohash2 in /Users/pring/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: docutils>=0.3 in /Users/pring/anaconda3/lib/python3.6/site-packages (from geohash2)
# You are using pip version 9.0.1, however version 9.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# -----
# Run this cell each time the notebook is loaded to include Python packages, and define some constants and functions used in this notebook:

# %%
import os
import re
import requests
from requests_file import FileAdapter
import json
import zipfile
import pandas as pd
import numpy as np
from io import BytesIO
from urllib.request import urlopen
import googlemaps
import geohash2
#####import ibm_boto3
#######from ibm_botocore.client import Config

# This constant points to the MaxMind 'GeoLite2' data.

maxmindGeoLite2URL = 'http://geolite.maxmind.com/download/geoip/database/GeoLite2-City-CSV.zip'

# This constant points to the IBM internal 'whois' service.

ibmWhoisLocationURL = 'http://whois.ibm.com:8080/whois/search.json?inverse-attribute=org&type-filter=domain&query-string=ORG-IBM1-IGA'
#ibmWhoisLocationURL = 'file:///Users/pring/git/MyGeohashDSXProject/whois.ibm.com_json_2018-03-23/ibm.domain.json'

# This constant contains a key for the Google Maps geocode API. 
# To create a key, follow the instructions at the top of this notebook.

googlemapsKey = 'AIzaSyAXrKyHrMa98L_e_CLtdi4UnQRPjHAEcYg'

# This constant contains the name of the JSON file where responses from the Google Maps
# geocode service are cached for reuse.

googlemapsCacheFilename = 'googlemaps.cache.json'

# This constant contains the name of a ZIP package that will contain the merged
# IBM and Maxmind data when this notebook has run to completion.

mergedPackageFilename = 'mergedIBMandMaxmindData.zip'

pd.set_option('max_rows', 15)

# This function iterates through the 'whois.ibm.com' data retrieved from the specified URL, 
# returning a 'dictionary' containing one entry each time it is called, until the end of the 
# data is reached, when it returns None.

def getWhoisEntry(url):
    
    # create an HTTP session that can handle a 'file' URL and send the request
    session = requests.Session()
    session.mount('file://', FileAdapter())
    response = session.get(url, stream=True)

    # if the HTTP response does not specify and encoding, force 'UTF-8'
    if response.encoding is None: response.encoding = 'utf-8'
    
    # read the HTTP response one line at a time, looking for the entry delimiters,
    # and returning one entry, converted to a JSON object, each time the function is called,
    # until the end of the response is reached
    body = ''
    state = 'prefix'
    for line in response.iter_lines(decode_unicode=True):
        if not line: continue
        if line == '  "object" : [ {': # starting delimiter for first entry 
            state = 'body'
        elif line == '  }, {': # delimiter between entries
            if len(body)>0: yield json.loads( '{' + body + '}' )
            body = ''
        elif line == '  } ]': # ending delimiter for last entry 
            if len(body)>0:  yield json.loads( '{' + body + '}' )
            state = 'suffix'
            body = ''
        else:
            if state=='body': body += line + '\n'
            
    # return 'None' when the end of the response is reached
    return None

# This function uses the Google Maps geocode API to map an address
# to location data, including latitude and longitude. Google limits 
# use of the API, so its responses are cached in a local file and 
# reused to avoid unnecessary use.

def getGoogleMapsGeocode(address, client, cache, cacheFilename):
    
    ########return None

    # if this address has been found before, return cached data, otherwise ask Google Maps
    # and cache the data
    if address in cache: 
        geocode = cache[address]
    else:
        print('--------------> geocode(' + address + ')')
        geocode = client.geocode(address)
        cache[address] = geocode
        storeObjectToFile(cacheFilename, cache)
    
    # extract address components from geocode data into simple dictionary
    if geocode and len(geocode)>0 and 'address_components' in geocode[0]: 
        result = { component['types'][0]: component['long_name'] for component in geocode[0]['address_components'] }
        result['latitude'] = geocode[0]['geometry']['location']['lat']
        result['longitude'] = geocode[0]['geometry']['location']['lng']
    else:
        result = None
        
    # return simple dictionary of address and location components
    return result

# This function loads a Python object from a JSON file. It used above
# to cache responses from the Google Maps geocode API.

def loadObjectFromFile(filename):
    if os.path.exists(filename):
        with open(filename, 'r') as file: return json.load(file)
    else:
        return {}

# This function stores a Python object in a JSON file. It used above
# to cache responses from the Google Maps geocode API.

def storeObjectToFile(filename, cache):
    if os.path.exists(filename+'.new'): os.remove(filename+'.new')
    with open(filename+'.new', 'w') as file: json.dump(cache, file)
    if os.path.exists(filename+'.old'): os.remove(filename+'.old')
    if os.path.exists(filename): os.rename(filename, filename+'.old')
    os.rename(filename+'.new', filename)
    
# This function replaces any mis-encoded Unicode characters of the form "\xXX"
# in the specified "UTF-8" string with the corresponding Unicode character, 
# properly encoded for "UTF-8"
    
def fixUnicodeCharacters(xxx):
    yyy = re.sub(r'\\x(..)', lambda match: chr(int(match.group(1),16)), xxx)
    return yyy

# %% [markdown]
# -----
# Run the next cell to download all of the 'domain' entries from the IBM 'whois' service into a list. This avoids the 'Connection broken: IncompleteRead' errors from the service that occur after a few hundred iterations when processing while downloading.

# %%
print('running ...')

whoisDomains = []
for whoisEntry in getWhoisEntry(ibmWhoisLocationURL):
    if whoisEntry['type']=='domain': whoisDomains.append(whoisEntry)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# Run the next cell to iterate through the list of 'domain' entries downloaded from the IBM 'whois' service above and collect IBM internal network and location data:

# %%
print('running ...')

# data for IBM networks and locations are collected in these lists
ibmNetworksIPv4 = []
ibmNetworksIPv6 = []
ibmLocations = []

# create a client for the Google Maps geocode service, and load any cached 
# responses from previous runs of this cell
googlemapsClient = googlemaps.Client(key=googlemapsKey)
googlemapsCache = loadObjectFromFile(googlemapsCacheFilename)
        
# iterate through the list of domain entries from IBM's whois' service
# downloaded above, collecting data on its locations and the subnets 
# assigned to each location
for whoisEntry in whoisDomains:

    # collect MaxMind location fields in this dictionary
    location = {}

    # skip 'whois' entries that are not IBM locations
    primaryKey = whoisEntry['primary-key']['attribute'][0]['value']
    if not re.fullmatch(r'[A-Z0-9]{3}', primaryKey): continue
    
    # extract fields of interest from 'whois' entries into a simple dictionary
    whois = {}
    for whoisAttribute in whoisEntry['attributes']['attribute']:  
        if whoisAttribute['name']=='remarks':
            match = re.fullmatch(r'RESO_(\w+)\.... = (.*)', whoisAttribute['value'])
            if match: whois[match.group(1)] = fixUnicodeCharacters(match.group(2))
            match = re.fullmatch(r'Prefix_List\.(\w+)\.... = (.*)', whoisAttribute['value'])
            if match and not match.group(2).endswith('NO_PREFIXES_FOUND'): whois[match.group(1)] = match.group(2).split(', ')
       
    # skip 'whois' entries that are not actual IBM locations
    if 'Country' not in whois: continue
    
    # construct string representation of location address from 'whois' fields
    address = whois['Country']
    if 'State' in whois: address = whois['State'] + ', ' + address        
    if 'City' in whois and whois['City']!='NO CITY': address = whois['City'] + ', ' + address
    if  'Address1' in whois and not whois['Address1'].startswith('NO IBM LOCATION'):
        if 'Address2' in whois: address = whois['Address2'] + ', ' + address
        if 'Address1' in whois: address = whois['Address1'] + ', ' + address
        ######if 'PostalCode' in whois: address = address  + ', ' + whois['PostalCode'] 
    print(primaryKey + ': ' + address)
        
    # get geocode data for location from Google Maps, and skip locations without any    
    geocode = getGoogleMapsGeocode(address, googlemapsClient, googlemapsCache, googlemapsCacheFilename)
    if not geocode: continue
        
    # copy 'whois' fields that correspond to MaxMind location fields
    location['geoname_id'] = primaryKey
    location['country_iso_code'] = whois['Country']
    if 'country' in geocode: location['country_name'] = geocode['country']
    if 'State' in whois: location['subdivision_1_iso_code'] = whois['State']
    if 'administrative_area_level_1' in geocode: location['subdivision_1_name'] = geocode['administrative_area_level_1']
    if 'City' in whois: location['city_name'] = 'IBM ' + whois['City']
    ####if 'locality' in geocode: location['city_name'] = 'IBM ' + geocode['locality']
    
    # add each IPv4 and IPv6 subnet at this location to their respective lists
    if 'IPv4' in whois:
        for cidr in whois['IPv4']:
            if not cidr.startswith('9.'): continue
            network = { 'network': cidr, 'geoname_id': primaryKey, 'latitude': geocode['latitude'], 'longitude': geocode['longitude'] }
            if 'PostalCode' in whois: network['postal_code'] = whois['PostalCode']
            ibmNetworksIPv4.append(network)
    if 'IPv6' in whois:
        for cidr in whois['IPv6']:
            if not cidr.startswith('2620:1F7:'): continue
            network = { 'network': cidr, 'geoname_id': primaryKey, 'latitude': geocode['latitude'], 'longitude': geocode['longitude'] }
            if 'PostalCode' in whois: network['postal_code'] = whois['PostalCode']
            ibmNetworksIPv6.append(network)
            
    # add this location to the list
    ibmLocations.append(location)
        
print('... done')
# Out:
# running ...
# 009: RUA DO PROLETARIADO 14/1, ALFRAGIDE, 11, PT
# --------------> geocode(RUA DO PROLETARIADO 14/1, ALFRAGIDE, 11, PT)
# 00A: AVDA DE LA PALMERA 19, SEVILLA, SE, ES
# --------------> geocode(AVDA DE LA PALMERA 19, SEVILLA, SE, ES)
# 00H: PLAZA CRONOS 1, MADRID, M, ES
# --------------> geocode(PLAZA CRONOS 1, MADRID, M, ES)
# 00J: C/ SAKURA, 8, SAN FRUITÒS DEL BALGÈS, B, ES
# --------------> geocode(C/ SAKURA, 8, SAN FRUITÒS DEL BALGÈS, B, ES)
# 00O: CALLE YECORA 4, MADRID, M, ES
# --------------> geocode(CALLE YECORA 4, MADRID, M, ES)
# 00T: PARCELA PC10601 - PARC DE L'ALBA, CERDANYOLA DEL VALLÉS, BARCELONA, B, ES
# --------------> geocode(PARCELA PC10601 - PARC DE L'ALBA, CERDANYOLA DEL VALLÉS, BARCELONA, B, ES)
# 00U: GRAN VÍA ASIMA 20, OFICINA 35. POLÍGONO SON CASTEL, PALMA DE MALLORCA, PM, ES
# --------------> geocode(GRAN VÍA ASIMA 20, OFICINA 35. POLÍGONO SON CASTEL, PALMA DE MALLORCA, PM, ES)
# 00W: PLAZA EUSKADI 5, BILBAO, PV, ES
# --------------> geocode(PLAZA EUSKADI 5, BILBAO, PV, ES)
# 01D: AVDA DIAGONAL 571, BARCELONA, B, ES
# --------------> geocode(AVDA DIAGONAL 571, BARCELONA, B, ES)
# 01E: AVDA DE ALGORTA NO 16, GETXO-VIZCAYA, BI, ES
# --------------> geocode(AVDA DE ALGORTA NO 16, GETXO-VIZCAYA, BI, ES)
# 01G: AV BRUSELAS, 20, ALCOBENDAS, M, ES
# --------------> geocode(AV BRUSELAS, 20, ALCOBENDAS, M, ES)
# 01H: TALES DE MILETO 1, ALCALA DE HENARES, M, ES
# --------------> geocode(TALES DE MILETO 1, ALCALA DE HENARES, M, ES)
# 01I: CALLE MARÍA TUBAU 3, MADRID, M, ES
# --------------> geocode(CALLE MARÍA TUBAU 3, MADRID, M, ES)
# 01J: CALLE MASQUEFA 58, BAJO DERECHA, VALENCIA, V, ES
# --------------> geocode(CALLE MASQUEFA 58, BAJO DERECHA, VALENCIA, V, ES)
# 01K: POLÍGONO DE POCOMACO, SECTOR I-1, N, LA CORUÑA, C, ES
# --------------> geocode(POLÍGONO DE POCOMACO, SECTOR I-1, N, LA CORUÑA, C, ES)
# 01L: POLÍGONO INDUSTRIAL SANTA CLARA, CALLE B, LOCAL 4, AV/ SANTA CLARA DE CUBA, SEVILLA, SE, ES
# --------------> geocode(POLÍGONO INDUSTRIAL SANTA CLARA, CALLE B, LOCAL 4, AV/ SANTA CLARA DE CUBA, SEVILLA, SE, ES)
# 01M: CARRER DE LA MORA 33, VIAL D, NAVE, BADALONA, B, ES
# --------------> geocode(CARRER DE LA MORA 33, VIAL D, NAVE, BADALONA, B, ES)
# 046: AVDA ARAGON 30, VALENCIA, V, ES
# --------------> geocode(AVDA ARAGON 30, VALENCIA, V, ES)
# 061: 1301 E EUCLID AVE, SUITE C, DES MOINES, IA, US
# --------------> geocode(1301 E EUCLID AVE, SUITE C, DES MOINES, IA, US)
# 068: J. HUIZINGALAAN 765, AMSTERDAM, NL
# --------------> geocode(J. HUIZINGALAAN 765, AMSTERDAM, NL)
# 083: 225 WESTERN AVE, AUGUSTA, ME, US
# --------------> geocode(225 WESTERN AVE, AUGUSTA, ME, US)
# 0AM: STA. HORTENSIA 26-28, MADRID, M, ES
# --------------> geocode(STA. HORTENSIA 26-28, MADRID, M, ES)
# 0AW: 1803 DOUGLAS ST, VICTORIA, BC, CA
# --------------> geocode(1803 DOUGLAS ST, VICTORIA, BC, CA)
# 0BE: 4611 CANADA WAY, BURNABY, BC, CA
# --------------> geocode(4611 CANADA WAY, BURNABY, BC, CA)
# 0BH: 4000 SEYMOUR PL, SAANICH, BC, CA
# --------------> geocode(4000 SEYMOUR PL, SAANICH, BC, CA)
# 0BR: 3-1-36 NORITAKESHINMACHI, NISHI-KU, NAGOYA, JP
# --------------> geocode(3-1-36 NORITAKESHINMACHI, NISHI-KU, NAGOYA, JP)
# 0BY: 3-25-9 MEIEKI, NAKAMURA-KU, NAGOYA, JP
# --------------> geocode(3-25-9 MEIEKI, NAKAMURA-KU, NAGOYA, JP)
# 0BZ: 1 KOKANCHO, FUKUYAMA, JP
# --------------> geocode(1 KOKANCHO, FUKUYAMA, JP)
# 0CA: RDA PONIENTE 18, TRES CANTOS, TRES CANTOS, M, ES
# --------------> geocode(RDA PONIENTE 18, TRES CANTOS, TRES CANTOS, M, ES)
# 0CB: 3-5-24 MIYAHARA, YODOGAWA-KU,, OSAKA, JP
# --------------> geocode(3-5-24 MIYAHARA, YODOGAWA-KU,, OSAKA, JP)
# 0CG: 1-1 MINAMIWATARIDACHO, KAWASAKI-KU, KAWASAKI, JP
# --------------> geocode(1-1 MINAMIWATARIDACHO, KAWASAKI-KU, KAWASAKI, JP)
# 0CT: MAR ADRIATICO 2, SAN FERNANDO DE HENARES, M, ES
# --------------> geocode(MAR ADRIATICO 2, SAN FERNANDO DE HENARES, M, ES)
# 0CU: 1 UZUMASA TATSUMICHO, UKYO-KU, KYOTO, JP
# --------------> geocode(1 UZUMASA TATSUMICHO, UKYO-KU, KYOTO, JP)
# 0CV: 1-1 MIZUSHIMA KAIGANDORI, KURASHIKI, JP
# --------------> geocode(1-1 MIZUSHIMA KAIGANDORI, KURASHIKI, JP)
# 0CX: 1 HASHIME CHOAZA NAKASHINKIRI, OKAZAKI, JP
# --------------> geocode(1 HASHIME CHOAZA NAKASHINKIRI, OKAZAKI, JP)
# 0DB: 4-2-7 IWAYANAKAMACHI, NADA-KU, KOBE, JP
# --------------> geocode(4-2-7 IWAYANAKAMACHI, NADA-KU, KOBE, JP)
# 0DD: 5-9-12 KITASHINAGAWA, SHINAGAWA-KU, TOKYO, JP
# --------------> geocode(5-9-12 KITASHINAGAWA, SHINAGAWA-KU, TOKYO, JP)
# 0DE: 1-5-5 TAKATSUKADAI, NISHI-KU, KOBE, JP
# --------------> geocode(1-5-5 TAKATSUKADAI, NISHI-KU, KOBE, JP)
# 0DF: 1 KANAZAWACHO, KAKOGAWA, JP
# --------------> geocode(1 KANAZAWACHO, KAKOGAWA, JP)
# 0DG: 2 NADAHAMAHIGASHICHO, NADA-KU, KOBE, JP
# --------------> geocode(2 NADAHAMAHIGASHICHO, NADA-KU, KOBE, JP)
# 0DH: 2-3-1 SHINHAMA, ARAICHO, TAKASAGO, JP
# --------------> geocode(2-3-1 SHINHAMA, ARAICHO, TAKASAGO, JP)
# 0DI: 740 YAGI, OKUBO CHO, AKASHI, JP
# --------------> geocode(740 YAGI, OKUBO CHO, AKASHI, JP)
# 0DK: 2-19 HIGASHIUNOBECHO, IBARAKI, JP
# --------------> geocode(2-19 HIGASHIUNOBECHO, IBARAKI, JP)
# 0DL: 15 KINUGAOKA, MOKA, JP
# --------------> geocode(15 KINUGAOKA, MOKA, JP)
# 0DM: 14-1 CHOFUMINATOMACHI, SHIMONOSEKI, JP
# --------------> geocode(14-1 CHOFUMINATOMACHI, SHIMONOSEKI, JP)
# 0EA: STOCKHOLMER ALLEE 30 A, DORTMUND, DE
# --------------> geocode(STOCKHOLMER ALLEE 30 A, DORTMUND, DE)
# 0EJ: CONCEJAL GARCIA FEO Nº 12, LAS PALMAS, GC, ES
# --------------> geocode(CONCEJAL GARCIA FEO Nº 12, LAS PALMAS, GC, ES)
# 0EL: 5-33-8 SHIBA MINATO-KU, TOKYO, JP
# --------------> geocode(5-33-8 SHIBA MINATO-KU, TOKYO, JP)
# 0EN: 4-15-1 SHIBAURA,, MINATO-KU, TOKYO, JP
# --------------> geocode(4-15-1 SHIBAURA,, MINATO-KU, TOKYO, JP)
# 0EO: PLOT NO. 44-A P.E.C.H.S. BLOCK 6 S, 5-6 FLOOR, NICE TRADE ORBIT BUILDING, KARACHI, PK
# --------------> geocode(PLOT NO. 44-A P.E.C.H.S. BLOCK 6 S, 5-6 FLOOR, NICE TRADE ORBIT BUILDING, KARACHI, PK)
# 0EP: 7 CHANGI BUSINESS PARK CENTRAL 1, SINGAPORE, SG
# --------------> geocode(7 CHANGI BUSINESS PARK CENTRAL 1, SINGAPORE, SG)
# 0FB: PYRAMIDS HEIGHTS OFFICE PARK - C09, ALEXANDRIA DESERT ROAD, KM 22 - PO BOX 166 EL-AHRAM GIZA, CAIRO, EG
# --------------> geocode(PYRAMIDS HEIGHTS OFFICE PARK - C09, ALEXANDRIA DESERT ROAD, KM 22 - PO BOX 166 EL-AHRAM GIZA, CAIRO, EG)
# 0FS: MARUTHI IND ESTATE - SHED NO 1,2&3, HOODY VILLAGE, WHITE FIELD RD, BANGALORE, KA, IN
# --------------> geocode(MARUTHI IND ESTATE - SHED NO 1,2&3, HOODY VILLAGE, WHITE FIELD RD, BANGALORE, KA, IN)
# 0GM: METROPOLITIAN TOWER, 68 ZOURONG LU, UNIT 10 & 11 OF 30/F, CHONGQING, 50, CN
# --------------> geocode(METROPOLITIAN TOWER, 68 ZOURONG LU, UNIT 10 & 11 OF 30/F, CHONGQING, 50, CN)
# 0HF: HAIFA UNIVERSITY, MOUNT CARMEL, HAIFA, HA, IL
# --------------> geocode(HAIFA UNIVERSITY, MOUNT CARMEL, HAIFA, HA, IL)
# 0HS: 2, SQUARE RENE CASSIN, RENNES, FR
# --------------> geocode(2, SQUARE RENE CASSIN, RENNES, FR)
# 0IB: SHEIKH ZAYED ROAD, DUBAI INTERNET CITY, BUILDING 5, DUBAI, AE
# --------------> geocode(SHEIKH ZAYED ROAD, DUBAI INTERNET CITY, BUILDING 5, DUBAI, AE)
# 0IO: SUBRAMANYA ARCADE, GRD-3RD FLRS, NO 12 BANNERGHATTA MAIN ROAD, BANGALORE, KA, IN
# --------------> geocode(SUBRAMANYA ARCADE, GRD-3RD FLRS, NO 12 BANNERGHATTA MAIN ROAD, BANGALORE, KA, IN)
# 0IP: 281 T T K ROAD, 2ND-4TH FLRS, CHENNAI, TN, IN
# --------------> geocode(281 T T K ROAD, 2ND-4TH FLRS, CHENNAI, TN, IN)
# 0IR: 16 CAMAC STREET, L&T CHAMBERS, 2ND FLR, KOLKATA, WB, IN
# --------------> geocode(16 CAMAC STREET, L&T CHAMBERS, 2ND FLR, KOLKATA, WB, IN)
# 0IV: THE IL&FS FINANCIAL CENTER, 4TH FLR, BANDRA KURLA COMPLEX, BANDRA (E), MUMBAI, MH, IN
# --------------> geocode(THE IL&FS FINANCIAL CENTER, 4TH FLR, BANDRA KURLA COMPLEX, BANDRA (E), MUMBAI, MH, IN)
# 0JB: C/ CANTON PEQUENO NO 13, LA CORUÑA, C, ES
# --------------> geocode(C/ CANTON PEQUENO NO 13, LA CORUÑA, C, ES)
# 0JS: PIAZZA BORGO PILA 38, CORTE LAMBRUSCHINI, GENOVA, GE, IT
# --------------> geocode(PIAZZA BORGO PILA 38, CORTE LAMBRUSCHINI, GENOVA, GE, IT)
# 125: 2-2 KITA 5 NISHI 6, CHUO-KU, SAPPORO, JP
# --------------> geocode(2-2 KITA 5 NISHI 6, CHUO-KU, SAPPORO, JP)
# 1AO: 227 - 11TH AVENUE SW, CALGARY, AB, CA
# --------------> geocode(227 - 11TH AVENUE SW, CALGARY, AB, CA)
# 1AU: 10044-108 ST NW, SUITE, EDMONTON, AB, CA
# --------------> geocode(10044-108 ST NW, SUITE, EDMONTON, AB, CA)
# 1MA: 2-1-10 SHIMONOPPORO TEKUNO PARK, AT, SAPPORO, JP
# --------------> geocode(2-1-10 SHIMONOPPORO TEKUNO PARK, AT, SAPPORO, JP)
# 238: 1-4-32 NAKATOURI, AKITA, JP
# --------------> geocode(1-4-32 NAKATOURI, AKITA, JP)
# 2AC: ONE RESEARCH DR, REGINA, SK, CA
# --------------> geocode(ONE RESEARCH DR, REGINA, SK, CA)
# 2AD: 1801 HAMILTON ST, REGINA, SK, CA
# --------------> geocode(1801 HAMILTON ST, REGINA, SK, CA)
# 2M8: 2-13-5 HASHIMOTO, AOMORI, JP
# --------------> geocode(2-13-5 HASHIMOTO, AOMORI, JP)
# 2P1: 15-20 MORIOKAEKIMAEDORI, MORIOKA, JP
# --------------> geocode(15-20 MORIOKAEKIMAEDORI, MORIOKA, JP)
# 341: 1-7-15 SOGAWA, TOYAMA, JP
# --------------> geocode(1-7-15 SOGAWA, TOYAMA, JP)
# 343: 2-1-18 HIGASHIODORI, CHUO-KU, NIIGATA, JP
# --------------> geocode(2-1-18 HIGASHIODORI, CHUO-KU, NIIGATA, JP)
# 344: 3-1-1 HIROOKA, KANAZAWA, JP
# --------------> geocode(3-1-1 HIROOKA, KANAZAWA, JP)
# 345: 2-7-15 OHTE, FUKUI, JP
# --------------> geocode(2-7-15 OHTE, FUKUI, JP)
# 3AE: 400 ELLICE AVE, WINNIPEG, MB, CA
# --------------> geocode(400 ELLICE AVE, WINNIPEG, MB, CA)
# 408: 1-12-1 DOUGENZAKA SHIBUYA-KU, 18FLR SHIBUYA MARK CITY BLDG, TOKYO, JP
# --------------> geocode(1-12-1 DOUGENZAKA SHIBUYA-KU, 18FLR SHIBUYA MARK CITY BLDG, TOKYO, JP)
# 423: 1-4-73 SANNOMARU, MITO, JP
# --------------> geocode(1-4-73 SANNOMARU, MITO, JP)
# 427: 4-7-11 ONOHARA, KAMISU, JP
# --------------> geocode(4-7-11 ONOHARA, KAMISU, JP)
# 4AI: 690 DALTON ST., KINGSTON, ON, CA
# --------------> geocode(690 DALTON ST., KINGSTON, ON, CA)
# 4AM: 3500 STEELES AVE EAST, MARKHAM, ON, CA
# --------------> geocode(3500 STEELES AVE EAST, MARKHAM, ON, CA)
# 4AN: 3600 STEELES AVE EAST, MARKHAM, ON, CA
# --------------> geocode(3600 STEELES AVE EAST, MARKHAM, ON, CA)
# 4AO: 4175 14TH AVENUE, MARKHAM, ON, CA
# --------------> geocode(4175 14TH AVENUE, MARKHAM, ON, CA)
# 4BY: 100 WYNFORD DR., 2ND FLOOR, TORONTO, ON, CA
# --------------> geocode(100 WYNFORD DR., 2ND FLOOR, TORONTO, ON, CA)
# 4CG: 151 FRONT STREET, SUITE 200, TORONTO, ON, CA
# --------------> geocode(151 FRONT STREET, SUITE 200, TORONTO, ON, CA)
# 4CH: 245 CONSUMERS RD, NORTH YORK, ON, CA
# --------------> geocode(245 CONSUMERS RD, NORTH YORK, ON, CA)
# 4CQ: 79 WELLINGTON ST. W., TORONTO, ON, CA
# --------------> geocode(79 WELLINGTON ST. W., TORONTO, ON, CA)
# 4EK: 120 BLOOR ST E, GROUND FLOOR, TORONTO, ON, CA
# --------------> geocode(120 BLOOR ST E, GROUND FLOOR, TORONTO, ON, CA)
# 4EM: 8200 WARDEN AVE, TORONTO LAB, MARKHAM, ON, CA
# --------------> geocode(8200 WARDEN AVE, TORONTO LAB, MARKHAM, ON, CA)
# 4EO: 100 GOUGH ROAD, MARKHAM, ON, CA
# --------------> geocode(100 GOUGH ROAD, MARKHAM, ON, CA)
# 4K2: 733 UEMATSUCHO, SHIMOGYO-KU, KYOTO, JP
# --------------> geocode(733 UEMATSUCHO, SHIMOGYO-KU, KYOTO, JP)
# 4MM: 2-6-1 NAKASE,, MIHAMA-KU, CHIBA, JP
# --------------> geocode(2-6-1 NAKASE,, MIHAMA-KU, CHIBA, JP)
# 4N2: 4-1-18 ODORI, UTSUNOMIYA, JP
# --------------> geocode(4-1-18 ODORI, UTSUNOMIYA, JP)
# 4N5: 1-11-3 SAKURAGICHO OHMIYA-KU, SAITAMA, JP
# --------------> geocode(1-11-3 SAKURAGICHO OHMIYA-KU, SAITAMA, JP)
# 4S6: 19-21 NIHONBASHI-HAKOZAKICHO, CHUO-KU, TOKYO, JP
# --------------> geocode(19-21 NIHONBASHI-HAKOZAKICHO, CHUO-KU, TOKYO, JP)
# 4S8: 1-1 NAKASE, MIHAMAKU, CHIBA, JP
# --------------> geocode(1-1 NAKASE, MIHAMAKU, CHIBA, JP)
# 4T3: 1-24-13 ASAHICHO, ATSUGI, JP
# --------------> geocode(1-24-13 ASAHICHO, ATSUGI, JP)
# 4T8: 1-204 TSUKUBA, KUMAGAYA, JP
# --------------> geocode(1-204 TSUKUBA, KUMAGAYA, JP)
# 4T9: 58-1 YASHIMACHO, TAKASAKI, JP
# --------------> geocode(58-1 YASHIMACHO, TAKASAKI, JP)
# 4W2: 1-6-1 TAKEZONO, TSUKUBA, JP
# --------------> geocode(1-6-1 TAKEZONO, TSUKUBA, JP)
# 4WR: 1-1 NIKKOCHO, TOKYO, JP
# --------------> geocode(1-1 NIKKOCHO, TOKYO, JP)
# 4WS: 1-15-2 OCHIAI, TAMA, JP
# --------------> geocode(1-15-2 OCHIAI, TAMA, JP)
# 4Z5: 14-23 WAKITAHONCHO, KAWAGOE, JP
# --------------> geocode(14-23 WAKITAHONCHO, KAWAGOE, JP)
# 502: 3001 HENDERSON DR, SUITE J, CHEYENNE, WY, US
# --------------> geocode(3001 HENDERSON DR, SUITE J, CHEYENNE, WY, US)
# 530: 1524-80 HIEKAWA, IZU, JP
# --------------> geocode(1524-80 HIEKAWA, IZU, JP)
# 535: 319-28 KAJIMACHI, NAKA-KU, HAMAMATSU, JP
# --------------> geocode(319-28 KAJIMACHI, NAKA-KU, HAMAMATSU, JP)
# 539: 3-1-1 NISHIKI NAKA-KU, NAGOYA, JP
# --------------> geocode(3-1-1 NISHIKI NAKA-KU, NAGOYA, JP)
# 542: 2-13-1 TOKIWACHO AOI-KU, SHIZUOKA, JP
# --------------> geocode(2-13-1 TOKIWACHO AOI-KU, SHIZUOKA, JP)
# 575: 4 ALLIANCE BOULEVARD, BARRIE, ON, CA
# --------------> geocode(4 ALLIANCE BOULEVARD, BARRIE, ON, CA)
# 5AA: 23 BOULEVARD DE L'AEROPORT, BROMONT, QC, CA
# --------------> geocode(23 BOULEVARD DE L'AEROPORT, BROMONT, QC, CA)
# 5AB: 200 BOUL BOUCHARD, ROOM 650A, DORVAL, QC, CA
# --------------> geocode(200 BOUL BOUCHARD, ROOM 650A, DORVAL, QC, CA)
# 5AF: 275 RUE VIGER EST, MONTREAL, QC, CA
# --------------> geocode(275 RUE VIGER EST, MONTREAL, QC, CA)
# 5AI: 2700 LAURIER BLVD., TOUR CHAMPLAIN, SAINTE-FOY, QC, CA
# --------------> geocode(2700 LAURIER BLVD., TOUR CHAMPLAIN, SAINTE-FOY, QC, CA)
# 5AP: 140 GRANDE ALLEE EAST, QUEBEC CITY, QC, CA
# --------------> geocode(140 GRANDE ALLEE EAST, QUEBEC CITY, QC, CA)
# 5N4: 1-2658-2 JONAN, SUWA, JP
# --------------> geocode(1-2658-2 JONAN, SUWA, JP)
# 5P8: 1-1 SUWASAKAEMACHI, YOKKAICHI, JP
# --------------> geocode(1-1 SUWASAKAEMACHI, YOKKAICHI, JP)
# 5U0: 2-5-2 FUKASHI, MATSUMOTO, JP
# --------------> geocode(2-5-2 FUKASHI, MATSUMOTO, JP)
# 5U5: 1-179 MIYUKIHONMACHI, TOYOTA, JP
# --------------> geocode(1-179 MIYUKIHONMACHI, TOYOTA, JP)
# 5V1: 1-1 SHIBAHONCHO, MISHIMA, JP
# --------------> geocode(1-1 SHIBAHONCHO, MISHIMA, JP)
# 5V4: 2-8 HASHIMOTOCHO, GIFU, JP
# --------------> geocode(2-8 HASHIMOTOCHO, GIFU, JP)
# 612: SECOND TERRACE & COLLINS AVENUE, NASSAU, BS
# --------------> geocode(SECOND TERRACE & COLLINS AVENUE, NASSAU, BS)
# 613: COLLYMORE ROCK, ST MICHAEL, BB
# --------------> geocode(COLLYMORE ROCK, ST MICHAEL, BB)
# 614: ANASASTRAAT 8, ORANJESTAD, AW
# --------------> geocode(ANASASTRAAT 8, ORANJESTAD, AW)
# 616: 52-56 KNUTSFORD BLVD, KINGSTON, JM
# --------------> geocode(52-56 KNUTSFORD BLVD, KINGSTON, JM)
# 617: VAN'T HOGERHUYSSTRAAT 9-11, PARAMARIBO, SR
# --------------> geocode(VAN'T HOGERHUYSSTRAAT 9-11, PARAMARIBO, SR)
# 618: 91-93 ST VINCENT STREET, FLOORS 1 AND 2, PORT-OF-SPAIN, TT
# --------------> geocode(91-93 ST VINCENT STREET, FLOORS 1 AND 2, PORT-OF-SPAIN, TT)
# 646: 1-7 KAKOGAWACHO KIMURA, KAKOGAWA, JP
# --------------> geocode(1-7 KAKOGAWACHO KIMURA, KAKOGAWA, JP)
# 648: 1-10-10 UTSUBOHONMACHI NISHI-KU, OSAKA, JP
# --------------> geocode(1-10-10 UTSUBOHONMACHI NISHI-KU, OSAKA, JP)
# 652: 7-1-1 ONOEDOURI CHUOH-KU, KOBE, JP
# --------------> geocode(7-1-1 ONOEDOURI CHUOH-KU, KOBE, JP)
# 654: 614 HIGASHISHIOKOJICHO, SHIMOGYO-KU, KYOTO, JP
# --------------> geocode(614 HIGASHISHIOKOJICHO, SHIMOGYO-KU, KYOTO, JP)
# 659: 1-6-27 NANKOKITA SUMINOE-KU, OSAKA, JP
# --------------> geocode(1-6-27 NANKOKITA SUMINOE-KU, OSAKA, JP)
# 6AH: 400 MAIN ST, SAINT JOHN, NB, CA
# --------------> geocode(400 MAIN ST, SAINT JOHN, NB, CA)
# 6U6: 1-1-5 SHINSENRI HIGASHIMACHI, TOYONAKA, JP
# --------------> geocode(1-1-5 SHINSENRI HIGASHIMACHI, TOYONAKA, JP)
# 71Y: 4 & 6 AVE GUTTEMBERG, BUSSY-SAINT-GEORGES, FR
# --------------> geocode(4 & 6 AVE GUTTEMBERG, BUSSY-SAINT-GEORGES, FR)
# 71Z: 137 BLVD VOLTAIRE, PARIS, FR
# --------------> geocode(137 BLVD VOLTAIRE, PARIS, FR)
# 72A: CHAUSSÉE DE LERY, VAL DE REUIL, FR
# --------------> geocode(CHAUSSÉE DE LERY, VAL DE REUIL, FR)
# 753: 240-5 DAIMONCHOTSUNOSHITA,, FUKUYAMA, JP
# --------------> geocode(240-5 DAIMONCHOTSUNOSHITA,, FUKUYAMA, JP)
# 754: 519-1 ISEMIYACHO, MATSUE, JP
# --------------> geocode(519-1 ISEMIYACHO, MATSUE, JP)
# 755: 1-1-3 SHIMOISHII, OKAYAMA, JP
# --------------> geocode(1-1-3 SHIMOISHII, OKAYAMA, JP)
# 760: 2-16 INARIMACHI, MINAMI-KU, HIROSHIMA, JP
# --------------> geocode(2-16 INARIMACHI, MINAMI-KU, HIROSHIMA, JP)
# 761: 1-10 YOYOGIDOURI TOKUYAMA, SHUNAN, JP
# --------------> geocode(1-10 YOYOGIDOURI TOKUYAMA, SHUNAN, JP)
# 7AB: 1969 UPPER WATER ST, 17TH FLR, PURDY'S WHARF, HALIFAX, NS, CA
# --------------> geocode(1969 UPPER WATER ST, 17TH FLR, PURDY'S WHARF, HALIFAX, NS, CA)
# 7V3: 2-201 MOTOUOMACHI, TOTTORI, JP
# --------------> geocode(2-201 MOTOUOMACHI, TOTTORI, JP)
# 871: 3-2-11 ICHIBANCHO, MATSUYAMA, JP
# --------------> geocode(3-2-11 ICHIBANCHO, MATSUYAMA, JP)
# 872: 2-26 SAKAIMACHI, KOCHI, JP
# --------------> geocode(2-26 SAKAIMACHI, KOCHI, JP)
# 8V6: 3-5-4 BANDAICHO, TOKUSHIMA, JP
# --------------> geocode(3-5-4 BANDAICHO, TOKUSHIMA, JP)
# 980: 3-26-29 HAKATAEKIMAE, HAKATA-KU, FUKUOKA, JP
# --------------> geocode(3-26-29 HAKATAEKIMAE, HAKATA-KU, FUKUOKA, JP)
# 981: 2-14-2 ASANO KOKURAKITA-KU, KITAKYUSHU, JP
# --------------> geocode(2-14-2 ASANO KOKURAKITA-KU, KITAKYUSHU, JP)
# 982: 2-21 KOZENMACHI, NAGASAKI, JP
# --------------> geocode(2-21 KOZENMACHI, NAGASAKI, JP)
# 984: 2-5-32 TAKACHIHODOURI, MIYAZAKI, JP
# --------------> geocode(2-5-32 TAKACHIHODOURI, MIYAZAKI, JP)
# 9WD: 2-27 MOMIJICHO, FUKUYAMA, JP
# --------------> geocode(2-27 MOMIJICHO, FUKUYAMA, JP)
# 9WX: 164 HAGADAI HAGAMACHI, HAGAGUN, JP
# --------------> geocode(164 HAGADAI HAGAMACHI, HAGAGUN, JP)
# 9ZG: 5-11-10 OZU, MINAMI-KU, HIROSHIMA, JP
# --------------> geocode(5-11-10 OZU, MINAMI-KU, HIROSHIMA, JP)
# 9ZH: 5-1-78 HIGASHIHARA, ZAMA, JP
# --------------> geocode(5-1-78 HIGASHIHARA, ZAMA, JP)
# 9ZJ: 4-9-15 OZU, MINAMI-KU, HIROSHIMA, JP
# --------------> geocode(4-9-15 OZU, MINAMI-KU, HIROSHIMA, JP)
# 9ZL: 3 HIKARI, KASHIMA, JP
# --------------> geocode(3 HIKARI, KASHIMA, JP)
# 9ZZ: 580 HORIKAWACHO, SAIWAI-KU, KAWASAKI, JP
# --------------> geocode(580 HORIKAWACHO, SAIWAI-KU, KAWASAKI, JP)
# A1P: 117 FARNBOROUGH ROAD, FARNBOROUGH, GB
# --------------> geocode(117 FARNBOROUGH ROAD, FARNBOROUGH, GB)
# A20: 521 S BOSTON, TULSA, OK, US
# --------------> geocode(521 S BOSTON, TULSA, OK, US)
# A2X: LOVSTADVEIEN 7, 2312 OTTESTAD, MAILDADRESS: 2325 HAMAR, HAMAR, NO
# --------------> geocode(LOVSTADVEIEN 7, 2312 OTTESTAD, MAILDADRESS: 2325 HAMAR, HAMAR, NO)
# A43: 8888 KEYSTONE CROSSING, SUITE 925, INDIANAPOLIS, IN, US
# --------------> geocode(8888 KEYSTONE CROSSING, SUITE 925, INDIANAPOLIS, IN, US)
# A49: 30 S 17TH ST, PHILADELPHIA, PA, US
# --------------> geocode(30 S 17TH ST, PHILADELPHIA, PA, US)
# A4U: 102 RUE DES BERGES DU LAC, TUNIS, TN
# --------------> geocode(102 RUE DES BERGES DU LAC, TUNIS, TN)
# A4W: 35, ALLEE DU CLOS DES CHARMES, LE POIRIER DE LA BUTTE, COLLEGIEN, FR
# --------------> geocode(35, ALLEE DU CLOS DES CHARMES, LE POIRIER DE LA BUTTE, COLLEGIEN, FR)
# A56: 8000 GRAINGER COURT, SPRINGFIELD, VA, US
# --------------> geocode(8000 GRAINGER COURT, SPRINGFIELD, VA, US)
# A5Y: 348 EDWARD STREET, BRISBANE, QLD, AU
# --------------> geocode(348 EDWARD STREET, BRISBANE, QLD, AU)
# A6S: CNR GEELONG RD & GEAR AVENUE, MT HELEN, BALLARAT, VIC, AU
# --------------> geocode(CNR GEELONG RD & GEAR AVENUE, MT HELEN, BALLARAT, VIC, AU)
# A6X: LAATZENER STR. 1, HANNOVER, DE
# --------------> geocode(LAATZENER STR. 1, HANNOVER, DE)
# A78: PLOT NO XI-7, KOLKATA, WB, IN
# --------------> geocode(PLOT NO XI-7, KOLKATA, WB, IN)
# A7X: CARL-BENZ RING 22, GAIMERSHEIM, DE
# --------------> geocode(CARL-BENZ RING 22, GAIMERSHEIM, DE)
# A94: GENERAAL LEMANSTRAAT 69, ANTWERP, BE
# --------------> geocode(GENERAAL LEMANSTRAAT 69, ANTWERP, BE)
# A9Q: 48 NAVAM MAWATHA, THAAKSHANA MANDIRAYA, COLOMBO, LK
# --------------> geocode(48 NAVAM MAWATHA, THAAKSHANA MANDIRAYA, COLOMBO, LK)
# A9V: 23, KASR EL NIL, CAIRO, EG
# --------------> geocode(23, KASR EL NIL, CAIRO, EG)
# AAG: IBM-ALLEE 1, EHNINGEN, DE
# --------------> geocode(IBM-ALLEE 1, EHNINGEN, DE)
# AAH: NEUMANN JANOS U.1, BUDAPEST, HU
# --------------> geocode(NEUMANN JANOS U.1, BUDAPEST, HU)
# AAM: ALTROTTSTR.31, WALLDORF, DE
# --------------> geocode(ALTROTTSTR.31, WALLDORF, DE)
# AAY: SITTARDER STRASSE 31, AACHEN, DE
# --------------> geocode(SITTARDER STRASSE 31, AACHEN, DE)
# ACT: PJE. ING. ENRIQUE BUTTY 275, CAPITAL FEDERAL, C, AR
# --------------> geocode(PJE. ING. ENRIQUE BUTTY 275, CAPITAL FEDERAL, C, AR)
# ADA: 180 GREENHILL ROAD, PARKSIDE, SA, AU
# --------------> geocode(180 GREENHILL ROAD, PARKSIDE, SA, AU)
# ADI: 4600 MCAULEY PLACE, SUITE 200, CINCINNATI, OH, US
# --------------> geocode(4600 MCAULEY PLACE, SUITE 200, CINCINNATI, OH, US)
# ADS: BEIM STROHHAUSE 17, HAMBURG, DE
# --------------> geocode(BEIM STROHHAUSE 17, HAMBURG, DE)
# ADT: 1000 BELLEVIEW ST, DALLAS, TX, US
# --------------> geocode(1000 BELLEVIEW ST, DALLAS, TX, US)
# AFO: 4499 FISHER RD, COLUMBUS, OH, US
# --------------> geocode(4499 FISHER RD, COLUMBUS, OH, US)
# AIR: 160 AIRPORT RD, WESCHESTER COUNTY AIRPORT, WHITE PLAINS, NY, US
# --------------> geocode(160 AIRPORT RD, WESCHESTER COUNTY AIRPORT, WHITE PLAINS, NY, US)
# ALA: 3500 BLUE LAKE DR, BIRMINGHAM, AL, US
# --------------> geocode(3500 BLUE LAKE DR, BIRMINGHAM, AL, US)
# ALX: 5, MAHMOUD ABDEL MOMEIM SHAKER, ST, ALEXANDRIA, EG
# --------------> geocode(5, MAHMOUD ABDEL MOMEIM SHAKER, ST, ALEXANDRIA, EG)
# AMA: PTE. HIPOLITO YRIGOYEN 2149, MARTINEZ / SAN ISIDRO, BUENOS AIRES, B, AR
# --------------> geocode(PTE. HIPOLITO YRIGOYEN 2149, MARTINEZ / SAN ISIDRO, BUENOS AIRES, B, AR)
# ANY: 80 STATE ST, 4TH FL, ALBANY, NY, US
# --------------> geocode(80 STATE ST, 4TH FL, ALBANY, NY, US)
# APM: 1000 REPUBLIC DR, SUITE 685, ALLEN PARK, MI, US
# --------------> geocode(1000 REPUBLIC DR, SUITE 685, ALLEN PARK, MI, US)
# ASK: MLYNSKE NIVY 49, APOLLO BC II, BLOCK H, BRATISLAVA, SK
# --------------> geocode(MLYNSKE NIVY 49, APOLLO BC II, BLOCK H, BRATISLAVA, SK)
# B6C: VIA SCIANGAI 53, ROMA, RM, IT
# --------------> geocode(VIA SCIANGAI 53, ROMA, RM, IT)
# BAC: 5100 CALIFORNIA AVE, BAKERSFIELD, CA, US
# --------------> geocode(5100 CALIFORNIA AVE, BAKERSFIELD, CA, US)
# BAW: RUA ENG. FRANCISCO DE PITTA BRITO 1, FLOOR SS, TE, 1, 4, & 5, SAO PAULO, SP, BR
# --------------> geocode(RUA ENG. FRANCISCO DE PITTA BRITO 1, FLOOR SS, TE, 1, 4, & 5, SAO PAULO, SP, BR)
# BBN: AL. ARAGUAIA 2044 - 9? ANDAR, CENTRO EMPRESARIAL ARAGUAIA, BARUERI, SP, BR
# --------------> geocode(AL. ARAGUAIA 2044 - 9? ANDAR, CENTRO EMPRESARIAL ARAGUAIA, BARUERI, SP, BR)
# BBS: SCN QUADRA 4, BLOCO B, N.100, SALA 601 E 701, BRASILIA, DF, BR
# --------------> geocode(SCN QUADRA 4, BLOCO B, N.100, SALA 601 E 701, BRASILIA, DF, BR)
# BBU: AV. DOLORES ALCARAZ CALDAS, 7, 10 &11 FLOORS, PORTO ALEGRE, RS, BR
# --------------> geocode(AV. DOLORES ALCARAZ CALDAS, 7, 10 &11 FLOORS, PORTO ALEGRE, RS, BR)
# BCD: RUA PLACIDO GOMES, BAIRRO ANITA GARIBALDI, JOINVILLE, SC, BR
# --------------> geocode(RUA PLACIDO GOMES, BAIRRO ANITA GARIBALDI, JOINVILLE, SC, BR)
# BCY: RUA MARIA LUIZA SANTIAGO 200, 3? E 5? ANDARES, BELO HORIZONTE, MG, BR
# --------------> geocode(RUA MARIA LUIZA SANTIAGO 200, 3? E 5? ANDARES, BELO HORIZONTE, MG, BR)
# BDF: 3 NEW SQUARE, BEDFONT LAKES, FELTHAM, GB
# --------------> geocode(3 NEW SQUARE, BEDFONT LAKES, FELTHAM, GB)
# BDO: AV. MINISTRO IVAN LINS, 300, 2O ANDAR, RIO DE JANEIRO, RJ, BR
# --------------> geocode(AV. MINISTRO IVAN LINS, 300, 2O ANDAR, RIO DE JANEIRO, RJ, BR)
# BDP: RUA EZEQUIEL RAMOS 3-33, 2 ANDAR - CENTRO BAURU, BAURU, SP, BR
# --------------> geocode(RUA EZEQUIEL RAMOS 3-33, 2 ANDAR - CENTRO BAURU, BAURU, SP, BR)
# BDQ: RUA GASPAR VIANA 324, ANDAR SUPERIOR, CAMPINA, BELEM, PA, BR
# --------------> geocode(RUA GASPAR VIANA 324, ANDAR SUPERIOR, CAMPINA, BELEM, PA, BR)
# BDT: RUA RIO DE JANEIRO, 328, 4 ANDAR - CENTRO, BELO HORIZONTE, MG, BR
# --------------> geocode(RUA RIO DE JANEIRO, 328, 4 ANDAR - CENTRO, BELO HORIZONTE, MG, BR)
# BDU: SCS QUADRA 2 ED. BRADESCO, BLOCO B-81, 2?. ANDAR, BRASILIA, DF, BR
# --------------> geocode(SCS QUADRA 2 ED. BRADESCO, BLOCO B-81, 2?. ANDAR, BRASILIA, DF, BR)
# BDV: AV. DR. MORAES SALES, 668, 4? ANDAR - CENTRO, CAMPINAS, SP, BR
# --------------> geocode(AV. DR. MORAES SALES, 668, 4? ANDAR - CENTRO, CAMPINAS, SP, BR)
# BDW: ESTRADA CAMPO LIMPO 4519, 1? ANDAR - PIRAJUSSARA, SAO PAULO, SP, BR
# --------------> geocode(ESTRADA CAMPO LIMPO 4519, 1? ANDAR - PIRAJUSSARA, SAO PAULO, SP, BR)
# BDX: RUA BARAO DE ITAPAGIPE 225, BLOCO D, T?RREO - R. COMPRIDO, RIO DE JANEIRO, RJ, BR
# --------------> geocode(RUA BARAO DE ITAPAGIPE 225, BLOCO D, T?RREO - R. COMPRIDO, RIO DE JANEIRO, RJ, BR)
# BDZ: AV. YARA S/N, CIDADE DE DEUS, PR?DIO AZUL - ANDAR INTERMED., OSASCO, SP, BR
# --------------> geocode(AV. YARA S/N, CIDADE DE DEUS, PR?DIO AZUL - ANDAR INTERMED., OSASCO, SP, BR)
# BEC: NAHMITZER DAMM 12, BERLIN, DE
# --------------> geocode(NAHMITZER DAMM 12, BERLIN, DE)
# BEG: AV. XV DE NOVEMBRO 772, 1? ANDAR - PORTO, CUIAB?, MT, BR
# --------------> geocode(AV. XV DE NOVEMBRO 772, 1? ANDAR - PORTO, CUIAB?, MT, BR)
# BEH: AV. PRESIDENTE AFFONSO CAMARGO 177, 2? ANDAR, JARDIM BOT?NICO, CURITIBA, PAR, BR
# --------------> geocode(AV. PRESIDENTE AFFONSO CAMARGO 177, 2? ANDAR, JARDIM BOT?NICO, CURITIBA, PAR, BR)
# BEI: RUA FULVIO ADUCCI 809, 1? ANDAR - CENTRO, FLORIANOPOLIS, SC, BR
# --------------> geocode(RUA FULVIO ADUCCI 809, 1? ANDAR - CENTRO, FLORIANOPOLIS, SC, BR)
# BEJ: RUA FLORIANO PEIXOTO 875, 2? ANDAR - CENTRO, FORTALEZA, CE, BR
# --------------> geocode(RUA FLORIANO PEIXOTO 875, 2? ANDAR - CENTRO, FORTALEZA, CE, BR)
# BEK: AV. GOIAS, 414, 3? ANDAR CENTRO, GOIANIA, GO, BR
# --------------> geocode(AV. GOIAS, 414, 3? ANDAR CENTRO, GOIANIA, GO, BR)
# BEM: AV. SETE DE SETEMBRO 1652/1698, 2? ANDAR - VILA GALV?O, GUARULHOS, SP, BR
# --------------> geocode(AV. SETE DE SETEMBRO 1652/1698, 2? ANDAR - VILA GALV?O, GUARULHOS, SP, BR)
# BEN: RUA 12 DE OUTUBRO 125, 4? ANDAR, SAO PAULO, SP, BR
# --------------> geocode(RUA 12 DE OUTUBRO 125, 4? ANDAR, SAO PAULO, SP, BR)
# BEO: RUA SILVA RAMOS, 368 - CENTRO, MANAUS, AM, BR
# --------------> geocode(RUA SILVA RAMOS, 368 - CENTRO, MANAUS, AM, BR)
# BEP: AV. GETULIO VARGAS 115, FUNDOS, 1? ANDAR - CENTRO, MARINGA, PAR, BR
# --------------> geocode(AV. GETULIO VARGAS 115, FUNDOS, 1? ANDAR - CENTRO, MARINGA, PAR, BR)
# BEQ: AV. ERNANI DO AMARAL PEIXOTO 211, 2 ANDAR - CENTRO, NITEROI, RJ, BR
# --------------> geocode(AV. ERNANI DO AMARAL PEIXOTO 211, 2 ANDAR - CENTRO, NITEROI, RJ, BR)
# BER: AV. RIO BRANCO 112, 1? E 2? ANDS - CAMPOS EL?SEOS, SAO PAULO, SP, BR
# --------------> geocode(AV. RIO BRANCO 112, 1? E 2? ANDS - CAMPOS EL?SEOS, SAO PAULO, SP, BR)
# BES: AV. NOSSA SRA. DA PENHA, 1255, SALAS 101 / 102, VIT?RIA, ES, BR
# --------------> geocode(AV. NOSSA SRA. DA PENHA, 1255, SALAS 101 / 102, VIT?RIA, ES, BR)
# BEU: AV. LINS DE VASCONCELOS 2362, 1 ANDAR, VILA MARIANA., SAO PAULO, SP, BR
# --------------> geocode(AV. LINS DE VASCONCELOS 2362, 1 ANDAR, VILA MARIANA., SAO PAULO, SP, BR)
# BEW: BRADESCO. RUA SAO CRISTOVAO 600, 2? E 3? ANDS - S?O CRISTOVAM, RIO DE JANEIRO, RJ, BR
# --------------> geocode(BRADESCO. RUA SAO CRISTOVAO 600, 2? E 3? ANDS - S?O CRISTOVAM, RIO DE JANEIRO, RJ, BR)
# BEX: AV DA FRANCA, 409 10 ANDAR, ED. ABELARDO PARENTE COM?RCIO, SALVADOR, BA, BR
# --------------> geocode(AV DA FRANCA, 409 10 ANDAR, ED. ABELARDO PARENTE COM?RCIO, SALVADOR, BA, BR)
# BEY: AV. DR. PEDRO LESSA, 847, 1? ANDAR, BAIRRO PONTA DA PRAIA, SANTOS, SP, BR
# --------------> geocode(AV. DR. PEDRO LESSA, 847, 1? ANDAR, BAIRRO PONTA DA PRAIA, SANTOS, SP, BR)
# BEZ: AV. DR. RUDGE RAMOS 155, 1?ANDAR - RUDGE RAMOS, SAO BERNARDO DO CAMPO, SP, BR
# --------------> geocode(AV. DR. RUDGE RAMOS 155, 1?ANDAR - RUDGE RAMOS, SAO BERNARDO DO CAMPO, SP, BR)
# BFA: AV. BENEDITO FRIGGI 3330, FUNDOS - BAIRRO VISTA VERDE, SAO JOSE DOS CAMPOS, SP, BR
# --------------> geocode(AV. BENEDITO FRIGGI 3330, FUNDOS - BAIRRO VISTA VERDE, SAO JOSE DOS CAMPOS, SP, BR)
# BFB: AV. FARRAPOS 3852, 1? ANDAR - NAVEGANTES, PORTO ALEGRE, RS, BR
# --------------> geocode(AV. FARRAPOS 3852, 1? ANDAR - NAVEGANTES, PORTO ALEGRE, RS, BR)
# BFC: R. DO MUNIZ, 162? 2? ANDAR, S?O JOS?, RECIFE, PE, BR
# --------------> geocode(R. DO MUNIZ, 162? 2? ANDAR, S?O JOS?, RECIFE, PE, BR)
# BFD: AV. SAUDADE 935, 2? ANDAR, CAMPOS EL?SIOS, RIBEIRAO PRETO, SP, BR
# --------------> geocode(AV. SAUDADE 935, 2? ANDAR, CAMPOS EL?SIOS, RIBEIRAO PRETO, SP, BR)
# BFE: R. GENERAL OS?RIO 124, 2? ANDAR - CENTRO, VIT?RIA, ES, BR
# --------------> geocode(R. GENERAL OS?RIO 124, 2? ANDAR - CENTRO, VIT?RIA, ES, BR)
# BFG: AVENIDA PRESIDENTE JUSCELINO KUBITS, SAO PAULO, SP, BR
# --------------> geocode(AVENIDA PRESIDENTE JUSCELINO KUBITS, SAO PAULO, SP, BR)
# BGN: RUA 6, N.370, 15 ANDAR, SALAS 1506/1507/1508, GOIANIA, GO, BR
# --------------> geocode(RUA 6, N.370, 15 ANDAR, SALAS 1506/1507/1508, GOIANIA, GO, BR)
# BHA: 3 BROOKHOLLOW AVENUE, NORWEST BUSINESS PARK, BAULKHAM HILLS, NSW, AU
# --------------> geocode(3 BROOKHOLLOW AVENUE, NORWEST BUSINESS PARK, BAULKHAM HILLS, NSW, AU)
# BLA: AV. NACOES UNIDAS 12901, 20? E 21? ANDARES - CENU, SAO PAULO, SP, BR
# --------------> geocode(AV. NACOES UNIDAS 12901, 20? E 21? ANDARES - CENU, SAO PAULO, SP, BR)
# BLI: AV. SANTOS DUMONT 1789 S.213, FORTALEZA, CE, BR
# --------------> geocode(AV. SANTOS DUMONT 1789 S.213, FORTALEZA, CE, BR)
# BLO: 1615 COMMERCE PKWY, BLOOMINGTON, IL, US
# --------------> geocode(1615 COMMERCE PKWY, BLOOMINGTON, IL, US)
# BLS: AVENUE DU BOURGET, 42, BRUSSELS, BE
# --------------> geocode(AVENUE DU BOURGET, 42, BRUSSELS, BE)
# BMA: AV. PASTEUR 146 & 138, RIO DE JANEIRO, RJ, BR
# --------------> geocode(AV. PASTEUR 146 & 138, RIO DE JANEIRO, RJ, BR)
# BME: 6710 ROCKLEDGE DR, BETHESDA, MD, US
# --------------> geocode(6710 ROCKLEDGE DR, BETHESDA, MD, US)
# BMM: RD J FCO AGUIRRE PROENCA KM 9, SP101. CHACARA ASSAY, HORTOLANDIA, SP, BR
# --------------> geocode(RD J FCO AGUIRRE PROENCA KM 9, SP101. CHACARA ASSAY, HORTOLANDIA, SP, BR)
# BMN: AVE. CONSTANTINO NERY 4165, SALA 104, MANAUS, AM, BR
# --------------> geocode(AVE. CONSTANTINO NERY 4165, SALA 104, MANAUS, AM, BR)
# BNT: 11501 BURNET RD, AUSTIN, TX, US
# --------------> geocode(11501 BURNET RD, AUSTIN, TX, US)
# BOA: SCHOENAICHER STR. 220, BOEBLINGEN, DE
# --------------> geocode(SCHOENAICHER STR. 220, BOEBLINGEN, DE)
# BOL: 6300 DIAGONAL HWY, BOULDER, CO, US
# --------------> geocode(6300 DIAGONAL HWY, BOULDER, CO, US)
# BPA: AV. GOVERNADOR JOSE MALCHER, BELEM, PA, BR
# --------------> geocode(AV. GOVERNADOR JOSE MALCHER, BELEM, PA, BR)
# BPR: AV. MARECHAL DEODORO, 10? ANDAR, CURITIBA, PR, BR
# --------------> geocode(AV. MARECHAL DEODORO, 10? ANDAR, CURITIBA, PR, BR)
# BSC: RUA ADOLFO MELO, SALAS 101 / 102, FLORIANOPOLIS, SC, BR
# --------------> geocode(RUA ADOLFO MELO, SALAS 101 / 102, FLORIANOPOLIS, SC, BR)
# BTU: RUA TUTOIA 1157, SAO PAULO, SP, BR
# --------------> geocode(RUA TUTOIA 1157, SAO PAULO, SP, BR)
# BVA: 2501 SE J ST, BENTONVILLE, AR, US
# --------------> geocode(2501 SE J ST, BENTONVILLE, AR, US)
# C0A: BORUPVANG 1, BALLERUP, DK
# --------------> geocode(BORUPVANG 1, BALLERUP, DK)
# C0Z: AV. TANCREDO NEVES 450, SALA 3201 AND 3202, SALVADOR, BA, BR
# --------------> geocode(AV. TANCREDO NEVES 450, SALA 3201 AND 3202, SALVADOR, BA, BR)
# C1C: AVE. LIBRAMIENTO APOD, STA ROSA 111, COL. FUTURO APODACA, MONTERREY, NLE, MX
# --------------> geocode(AVE. LIBRAMIENTO APOD, STA ROSA 111, COL. FUTURO APODACA, MONTERREY, NLE, MX)
# C1E: RUA CAIS DO APOLO, 14? ANDAR - RECIFE, RECIFE, PE, BR
# --------------> geocode(RUA CAIS DO APOLO, 14? ANDAR - RECIFE, RECIFE, PE, BR)
# C1F: 505 DOTA, KANI, JP
# --------------> geocode(505 DOTA, KANI, JP)
# C1G: 5-2-48 INOKUCHI, NISHI-KU, HIROSHIMA, JP
# --------------> geocode(5-2-48 INOKUCHI, NISHI-KU, HIROSHIMA, JP)
# C1L: J. HUIZINGALAAN 759, AMSTERDAM, NL
# --------------> geocode(J. HUIZINGALAAN 759, AMSTERDAM, NL)
# C1M: DAVID RICARDOSTRAAT 2-4, AMSTERDAM, NL
# --------------> geocode(DAVID RICARDOSTRAAT 2-4, AMSTERDAM, NL)
# C1N: TECHNICKA 23, BRNO, CZ
# --------------> geocode(TECHNICKA 23, BRNO, CZ)
# C1S: GROUND FLOOR OF SUB-STATION BUILDIN, 1 MINTO ROAD,DHAKA-1000BANGLADESH, DHAKA, BD
# --------------> geocode(GROUND FLOOR OF SUB-STATION BUILDIN, 1 MINTO ROAD,DHAKA-1000BANGLADESH, DHAKA, BD)
# C1U: WILHELM-FAY-STR. 30-34, FRANKFURT, DE
# --------------> geocode(WILHELM-FAY-STR. 30-34, FRANKFURT, DE)
# C1V: HOLLERITHSTR. 1, MÜNCHEN, DE
# --------------> geocode(HOLLERITHSTR. 1, MÜNCHEN, DE)
# C1Y: KE JI NAN YI LU, SHENZHEN HI-TECH IND PARK, LIMING BUILDING, NANSHAN DISTRICT, SHENZHEN, 44, CN
# --------------> geocode(KE JI NAN YI LU, SHENZHEN HI-TECH IND PARK, LIMING BUILDING, NANSHAN DISTRICT, SHENZHEN, 44, CN)
# C3B: THE ESTUARIES, CENTURY CITY, NO. 1 OXBOW CRESCENT, CAPE TOWN, ZA
# --------------> geocode(THE ESTUARIES, CENTURY CITY, NO. 1 OXBOW CRESCENT, CAPE TOWN, ZA)
# C3C: COMMONWEALTH AVENUE, BARANGAY UP DI, UP AYALA LAND TECHNO HUB, QUEZON CITY, 0, PH
# --------------> geocode(COMMONWEALTH AVENUE, BARANGAY UP DI, UP AYALA LAND TECHNO HUB, QUEZON CITY, 0, PH)
# C3G: ALL, VI
# --------------> geocode(ALL, VI)
# C3Q: 9 CHANGI BUSINESS PARK CENTRAL 1, SINGAPORE, SG
# --------------> geocode(9 CHANGI BUSINESS PARK CENTRAL 1, SINGAPORE, SG)
# C3R: KOEZTELEK U. 6, CITY GATE, BUDAPEST, HU
# --------------> geocode(KOEZTELEK U. 6, CITY GATE, BUDAPEST, HU)
# C3T: NO 7 SONG REN ROAD, 3/F & 4/F, CATHAY FINANCIAL CENTER, TAIPEI, TW
# --------------> geocode(NO 7 SONG REN ROAD, 3/F & 4/F, CATHAY FINANCIAL CENTER, TAIPEI, TW)
# C3V: 2 KE FA RD, GREAT WALL TECH BLDG,, NORTH AREA, SHENZHEN HI-TECH INDUSTRIAL PARK, NANSHAN DISTRICT,, SHENZHEN, 44, CN
# --------------> geocode(2 KE FA RD, GREAT WALL TECH BLDG,, NORTH AREA, SHENZHEN HI-TECH INDUSTRIAL PARK, NANSHAN DISTRICT,, SHENZHEN, 44, CN)
# C4H: 1 THE SQUARE, TEMPLE QUAY, BRISTOL, GB
# --------------> geocode(1 THE SQUARE, TEMPLE QUAY, BRISTOL, GB)
# C4I: 9 ALLEE ALAN TURING, PARC TECHNOLOGIQUE DE LA PARDIEU, AUBIERE, FR
# --------------> geocode(9 ALLEE ALAN TURING, PARC TECHNOLOGIQUE DE LA PARDIEU, AUBIERE, FR)
# C4J: RUE DE CHANTEMERLE, ZI DE LA COMBAUDE, CLERMONT-FERRAND, FR
# --------------> geocode(RUE DE CHANTEMERLE, ZI DE LA COMBAUDE, CLERMONT-FERRAND, FR)
# C4L: EXPLORER, INFORMATION TECHNOLOGY PK, 4TH & 5TH FLRS, WHITEFIELD, BANGALORE, KA, IN
# --------------> geocode(EXPLORER, INFORMATION TECHNOLOGY PK, 4TH & 5TH FLRS, WHITEFIELD, BANGALORE, KA, IN)
# C4N: OZONE - 3, SP INFOCITY, SASWAD RD, FURSUNGI VILLAGE, HADAPSAR, PUNE, MH, IN
# --------------> geocode(OZONE - 3, SP INFOCITY, SASWAD RD, FURSUNGI VILLAGE, HADAPSAR, PUNE, MH, IN)
# C4P: EMBASSY LINKS, EMBASSY CYPRESS PT, INDIRANAGAR-KORAMANGALA, INTERMEDIATE RING RD, BANGALORE, KA, IN
# --------------> geocode(EMBASSY LINKS, EMBASSY CYPRESS PT, INDIRANAGAR-KORAMANGALA, INTERMEDIATE RING RD, BANGALORE, KA, IN)
# C4S: 102 BOULEVARD DE LA WOLUWE, BRUSSELS, BE
# --------------> geocode(102 BOULEVARD DE LA WOLUWE, BRUSSELS, BE)
# C4U: KARLSROGATAN 2, SOLNA, SE
# --------------> geocode(KARLSROGATAN 2, SOLNA, SE)
# C5D: AVE. JOAQUIN ORRANTIA & JUAN TANCA, EXECUTIVE BUILDING, GUAYAQUIL, G, EC
# --------------> geocode(AVE. JOAQUIN ORRANTIA & JUAN TANCA, EXECUTIVE BUILDING, GUAYAQUIL, G, EC)
# C5N: VIA DARWIN,85, SETTIMO MILANESE, MI, IT
# --------------> geocode(VIA DARWIN,85, SETTIMO MILANESE, MI, IT)
# C5P: DLF SILOKHERA, VILLAGE SILOKHERA, NATIONALL HIGHWAY - 8, HARYANA, GURGAON, HR, IN
# --------------> geocode(DLF SILOKHERA, VILLAGE SILOKHERA, NATIONALL HIGHWAY - 8, HARYANA, GURGAON, HR, IN)
# C6G: SAMPSON HOUSE, 64 HOPTON STREET, LONDON, GB
# --------------> geocode(SAMPSON HOUSE, 64 HOPTON STREET, LONDON, GB)
# C6N: BUILDING 2, KELBURN COURT, DATEN PARK, BIRCHWOOD, WARRINGTON, GB
# --------------> geocode(BUILDING 2, KELBURN COURT, DATEN PARK, BIRCHWOOD, WARRINGTON, GB)
# C7C: 3-1-1 KARAKIDA, TAMA, JP
# --------------> geocode(3-1-1 KARAKIDA, TAMA, JP)
# C7D: 10 PLACE DE LA JOLIETTE, MARSEILLE, FR
# --------------> geocode(10 PLACE DE LA JOLIETTE, MARSEILLE, FR)
# C7E: 10 PRESNENSKAYA NABEREZHNAYA, MOSCOW, RU
# --------------> geocode(10 PRESNENSKAYA NABEREZHNAYA, MOSCOW, RU)
# C7J: NO 6 SZU WEI 3RD ROAD, 26/F, CATHAY SZU WEI FINANCIAL BLDG, KAOHSIUNG, TW
# --------------> geocode(NO 6 SZU WEI 3RD ROAD, 26/F, CATHAY SZU WEI FINANCIAL BLDG, KAOHSIUNG, TW)
# C7K: SHEFA TAL ST. GIVATAYIM, TEL AVIV, TA, IL
# --------------> geocode(SHEFA TAL ST. GIVATAYIM, TEL AVIV, TA, IL)
# C7P: ROAD NUMBER 1702, AL JASRAH TOWER BUILDING 95, 14TH FLOOR, OFFICE 1403, MANAMA, BH
# --------------> geocode(ROAD NUMBER 1702, AL JASRAH TOWER BUILDING 95, 14TH FLOOR, OFFICE 1403, MANAMA, BH)
# C7S: 1-2-13 SHINSENRI NISHIMACHI, TOYONAKA, JP
# --------------> geocode(1-2-13 SHINSENRI NISHIMACHI, TOYONAKA, JP)
# C7T: 1-1-25 SHINURASHIMACHO, KANAGAWA-KU, YOKOHAMA, JP
# --------------> geocode(1-1-25 SHINURASHIMACHO, KANAGAWA-KU, YOKOHAMA, JP)
# C7U: 7-2-14 TOYO, KOTO-KU, TOKYO, JP
# --------------> geocode(7-2-14 TOYO, KOTO-KU, TOKYO, JP)
# C7V: 8-18 AZUMA KAMI-CHOU, KASHIWA, JP
# --------------> geocode(8-18 AZUMA KAMI-CHOU, KASHIWA, JP)
# C7W: 3-4-1 MARUNOUCHI, CHIYODA-KU, TOKYO, JP
# --------------> geocode(3-4-1 MARUNOUCHI, CHIYODA-KU, TOKYO, JP)
# C7Y: 2-14-1 KUMOJI, NAHA, JP
# --------------> geocode(2-14-1 KUMOJI, NAHA, JP)
# C7Z: CIRCONVALLAZIONE IDROSCALO, SEGRATE, MI, IT
# --------------> geocode(CIRCONVALLAZIONE IDROSCALO, SEGRATE, MI, IT)
# C8A: 1-1 HONKOMORICHO, NARA, JP
# --------------> geocode(1-1 HONKOMORICHO, NARA, JP)
# C8O: 804-805 LEVEL 8, JL. PEMUDA 60-70, SURABAYA, JI, ID
# --------------> geocode(804-805 LEVEL 8, JL. PEMUDA 60-70, SURABAYA, JI, ID)
# C8R: NO. 8 NEW LINK RD, 5/F, MAGNUS TOWERS, MINDSPACE, MALAD (WEST), MUMBAI, MH, IN
# --------------> geocode(NO. 8 NEW LINK RD, 5/F, MAGNUS TOWERS, MINDSPACE, MALAD (WEST), MUMBAI, MH, IN)
# C8X: DEAKVARI FASOR 16-18, VAC, HU
# --------------> geocode(DEAKVARI FASOR 16-18, VAC, HU)
# C9G: 2-6-6 HAKATAEKIMAE, HAKATA-KU, FUKUOKA, JP
# --------------> geocode(2-6-6 HAKATAEKIMAE, HAKATA-KU, FUKUOKA, JP)
# C9H: 2-16-4,KOHNAN,MINATO-KU, TOKYO, JP
# --------------> geocode(2-16-4,KOHNAN,MINATO-KU, TOKYO, JP)
# C9L: 1-20-1 IWAMURADAKITA,, SAKU, JP
# --------------> geocode(1-20-1 IWAMURADAKITA,, SAKU, JP)
# C9Y: PRØVENSVEJ 1, BRØNDBY, DK
# --------------> geocode(PRØVENSVEJ 1, BRØNDBY, DK)
# CAM: VIA MAMELI 191, CAGLIARI, CA, IT
# --------------> geocode(VIA MAMELI 191, CAGLIARI, CA, IT)
# CB1: 1302 CONCOURSE DR, STE 110, LINTHICUM, MD, US
# --------------> geocode(1302 CONCOURSE DR, STE 110, LINTHICUM, MD, US)
# CBO: CARRERA 53 NUMERO 100-25, BOGOTA, CO
# --------------> geocode(CARRERA 53 NUMERO 100-25, BOGOTA, CO)
# CC5: 333 JOHN CARLYLE ST, SUITE 635, ALEXANDRIA, VA, US
# --------------> geocode(333 JOHN CARLYLE ST, SUITE 635, ALEXANDRIA, VA, US)
# CC6: 2101 EXECUTIVE DR, HAMPTON, VA, US
# --------------> geocode(2101 EXECUTIVE DR, HAMPTON, VA, US)
# CD1: 2500 TECHNOLOGY CIRCLE, SUITE 2, BENTONVILLE, AR, US
# --------------> geocode(2500 TECHNOLOGY CIRCLE, SUITE 2, BENTONVILLE, AR, US)
# CE2: 30501 AGOURA RD, SUITE 100, AGOURA HILLS, CA, US
# --------------> geocode(30501 AGOURA RD, SUITE 100, AGOURA HILLS, CA, US)
# CE5: 194 WOOD AVE, ISELIN, NJ, US
# --------------> geocode(194 WOOD AVE, ISELIN, NJ, US)
# CEF: 2070 ROUTE 52, HOPEWELL JUNCTION, NY, US
# --------------> geocode(2070 ROUTE 52, HOPEWELL JUNCTION, NY, US)
# CF0: 11511 LUNA ROAD, FARMERS BRANCH, TX, US
# --------------> geocode(11511 LUNA ROAD, FARMERS BRANCH, TX, US)
# CF3: 2300 15TH STREET, SUITE 400, DENVER, CO, US
# --------------> geocode(2300 15TH STREET, SUITE 400, DENVER, CO, US)
# CF5: 14001 NORTH DALLAS PARKWAY, SUITE M100, DALLAS, TX, US
# --------------> geocode(14001 NORTH DALLAS PARKWAY, SUITE M100, DALLAS, TX, US)
# CF6: 4040 LAFAYETTE CENTER DRIVE, CHANTILLY, VA, US
# --------------> geocode(4040 LAFAYETTE CENTER DRIVE, CHANTILLY, VA, US)
# CF8: 44060 DIGITAL LOUDOUN, ASHBURN, VA, US
# --------------> geocode(44060 DIGITAL LOUDOUN, ASHBURN, VA, US)
# CFA: 55 COONARA AVENUE, WEST PENNANT HILLS, NSW, AU
# --------------> geocode(55 COONARA AVENUE, WEST PENNANT HILLS, NSW, AU)
# CG2: 550 ASSEMBLY ST, COLUMBIA, SC, US
# --------------> geocode(550 ASSEMBLY ST, COLUMBIA, SC, US)
# CG6: 505 HOWARD ST, SUITE 600, 700, & 850, SAN FRANCISCO, CA, US
# --------------> geocode(505 HOWARD ST, SUITE 600, 700, & 850, SAN FRANCISCO, CA, US)
# CG9: 1100 SPACE PARK DRIVE, SANTA CLARA, CA, US
# --------------> geocode(1100 SPACE PARK DRIVE, SANTA CLARA, CA, US)
# CH0: 75 BINNEY ST, CAMBRIDGE, MA, US
# --------------> geocode(75 BINNEY ST, CAMBRIDGE, MA, US)
# CH1: 1500 NORTH 19TH STREET, MONROE, LA, US
# --------------> geocode(1500 NORTH 19TH STREET, MONROE, LA, US)
# CH3: 10140 MESA RIM RD, SAN DIEGO, CA, US
# --------------> geocode(10140 MESA RIM RD, SAN DIEGO, CA, US)
# CH4: 325 BILL FRANCE BLVD, DAYTONA BEACH, FL, US
# --------------> geocode(325 BILL FRANCE BLVD, DAYTONA BEACH, FL, US)
# CH5: 900 WALNUT RIDGE DRIVE, HARTLAND, WI, US
# --------------> geocode(900 WALNUT RIDGE DRIVE, HARTLAND, WI, US)
# CH8: 260 FRANKLIN ST, BOSTON, MA, US
# --------------> geocode(260 FRANKLIN ST, BOSTON, MA, US)
# CH9: 111 WEST JACKSON BLVD, SUITE 2120, CHICAGO, IL, US
# --------------> geocode(111 WEST JACKSON BLVD, SUITE 2120, CHICAGO, IL, US)
# CHE: RATHAUSSTR. 7, CHEMNITZ, DE
# --------------> geocode(RATHAUSSTR. 7, CHEMNITZ, DE)
# CHQ: 1 NEW ORCHARD RD, ARMONK, NY, US
# --------------> geocode(1 NEW ORCHARD RD, ARMONK, NY, US)
# CI0: 222 SOUTH RIVERSIDE PLAZA, SUITES 170 & 182, CHICAGO, IL, US
# --------------> geocode(222 SOUTH RIVERSIDE PLAZA, SUITES 170 & 182, CHICAGO, IL, US)
# CI6: 10 NORTH MARTINGALE RD, WOODFIELD PRESERVE, SCHAUMBURG, IL, US
# --------------> geocode(10 NORTH MARTINGALE RD, WOODFIELD PRESERVE, SCHAUMBURG, IL, US)
# CMA: ONE ROGERS ST, CAMBRIDGE, MA, US
# --------------> geocode(ONE ROGERS ST, CAMBRIDGE, MA, US)
# CMS: 600 ANTON BLVD, COSTA MESA, CA, US
# --------------> geocode(600 ANTON BLVD, COSTA MESA, CA, US)
# CNE: 300 EAST JIE FA, HUA TIAN HOTEL, RM 61007 & 61008 & 61008A, 10/F, VIP BLDG, HUNAN PROVINCE, CHANGSHA, 43, CN
# --------------> geocode(300 EAST JIE FA, HUA TIAN HOTEL, RM 61007 & 61008 & 61008A, 10/F, VIP BLDG, HUNAN PROVINCE, CHANGSHA, 43, CN)
# CNY: 1 NORTH CASTLE DR, ARMONK, NY, US
# --------------> geocode(1 NORTH CASTLE DR, ARMONK, NY, US)
# CZ9: 23 PARKWAY CIRCLE, UNIT, NEW CASTLE, DE, US
# --------------> geocode(23 PARKWAY CIRCLE, UNIT, NEW CASTLE, DE, US)
# CZA: THE PARK, V PARKU 2294/4, BUILDING 2/4, PRAHA, CZ
# --------------> geocode(THE PARK, V PARKU 2294/4, BUILDING 2/4, PRAHA, CZ)
# D0I: 2-60 HIGASHIHONMACHI, MATSUE, JP
# --------------> geocode(2-60 HIGASHIHONMACHI, MATSUE, JP)
# D0J: 2-29-2 AIOICHO, KARIYA, JP
# --------------> geocode(2-29-2 AIOICHO, KARIYA, JP)
# D0L: 3-1 KANAYAMACHO, NAKA-KU, HIROSHIMA, JP
# --------------> geocode(3-1 KANAYAMACHO, NAKA-KU, HIROSHIMA, JP)
# D0S: 5, RUE ROLAND GARROS, MINIPARC ALPES CONGRES, EYBENS, FR
# --------------> geocode(5, RUE ROLAND GARROS, MINIPARC ALPES CONGRES, EYBENS, FR)
# D0X: AMIR TIMUR STREET 107-B, TASHKENT, UZ
# --------------> geocode(AMIR TIMUR STREET 107-B, TASHKENT, UZ)
# D1A: SORTEMOSEVEJ 21, ALLEROD, DK
# --------------> geocode(SORTEMOSEVEJ 21, ALLEROD, DK)
# D1B: 19 ZHONGGUANCUN SOFTWARE PARK, 8 DONGBEIWANG WESTERN ROAD, HAIDIAN DISTRICT, BEIJING, 11, CN
# --------------> geocode(19 ZHONGGUANCUN SOFTWARE PARK, 8 DONGBEIWANG WESTERN ROAD, HAIDIAN DISTRICT, BEIJING, 11, CN)
# D1E: 25 BARAKHAMBHA ROAD, 1ST FLOOR, BIRLA TOWER, NEW DELHI, DL, IN
# --------------> geocode(25 BARAKHAMBHA ROAD, 1ST FLOOR, BIRLA TOWER, NEW DELHI, DL, IN)
# D1F: KASHI KUNJ ROAD NO. 2, CONTRACTOR'S AREA BISTUPUR, JAMSHEDPUR, JH, IN
# --------------> geocode(KASHI KUNJ ROAD NO. 2, CONTRACTOR'S AREA BISTUPUR, JAMSHEDPUR, JH, IN)
# D1N: AL.ARMII KRAJOWEJ 18, KRAKOW, PL
# --------------> geocode(AL.ARMII KRAJOWEJ 18, KRAKOW, PL)
# D1Q: 722 UPPER CHANGI ROAD EAST, SIA COMPUTER CENTRE BUILDING, SINGAPORE, SG
# --------------> geocode(722 UPPER CHANGI ROAD EAST, SIA COMPUTER CENTRE BUILDING, SINGAPORE, SG)
# D2E: HARRISON CLOSE, POWER HOUSE, KNOWLHILL, MILTON KEYNES, GB
# --------------> geocode(HARRISON CLOSE, POWER HOUSE, KNOWLHILL, MILTON KEYNES, GB)
# D2U: 3960 QUADRA STREET, QUADRA CENTRE, VICTORIA, BC, CA
# --------------> geocode(3960 QUADRA STREET, QUADRA CENTRE, VICTORIA, BC, CA)
# D2Z: SEESTRASSE 6, BREGENZ, AT
# --------------> geocode(SEESTRASSE 6, BREGENZ, AT)
# D3D: 1-13-12 SHINBASHI MINATO-KU, TSUTSUMI BLDG, TOKYO, JP
# --------------> geocode(1-13-12 SHINBASHI MINATO-KU, TSUTSUMI BLDG, TOKYO, JP)
# D3E: MINDSPACE, HI-TECH CITY, MADHAPUR, HYDERABAD, TS, IN
# --------------> geocode(MINDSPACE, HI-TECH CITY, MADHAPUR, HYDERABAD, TS, IN)
# D3F: VULKANSTR. 106, ZÜRICH, CH
# --------------> geocode(VULKANSTR. 106, ZÜRICH, CH)
# D3J: DLF IT PARK, PLOT NO. 08-MAR, 59.0 M ARTERIAL RD OF NEW TOWN (RAJARHAT), KOLKATA, WB, IN
# --------------> geocode(DLF IT PARK, PLOT NO. 08-MAR, 59.0 M ARTERIAL RD OF NEW TOWN (RAJARHAT), KOLKATA, WB, IN)
# D3W: BUCHAREST BUSINESS PARK, BUCURESTI-PLOIESTI NATIONAL ROAD 1A, BUILDING A2, BUCHAREST, RO
# --------------> geocode(BUCHAREST BUSINESS PARK, BUCURESTI-PLOIESTI NATIONAL ROAD 1A, BUILDING A2, BUCHAREST, RO)
# D3Y: TECH PARK ONE (PANCHSHILL), OFF AIRPORT ROAD, YERWADA, PUNE, MH, IN
# --------------> geocode(TECH PARK ONE (PANCHSHILL), OFF AIRPORT ROAD, YERWADA, PUNE, MH, IN)
# D3Z: 4396 WEST SAANICH RD, SUITE 200, VICTORIA, BC, CA
# --------------> geocode(4396 WEST SAANICH RD, SUITE 200, VICTORIA, BC, CA)
# D4C: 10 KAKI BUKIT AVENUE 1, KAKI BUKIT INDUSTRIAL ESTATE,, SINGAPORE, SG
# --------------> geocode(10 KAKI BUKIT AVENUE 1, KAKI BUKIT INDUSTRIAL ESTATE,, SINGAPORE, SG)
# D4E: 15-35 HONCHO, WAKO, JP
# --------------> geocode(15-35 HONCHO, WAKO, JP)
# D4H: 1-25-1 NISHISHINJUKU SHINJUKU-KU, TOKYO, JP
# --------------> geocode(1-25-1 NISHISHINJUKU SHINJUKU-KU, TOKYO, JP)
# D4I: 4-3-31 TOKAMACHI, YAMAGATA, JP
# --------------> geocode(4-3-31 TOKAMACHI, YAMAGATA, JP)
# D4N: MIRAMARSKA 23, EUROCENTER, ZAGREB, HR
# --------------> geocode(MIRAMARSKA 23, EUROCENTER, ZAGREB, HR)
# D4O: VIRCHOWSTR. 3, WILHELMSHAVEN, DE
# --------------> geocode(VIRCHOWSTR. 3, WILHELMSHAVEN, DE)
# D4R: ZAC DE CHARBONNIERE, 110, BOULEVARD DE LA SALLE, BOIGNY SUR BIONNE, FR
# --------------> geocode(ZAC DE CHARBONNIERE, 110, BOULEVARD DE LA SALLE, BOIGNY SUR BIONNE, FR)
# D4T: OUTER RING ROAD, EMBASSY MANYATHA B, RACHENAHALLI & NAGAWARA VILLAGES, BANGALORE, KA, IN
# --------------> geocode(OUTER RING ROAD, EMBASSY MANYATHA B, RACHENAHALLI & NAGAWARA VILLAGES, BANGALORE, KA, IN)
# D4U: DLF INFINITY TOWERS, PHASE II, DLF CITY, GURGAON, HR, IN
# --------------> geocode(DLF INFINITY TOWERS, PHASE II, DLF CITY, GURGAON, HR, IN)
# D4Y: 189 NANJING ROAD, HEPING DISTRICT UNIT 3401 EXCHANGE PLAZA, TIANJIN, 12, CN
# --------------> geocode(189 NANJING ROAD, HEPING DISTRICT UNIT 3401 EXCHANGE PLAZA, TIANJIN, 12, CN)
# D4Z: INVENTOR, INFORMATION TECHNOLOGY PK, WHITEFIELD, BANGALORE, KA, IN
# --------------> geocode(INVENTOR, INFORMATION TECHNOLOGY PK, WHITEFIELD, BANGALORE, KA, IN)
# D5A: VASTRA VARVSGATAN 19, (MAIL ADDRESS: BOX 4104, 20312 MALMÖ, MALMÖ, SE
# --------------> geocode(VASTRA VARVSGATAN 19, (MAIL ADDRESS: BOX 4104, 20312 MALMÖ, MALMÖ, SE)
# D5C: STRADA PRIVATA CASCIA 5, MILANO, MI, IT
# --------------> geocode(STRADA PRIVATA CASCIA 5, MILANO, MI, IT)
# D5Y: 8 FIRST AVENUE, PERSIARAN BANDAR UTAMA, PETALING JAYA, 10, MY
# --------------> geocode(8 FIRST AVENUE, PERSIARAN BANDAR UTAMA, PETALING JAYA, 10, MY)
# D6E: TECHNICKA 21, BRNO, CZ
# --------------> geocode(TECHNICKA 21, BRNO, CZ)
# D6J: 340 FINDON RD, KIDMAN PARK, SA, AU
# --------------> geocode(340 FINDON RD, KIDMAN PARK, SA, AU)
# D6K: 733 ANN STREET, FORTITUDE VALLEY, QLD, AU
# --------------> geocode(733 ANN STREET, FORTITUDE VALLEY, QLD, AU)
# D7L: TECHNICKA 19, BRNO, CZ
# --------------> geocode(TECHNICKA 19, BRNO, CZ)
# D8A: 9 RUE LINUS CARL PAULING - PARC DE, MONT SAINT AIGNAN, FR
# --------------> geocode(9 RUE LINUS CARL PAULING - PARC DE, MONT SAINT AIGNAN, FR)
# D8N: 58 ZHICHUNLU, CHINA AVIATION TECH BLDG, HAIDIAN, BEIJING, 11, CN
# --------------> geocode(58 ZHICHUNLU, CHINA AVIATION TECH BLDG, HAIDIAN, BEIJING, 11, CN)
# D8V: 568 JIANSHE AVE, UNIT 3803-3808, NEW WORLD INT'L TRADE CTR TOWER 1, WUHAN, 42, CN
# --------------> geocode(568 JIANSHE AVE, UNIT 3803-3808, NEW WORLD INT'L TRADE CTR TOWER 1, WUHAN, 42, CN)
# D8X: 340/1 AVENUE DE LA MARNE - PARC EUR, MARCQ-EN-BAROEUL, FR
# --------------> geocode(340/1 AVENUE DE LA MARNE - PARC EUR, MARCQ-EN-BAROEUL, FR)
# D9I: 4A VASILE MILEA BLVD, 6TH DISTRICT, BUCHAREST, RO
# --------------> geocode(4A VASILE MILEA BLVD, 6TH DISTRICT, BUCHAREST, RO)
# D9R: BIRCH POINT, UNIT W,, BIRCH INDUSTRIAL ESTATE, WHITTLE LANE, HEYWOOD, ROCHDALE, GB
# --------------> geocode(BIRCH POINT, UNIT W,, BIRCH INDUSTRIAL ESTATE, WHITTLE LANE, HEYWOOD, ROCHDALE, GB)
# D9S: MINERVA POINT, WORCESTER ROAD, STOURPORT ON SEVERN, GB
# --------------> geocode(MINERVA POINT, WORCESTER ROAD, STOURPORT ON SEVERN, GB)
# D9T: UNIT Z, SPRINGFIELD BUSINESS PARK, SHEEPSCOTES, CHELMSFORD, GB
# --------------> geocode(UNIT Z, SPRINGFIELD BUSINESS PARK, SHEEPSCOTES, CHELMSFORD, GB)
# D9X: BULEVAR MIHAJLA PUPINA NO. 6, BELGRADE, RS
# ...
# K2O: RUE HENRI M. SCHNADT 8, CLOCHE D'OR, LUXEMBOURG, LU
# --------------> geocode(RUE HENRI M. SCHNADT 8, CLOCHE D'OR, LUXEMBOURG, LU)
# K2P: 850 E COLLINS BLVD, RICHARDSON, TX, US
# --------------> geocode(850 E COLLINS BLVD, RICHARDSON, TX, US)
# K2Q: 77 KING STREET WEST, TORONTO, ON, CA
# --------------> geocode(77 KING STREET WEST, TORONTO, ON, CA)
# K2R: HURBANOVA 9A, BANSKA BYSTRICA, SK
# --------------> geocode(HURBANOVA 9A, BANSKA BYSTRICA, SK)
# K2V: 1-20 SAKURAMACHI, CHUO-KU, KUMAMOTO, JP
# --------------> geocode(1-20 SAKURAMACHI, CHUO-KU, KUMAMOTO, JP)
# K2W: AV. ANTEA 1088, EDIFICIO BUSINESS P, SAN FRANCISCO JURIQUILLA, QUERÉTARO, QUE, MX
# --------------> geocode(AV. ANTEA 1088, EDIFICIO BUSINESS P, SAN FRANCISCO JURIQUILLA, QUERÉTARO, QUE, MX)
# K2X: NO. 51&53, SEC. 2, GONGYI ROAD, UNI, TAICHUNG, TW
# --------------> geocode(NO. 51&53, SEC. 2, GONGYI ROAD, UNI, TAICHUNG, TW)
# K2Y: 15C ORHIDEELOR STREET, BUCHAREST, RO
# --------------> geocode(15C ORHIDEELOR STREET, BUCHAREST, RO)
# K2Z: STR. GARII NR. 21, CLUJ-NAPOCA, RO
# --------------> geocode(STR. GARII NR. 21, CLUJ-NAPOCA, RO)
# K3A: CENTRE D'AFFAIRES - LA CONCORDE, 24, RUE LAMARTINE, EYBENS, FR
# --------------> geocode(CENTRE D'AFFAIRES - LA CONCORDE, 24, RUE LAMARTINE, EYBENS, FR)
# K3D: CENTRE D'AFFAIRES - 7, RUE PIERRE S, REIMS, FR
# --------------> geocode(CENTRE D'AFFAIRES - 7, RUE PIERRE S, REIMS, FR)
# K3E: SUNDTKVARTALET, LAKKEGATA 53, OSLO, NO
# --------------> geocode(SUNDTKVARTALET, LAKKEGATA 53, OSLO, NO)
# K3F: KISTAGÅNGEN 6, KISTA, SE
# --------------> geocode(KISTAGÅNGEN 6, KISTA, SE)
# K3G: 484-19 ASAHIMACHI, MATSUE, JP
# --------------> geocode(484-19 ASAHIMACHI, MATSUE, JP)
# K3H: LEVEL 16, CHARLES DARWIN CENTRE, 19 SMITH STREET MALL, DARWIN, NT, AU
# --------------> geocode(LEVEL 16, CHARLES DARWIN CENTRE, 19 SMITH STREET MALL, DARWIN, NT, AU)
# K3J: VIA G. PERONI 282-296, ROMA, ROM, IT
# --------------> geocode(VIA G. PERONI 282-296, ROMA, ROM, IT)
# K3K: 3552 JALAN TEKNOKRAT 6, CYBERJAYA, 10, MY
# --------------> geocode(3552 JALAN TEKNOKRAT 6, CYBERJAYA, 10, MY)
# K3M: 111-2 ITAYAMACHI, NAKA-KU, HAMAMATSU, JP
# --------------> geocode(111-2 ITAYAMACHI, NAKA-KU, HAMAMATSU, JP)
# KDC: 1630 LONG POND RD, ROCHESTER, NY, US
# --------------> geocode(1630 LONG POND RD, ROCHESTER, NY, US)
# KGF: HANS-SACHS-STRASSE 16, KLAGENFURT, AT
# --------------> geocode(HANS-SACHS-STRASSE 16, KLAGENFURT, AT)
# KOL: GUSTAV-HEINEMANN-UFER 120, KÖLN, DE
# --------------> geocode(GUSTAV-HEINEMANN-UFER 120, KÖLN, DE)
# LEK: KOHLGARTENSTRASSE 11, LEIPZIG, DE
# --------------> geocode(KOHLGARTENSTRASSE 11, LEIPZIG, DE)
# LRB: 111 CENTER ST, LITTLE ROCK, AR, US
# --------------> geocode(111 CENTER ST, LITTLE ROCK, AR, US)
# LSB: RUA DO MAR DA CHINA, 3, PARQUE DAS NACOES EDIFICIO OFFICE ORIENTE, LISBOA, 11, PT
# --------------> geocode(RUA DO MAR DA CHINA, 3, PARQUE DAS NACOES EDIFICIO OFFICE ORIENTE, LISBOA, 11, PT)
# LUG: VIA BALESTRA 12, LUGANO, CH
# --------------> geocode(VIA BALESTRA 12, LUGANO, CH)
# LVL: 9780 ORMSBY STATION RD, SUITE 1400, LOUISVILLE, KY, US
# --------------> geocode(9780 ORMSBY STATION RD, SUITE 1400, LOUISVILLE, KY, US)
# MDC: 20 OLD POST RD, ARMONK, NY, US
# --------------> geocode(20 OLD POST RD, ARMONK, NY, US)
# MDM: 2125 RIDGEWOOD DR, SUITE 102, MIDLAND, MI, US
# --------------> geocode(2125 RIDGEWOOD DR, SUITE 102, MIDLAND, MI, US)
# MJH: JACKSON HOUSE, SIBSON ROAD, SALE, MANCHESTER, GB
# --------------> geocode(JACKSON HOUSE, SIBSON ROAD, SALE, MANCHESTER, GB)
# MLG: CALZADA LEGARIA NRO. 853. COLONIA I, MEXICO CITY, DIF, MX
# --------------> geocode(CALZADA LEGARIA NRO. 853. COLONIA I, MEXICO CITY, DIF, MX)
# MLN: 33 MAIDEN LANE, NEW YORK, NY, US
# --------------> geocode(33 MAIDEN LANE, NEW YORK, NY, US)
# MLV: 1 PLACE J.B CLEMENT, NOISY-LE-GRAND, FR
# --------------> geocode(1 PLACE J.B CLEMENT, NOISY-LE-GRAND, FR)
# MMM: GOTTLIEB-DAIMLER-STR. 12, MANNHEIM, DE
# --------------> geocode(GOTTLIEB-DAIMLER-STR. 12, MANNHEIM, DE)
# MOL: 1701 RIVER DR, MOLINE, IL, US
# --------------> geocode(1701 RIVER DR, MOLINE, IL, US)
# MOP: RUE DE LA VIEILLE POSTE, PARC IND.LA POMPIGNANE, MONTPELLIER CEDEX 01, FR
# --------------> geocode(RUE DE LA VIEILLE POSTE, PARC IND.LA POMPIGNANE, MONTPELLIER CEDEX 01, FR)
# MPG: 2200 CAMINO A EL CASTILLO, GUADALAJARA, JAL, MX
# --------------> geocode(2200 CAMINO A EL CASTILLO, GUADALAJARA, JAL, MX)
# MSF: ALFONSO NAPOLES GANDARA 3111, MEXICO CITY, DIF, MX
# --------------> geocode(ALFONSO NAPOLES GANDARA 3111, MEXICO CITY, DIF, MX)
# MUN: NEVINGHOFF 3, MÜNSTER, DE
# --------------> geocode(NEVINGHOFF 3, MÜNSTER, DE)
# NAD: VIA G.PORZIO 4, NAPOLI, NA, IT
# --------------> geocode(VIA G.PORZIO 4, NAPOLI, NA, IT)
# NCA: 21 AVENUE SIMONE VEIL, NICE MERIDIA, FR
# --------------> geocode(21 AVENUE SIMONE VEIL, NICE MERIDIA, FR)
# NCI: AV.PROF.DR.CAVACO SILVA-TAGUS PARK, PORTO SALVO, 11, PT
# --------------> geocode(AV.PROF.DR.CAVACO SILVA-TAGUS PARK, PORTO SALVO, 11, PT)
# NHA: 601 PACIFIC HIGHWAY, ST LEONARDS, NSW, AU
# --------------> geocode(601 PACIFIC HIGHWAY, ST LEONARDS, NSW, AU)
# NHB: WESTERN ROAD, NORTH HARBOUR, PORTSMOUTH, GB
# --------------> geocode(WESTERN ROAD, NORTH HARBOUR, PORTSMOUTH, GB)
# NIC: 42-44 GRIVA DIGHENI AV., NICOSIA, 1, CY
# --------------> geocode(42-44 GRIVA DIGHENI AV., NICOSIA, 1, CY)
# NMA: 36,RUE EUGENE PORCHERON, IMM.ROGER BERARD, NOUMEA, NC
# --------------> geocode(36,RUE EUGENE PORCHERON, IMM.ROGER BERARD, NOUMEA, NC)
# NOI: ROSENHOLMVEIEN 25, (MAIL ADDRESS: P.O BOX 500, 1411 KOLBOTN), TROLLASEN, NO
# --------------> geocode(ROSENHOLMVEIEN 25, (MAIL ADDRESS: P.O BOX 500, 1411 KOLBOTN), TROLLASEN, NO)
# NOS: MERCURIUSSTRAAT 27, NOSSEGEM, BE
# --------------> geocode(MERCURIUSSTRAAT 27, NOSSEGEM, BE)
# O65: 33, RUE DES VIEILLES VIGNES, CROISSY-BEAUBOURG, FR
# --------------> geocode(33, RUE DES VIEILLES VIGNES, CROISSY-BEAUBOURG, FR)
# OCP: ONE FINANCIAL PLAZA, HARTFORD, CT, US
# --------------> geocode(ONE FINANCIAL PLAZA, HARTFORD, CT, US)
# OCS: LAXENBURGERSTR. 252, WIEN, AT
# --------------> geocode(LAXENBURGERSTR. 252, WIEN, AT)
# ONP: 150 4TH AVE N, SUITE 450, ONE NASHVILLE PLACE, NASHVILLE, TN, US
# --------------> geocode(150 4TH AVE N, SUITE 450, ONE NASHVILLE PLACE, NASHVILLE, TN, US)
# OSA: HAVLICKOVO NABREZI 38, OSTRAVA, CZ
# --------------> geocode(HAVLICKOVO NABREZI 38, OSTRAVA, CZ)
# PAP: RUE FERDINAND FOREST, ZI.JARRY-HOUELBOURG, POINTE A PITRE, GP
# --------------> geocode(RUE FERDINAND FOREST, ZI.JARRY-HOUELBOURG, POINTE A PITRE, GP)
# PAS: VIA M.STABILE 160, PALERMO, PA, IT
# --------------> geocode(VIA M.STABILE 160, PALERMO, PA, IT)
# PDM: VIA MASINI 8, PADOVA, PD, IT
# --------------> geocode(VIA MASINI 8, PADOVA, PD, IT)
# PEA: 1060 HAY STREET, WEST PERTH, WA, AU
# --------------> geocode(1060 HAY STREET, WEST PERTH, WA, AU)
# PEI: 401 SW WATER ST SUITE 401, FOSTER & GALLAGHER BLDG, PEORIA, IL, US
# --------------> geocode(401 SW WATER ST SUITE 401, FOSTER & GALLAGHER BLDG, PEORIA, IL, US)
# PHB: 188 E. RODRIGUEZ JR. AVENUE, EASTWOOD CITY CYBERPARK, BAGUMBAYAN, QUEZON CITY, 0, PH
# --------------> geocode(188 E. RODRIGUEZ JR. AVENUE, EASTWOOD CITY CYBERPARK, BAGUMBAYAN, QUEZON CITY, 0, PH)
# PIC: 1551 S WASHINGTON AVE, PISCATAWAY, NJ, US
# --------------> geocode(1551 S WASHINGTON AVE, PISCATAWAY, NJ, US)
# PKS: 145 BOARDMAN RD, POUGHKEEPSIE, NY, US
# --------------> geocode(145 BOARDMAN RD, POUGHKEEPSIE, NY, US)
# PLA: 11400 BURNET RD, AUSTIN, TX, US
# --------------> geocode(11400 BURNET RD, AUSTIN, TX, US)
# PLB: 1000 RIVER ST, ESSEX JUNCTION, VT, US
# --------------> geocode(1000 RIVER ST, ESSEX JUNCTION, VT, US)
# PLE: IBM 1701 NORTH ST, ENDICOTT, NY, US
# --------------> geocode(IBM 1701 NORTH ST, ENDICOTT, NY, US)
# PLL: 745 WEST NEW CIRCLE RD, BUILDING 200 & BUILDING 202, LEXINGTON, KY, US
# --------------> geocode(745 WEST NEW CIRCLE RD, BUILDING 200 & BUILDING 202, LEXINGTON, KY, US)
# PLM: AV. PROLONGACION JAVIER PRADO ESTE, LA MOLINA, LIMA, LIM, PE
# --------------> geocode(AV. PROLONGACION JAVIER PRADO ESTE, LA MOLINA, LIMA, LIM, PE)
# PLP: 2455 SOUTH RD, POUGHKEEPSIE, NY, US
# --------------> geocode(2455 SOUTH RD, POUGHKEEPSIE, NY, US)
# PLR: 3605 HWY 52 N, ROCHESTER, MN, US
# --------------> geocode(3605 HWY 52 N, ROCHESTER, MN, US)
# PLT: 9000 S RITA RD, TUCSON, AZ, US
# --------------> geocode(9000 S RITA RD, TUCSON, AZ, US)
# PNO: 1515 POYDRAS ST, SUITE, NEW ORLEANS, LA, US
# --------------> geocode(1515 POYDRAS ST, SUITE, NEW ORLEANS, LA, US)
# PNY: 334 ROUTE 9W, PALISADES, NY, US
# --------------> geocode(334 ROUTE 9W, PALISADES, NY, US)
# POZ: ZIEBIECKA 35, POZNAN, PL
# --------------> geocode(ZIEBIECKA 35, POZNAN, PL)
# PPT: BOULEVARD POMARE, RESIDENCE PAOFAI, PAPEETE, PF
# --------------> geocode(BOULEVARD POMARE, RESIDENCE PAOFAI, PAPEETE, PF)
# PTK: RUA GONCALO SAMPAIO 157, PORTO, 13, PT
# --------------> geocode(RUA GONCALO SAMPAIO 157, PORTO, 13, PT)
# PTT: 11 STANWIX ST, FLOOR 9, PITTSBURGH, PA, US
# --------------> geocode(11 STANWIX ST, FLOOR 9, PITTSBURGH, PA, US)
# PUR: 654 MUNOZ RIVERA AVE, 8TH FL, STE 805, HATO REY, PR
# --------------> geocode(654 MUNOZ RIVERA AVE, 8TH FL, STE 805, HATO REY, PR)
# QIC: ROCADE DE ZEPHIR, CENTRE CIAL DE LA ROCADE, CAYENNE, GF
# --------------> geocode(ROCADE DE ZEPHIR, CENTRE CIAL DE LA ROCADE, CAYENNE, GF)
# RCX: PO BOX 218, 1101 KITCHAWAN RD, YORKTOWN HEIGHTS, NY, US
# --------------> geocode(PO BOX 218, 1101 KITCHAWAN RD, YORKTOWN HEIGHTS, NY, US)
# RDS: 201 W NORTH RIVER DR, SPOKANE, WA, US
# --------------> geocode(201 W NORTH RIVER DR, SPOKANE, WA, US)
# RET: 11107 SUNSET HILLS RD, RESTON, VA, US
# --------------> geocode(11107 SUNSET HILLS RD, RESTON, VA, US)
# RHT: 3222 40TH AVE NW, ROCHESTER, MN, US
# --------------> geocode(3222 40TH AVE NW, ROCHESTER, MN, US)
# RIC: 9201 ARBORETUM PKWY, SUITE 300, RICHMOND, VA, US
# --------------> geocode(9201 ARBORETUM PKWY, SUITE 300, RICHMOND, VA, US)
# RIG: BAUSKAS STR 58A, RIGA, LV
# --------------> geocode(BAUSKAS STR 58A, RIGA, LV)
# RLO: 8401 GREENSBORO DR, 1ST FL, MCLEAN, VA, US
# --------------> geocode(8401 GREENSBORO DR, 1ST FL, MCLEAN, VA, US)
# RML: VIA DEI LUCCHESI 26, ROMA, RM, IT
# --------------> geocode(VIA DEI LUCCHESI 26, ROMA, RM, IT)
# RMS: 95/97 BD DU GENERAL LECLERC, REIMS, FR
# --------------> geocode(95/97 BD DU GENERAL LECLERC, REIMS, FR)
# RPL: 3039 E CORNWALLIS RD, P.O. BOX 12195, RESEARCH TRIANGLE PARK, NC, US
# --------------> geocode(3039 E CORNWALLIS RD, P.O. BOX 12195, RESEARCH TRIANGLE PARK, NC, US)
# RSA: 590 MADISON AVE, NEW YORK, NY, US
# --------------> geocode(590 MADISON AVE, NEW YORK, NY, US)
# RV3: MUROOR STREET, BUILDING "C" ; 1ST FLOOR, ABU DHABI, AE
# --------------> geocode(MUROOR STREET, BUILDING "C" ; 1ST FLOOR, ABU DHABI, AE)
# SAN: 911 CENTRAL PKWY N, SUITE 100, SAN ANTONIO, TX, US
# --------------> geocode(911 CENTRAL PKWY N, SUITE 100, SAN ANTONIO, TX, US)
# SBK: 76 UPPER GROUND, LONDON, GB
# --------------> geocode(76 UPPER GROUND, LONDON, GB)
# SBR: 150 KETTLETOWN RD, SOUTHBURY, CT, US
# --------------> geocode(150 KETTLETOWN RD, SOUTHBURY, CT, US)
# SDN: 65 RUE STE MARIE, SAINT-DENIS DE LA REUNION, RE
# --------------> geocode(65 RUE STE MARIE, SAINT-DENIS DE LA REUNION, RE)
# SEA: 1200 5TH AVE, SEATTLE, WA, US
# --------------> geocode(1200 5TH AVE, SEATTLE, WA, US)
# SEC: LINDHOLMSALLEN 10, (MAIL ADDRESS:BOX 195, 40123 GÖTEBORG), GÖTEBORG, SE
# --------------> geocode(LINDHOLMSALLEN 10, (MAIL ADDRESS:BOX 195, 40123 GÖTEBORG), GÖTEBORG, SE)
# SEI: KISTA ALLÉVÄG 60, (MAIL ADDRESS: 16492 STOCKHOLM), KISTA, SE
# --------------> geocode(KISTA ALLÉVÄG 60, (MAIL ADDRESS: 16492 STOCKHOLM), KISTA, SE)
# SEK: STORGATAN 44, (MAIL ADDRESS: 85173 SUNDSVALL), SUNDSVALL, SE
# --------------> geocode(STORGATAN 44, (MAIL ADDRESS: 85173 SUNDSVALL), SUNDSVALL, SE)
# SFC: 425 MARKET ST, SAN FRANCISCO, CA, US
# --------------> geocode(425 MARKET ST, SAN FRANCISCO, CA, US)
# SGA: W TOWER, 60 CITY RD, SOUTHGATE, MELBOURNE, VIC, AU
# --------------> geocode(W TOWER, 60 CITY RD, SOUTHGATE, MELBOURNE, VIC, AU)
# SHC: 389 GANG AO ROAD, WAI GAO QIAO FREE TRADE ZONE, SHANGHAI, 31, CN
# --------------> geocode(389 GANG AO ROAD, WAI GAO QIAO FREE TRADE ZONE, SHANGHAI, 31, CN)
# SHE: ISTC/ITPC/CPC, GREAT WALL COMPUTER, SCIENCE & INDUSTRY PARK, NANSHAN DIST, SHENZHEN, 44, CN
# --------------> geocode(ISTC/ITPC/CPC, GREAT WALL COMPUTER, SCIENCE & INDUSTRY PARK, NANSHAN DIST, SHENZHEN, 44, CN)
# SIO: 4916 TECHNOPOLIS DR, BUILDING, SIOUX FALLS, SD, US
# --------------> geocode(4916 TECHNOPOLIS DR, BUILDING, SIOUX FALLS, SD, US)
# SJH: 650 HARRY ROAD, ALMADEN RESEARCH CENTER, SAN JOSE, CA, US
# --------------> geocode(650 HARRY ROAD, ALMADEN RESEARCH CENTER, SAN JOSE, CA, US)
# SJS: 555 BAILEY AVE, SAN JOSE, CA, US
# --------------> geocode(555 BAILEY AVE, SAN JOSE, CA, US)
# SLM: 325 JAMES S MCDONNELL BLVD, HAZELWOOD, MO, US
# --------------> geocode(325 JAMES S MCDONNELL BLVD, HAZELWOOD, MO, US)
# SMB: 4205 S MIAMI BLVD, DURHAM, NC, US
# --------------> geocode(4205 S MIAMI BLVD, DURHAM, NC, US)
# SMT: 2710 S GATEWAY OAKS DR, SUITE 200, SACRAMENTO, CA, US
# --------------> geocode(2710 S GATEWAY OAKS DR, SUITE 200, SACRAMENTO, CA, US)
# SOB: 36, DRAGAN TZANKOV BLVD, INTERPRED WORLD TRADE CENTER, SOFIA, BG
# --------------> geocode(36, DRAGAN TZANKOV BLVD, INTERPRED WORLD TRADE CENTER, SOFIA, BG)
# SPM: 3315 E RIDGEVIEW, SPRINGFIELD, MO, US
# --------------> geocode(3315 E RIDGEVIEW, SPRINGFIELD, MO, US)
# SRN: 4000 EXECUTIVE PKWY, SAN RAMON, CA, US
# --------------> geocode(4000 EXECUTIVE PKWY, SAN RAMON, CA, US)
# STR: 48 RUE DU FAUBOURG DE SAVERNE, IMMEUBLE L'AVANCE, STRASBOURG, FR
# --------------> geocode(48 RUE DU FAUBOURG DE SAVERNE, IMMEUBLE L'AVANCE, STRASBOURG, FR)
# SUF: P.O. BOX 700, 299-300 LONG MEADOW RD, STERLING FOREST, NY, US
# --------------> geocode(P.O. BOX 700, 299-300 LONG MEADOW RD, STERLING FOREST, NY, US)
# SUM: 1650 SUMMIT LAKE DR, TALLAHASSEE, FL, US
# --------------> geocode(1650 SUMMIT LAKE DR, TALLAHASSEE, FL, US)
# SW5: 486 SIN-DONG, YOUNGTONG-GU, 3F, DIGITAL EMPIRE2 BUILDING, SUWON, 41, KR
# --------------> geocode(486 SIN-DONG, YOUNGTONG-GU, 3F, DIGITAL EMPIRE2 BUILDING, SUWON, 41, KR)
# TAA: 3031 N ROCKY POINT DR WEST, SUITE 500, TAMPA, FL, US
# --------------> geocode(3031 N ROCKY POINT DR WEST, SUITE 500, TAMPA, FL, US)
# TAL: TOOMPUIESTEE 33A, TALLIN, EE
# --------------> geocode(TOOMPUIESTEE 33A, TALLIN, EE)
# THA: SP BLDG, 388 PHAHOLYOTHIN ROAD, PHAYATHAI, BANGKOK, 10, TH
# --------------> geocode(SP BLDG, 388 PHAHOLYOTHIN ROAD, PHAYATHAI, BANGKOK, 10, TH)
# TKA: 618 S KANSAS AVE, TOPEKA, KS, US
# --------------> geocode(618 S KANSAS AVE, TOPEKA, KS, US)
# TRF: BUYUKDERE CADDESI LEVENT, ISTANBUL, 34, TR
# --------------> geocode(BUYUKDERE CADDESI LEVENT, ISTANBUL, 34, TR)
# TTT: 6,RUE BRINDEJONC-DES-MOULINAIS, TOULOUSE, FR
# --------------> geocode(6,RUE BRINDEJONC-DES-MOULINAIS, TOULOUSE, FR)
# ULS: SYRLINSTRASSE 38, ULM, DE
# --------------> geocode(SYRLINSTRASSE 38, ULM, DE)
# UPL: PLAZA INDEPENDENCIA 721, MONTEVIDEO, MO, UY
# --------------> geocode(PLAZA INDEPENDENCIA 721, MONTEVIDEO, MO, UY)
# UX5: VIA DEL CARROCCIO 6, PERO, MI, IT
# --------------> geocode(VIA DEL CARROCCIO 6, PERO, MI, IT)
# VCH: AV. ERNESTO BLOHM, EDIFICIO IBM, CHUAO, CARACAS, M, VE
# --------------> geocode(AV. ERNESTO BLOHM, EDIFICIO IBM, CHUAO, CARACAS, M, VE)
# VIL: SEIMYNISKIU STR 3, VILNIUS, LT
# --------------> geocode(SEIMYNISKIU STR 3, VILNIUS, LT)
# W97: 59 RUE DE LA REPUBLIQUE, VALMY, MONTREUIL-SOUS-BOIS, FR
# --------------> geocode(59 RUE DE LA REPUBLIQUE, VALMY, MONTREUIL-SOUS-BOIS, FR)
# WI3: PAULSTRASSE 12, WINTERTHUR, CH
# --------------> geocode(PAULSTRASSE 12, WINTERTHUR, CH)
# WNM: 18000 W 9 MILE RD, SOUTHFIELD, MI, US
# --------------> geocode(18000 W 9 MILE RD, SOUTHFIELD, MI, US)
# WWK: BIRMINGHAM ROAD, WARWICK, GB
# --------------> geocode(BIRMINGHAM ROAD, WARWICK, GB)
# Z1A: PARK AZORIM 94 EM HAMOSHAVOT ROAD, KYRIAT ARIE - PETACH TIKVA, PETACH TIKVA, M, IL
# --------------> geocode(PARK AZORIM 94 EM HAMOSHAVOT ROAD, KYRIAT ARIE - PETACH TIKVA, PETACH TIKVA, M, IL)
# Z1J: L11 & L7 SEABANK, 12-14 MARINE PARADE, SOUTHPORT, QLD, AU
# --------------> geocode(L11 & L7 SEABANK, 12-14 MARINE PARADE, SOUTHPORT, QLD, AU)
# Z3O: NAN KANG (SOFTWARE PARK), E9W&E/E10W,, TAIPEI, TW
# --------------> geocode(NAN KANG (SOFTWARE PARK), E9W&E/E10W,, TAIPEI, TW)
# ZRL: SAEUMERSTRASSE 4, RUESCHLIKON, CH
# --------------> geocode(SAEUMERSTRASSE 4, RUESCHLIKON, CH)
# ... done

# %%
print('running ...')
   
# store IBM location data in a CSV file
columns = ['geoname_id','country_iso_code','country_name','subdivision_1_iso_code','subdivision_1_name','city_name']
pd.DataFrame(ibmLocations).to_csv('test.ibmLocations.csv', index=False, float_format='%.9g', columns=columns)

# store IBM network data in a CSV file
columns = ['network','geoname_id','latitude','longitude','postal_code']
pd.DataFrame(ibmNetworksIPv4).to_csv('test.ibmNetworksIPv4.csv', index=False, float_format='%.9g', columns=columns)
pd.DataFrame(ibmNetworksIPv6).to_csv('test.ibmNetworksIPv6.csv', index=False, float_format='%.9g', columns=columns)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# Run the next cell to download Internet network and location data from MaxMind:

# %%
print('running ...')

with urlopen(maxmindGeoLite2URL) as response:
    with zipfile.ZipFile(BytesIO(response.read())) as file:
        file.extractall()

# find the newest directory, in case there are old directories left over from previous runs
maxmindDirectory = sorted( [ f for f in os.listdir() if os.path.isdir(f) and f.startswith('GeoLite2-City-CSV') ] )[-1]

# load the MaxMind network and location data 
maxmindNetworksIPv4 = pd.read_csv(maxmindDirectory + '/GeoLite2-City-Blocks-IPv4.csv', header=0, dtype=str)
maxmindNetworksIPv6 = pd.read_csv(maxmindDirectory + '/GeoLite2-City-Blocks-IPv6.csv', header=0, dtype=str)
maxmindLocations = pd.read_csv(maxmindDirectory + '/GeoLite2-City-Locations-en.csv', header=0, dtype=str)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# Run the next cell to merge the MaxMind and IBM data. The merged data will be written into CSV files in the 'merged' directory, using the filenames of the original MaxMind CSV files.

# %%
print('running ...')

# create a directory for the merged MaxMind+IBM CSV files
os.makedirs('merged', exist_ok=True)

# merge the MaxMind and IBM network data and store the result in CSV files

maxmindNetworksIPv4 = maxmindNetworksIPv4[ ~ maxmindNetworksIPv4['network'].str.startswith('9.') ]
mergedNetworksIPv4 = maxmindNetworksIPv4.append(ibmNetworksIPv4)
mergedNetworksIPv4.to_csv('merged/GeoLite2-City-Blocks-IPv4.csv', index=False, float_format='%.9g', columns=maxmindNetworksIPv4.columns)

maxmindNetworksIPv6 = maxmindNetworksIPv6[ ~ maxmindNetworksIPv6['network'].str.startswith('2620:1F7:') ]
maxmindNetworksIPv6 = maxmindNetworksIPv6[ ~ maxmindNetworksIPv6['network'].str.startswith('2620:1f7:') ]
mergedNetworksIPv6 = maxmindNetworksIPv6.append(ibmNetworksIPv6)
mergedNetworksIPv6.to_csv('merged/GeoLite2-City-Blocks-IPv6.csv', index=False, float_format='%.9g', columns=maxmindNetworksIPv6.columns)

# merge the MaxMind and IBM location data and store the result in a CSV file
mergedLocations = maxmindLocations.append(ibmLocations)
mergedLocations.to_csv('merged/GeoLite2-City-Locations-en.csv', index=False, float_format='%.9g', columns=maxmindLocations.columns)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# Run the next cell to calculate [geohash codes](https://en.wikipedia.org/wiki/Geohash) for the latitude/longitude coordinates of merged MaxMind and IBM locations. The geohashes, coordinates, and location data will be written into a CSV file in the 'merged' directory named 'GeoLite2-City-Geohashes-en.csv'.

# %%
# %%script false
#
# print('running ...')
#
# # create a frame of locations indexed by ID number
# mergedLocationsIndexed = mergedLocations.set_index('geoname_id')
#
# # create a frame of geographical coordinates, that is, ID number, latitude, and longitude
# mergedCoordinates = mergedNetworks[['geoname_id','latitude','longitude']].drop_duplicates()
#
# # merge location and coordinate data and calculate geohash for each location's coordinates
# mergedGeohashes = mergedCoordinates.join(mergedLocationsIndexed, on='geoname_id')
# mergedGeohashes['geohash'] = mergedGeohashes.apply(lambda row: geohash2.encode(row['latitude'],row['longitude'],precision=6),axis=1)
#
# # store the result in a CSV file
# columns = ['geohash','latitude','longitude','geoname_id','country_iso_code','country_name','subdivision_1_iso_code','subdivision_1_name','subdivision_2_iso_code','subdivision_2_name','city_name']
# mergedGeohashes.to_csv('merged/GeoLite2-City-Geohashes-en.csv', index=False, float_format='%.9g', columns=columns)
#
# print('... done')

# %% [markdown]
# -----
# Run the next cell to pack the merged CSV files in the 'merged' directory into a ZIP file for export to systems running IBM Streams applications with the IPAddressLocation operator:

# %%
print('running ...')

# pack all result files into a ZIP package
with zipfile.ZipFile(mergedPackageFilename, 'w', compression=zipfile.ZIP_DEFLATED) as zipFile:
    for file in os.listdir('merged'):
        zipFile.write('merged/'+file, file)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# Run the next cell to upload the ZIP package containing the merged CSV files from DSX to IBM Cloud Object Storage:

# %%
# %%script false
#
# # credentials for bucket in IBM Cloud Object Store
# credentials = {
#     'IBM_API_KEY_ID': 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx',
#     'IAM_SERVICE_ID': 'iam-ServiceId-xxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxxxxxx',
#     'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
#     'IBM_AUTH_ENDPOINT': 'https://iam.ng.bluemix.net/oidc/token',
#     'BUCKET': 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx',
#     'FILE': 'report_IGA_Global_Q1_2016.xlsx'
# }
#
# # create a Cloud Object Store HTTP client with the bucket's credentials
# cosClient = ibm_boto3.client(service_name='s3',
#     ibm_api_key_id=credentials['IBM_API_KEY_ID'],
#     ibm_service_instance_id=credentials['IAM_SERVICE_ID'],
#     ibm_auth_endpoint=credentials['IBM_AUTH_ENDPOINT'],
#     config=Config(signature_version='oauth'),
#     endpoint_url=credentials['ENDPOINT'])
#
# # write the ZIP file to the notebook's bucket in Cloud Object Storage
# cosClient.upload_file(Filename=mergedPackageFilename, Bucket=credentials['BUCKET'], Key=mergedPackageFilename)

# %% [markdown]
# -----
# To download the ZIP package containing the merged CSV files from DSX to your laptop, do this:
#
# * In a browser, go to this notebook's project page
#
# * open the 'Files' panel by clicking the 'Find and Add Data' icon in the upper-right corner of the project page,
#
# * check the box next to 'mergedIBMandMaxmindData.zip'
#
# * select 'Download' from the pop-up menu in the 'Files' panel

# %% [markdown]
# \/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/
