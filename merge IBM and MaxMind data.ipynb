# %% [markdown]
# ## merge IBM and MaxMind network and location data
#
# -----
#
# The code in this notebook merges Internet and IBM network and location data for use in IBM Streaming Analytics, such as the NetflowViewer demonstration and cyber-security applications:
#
# * Data for the Internet comes from CSV files provided by [MaxMind, Inc.](https://www.maxmind.com/en/home) as [GeoLite2 data](https://dev.maxmind.com/geoip/geoip2/geolite2/). This notebook downloads MaxMind's 'GeoLite2' data that lists subnets and their locations in the Internet, including country, state/province/territory, city, latitude, and longitude.
#
# * Data for the IBM internal network comes from a ['whois' service](http://whois.ibm.com) provided by AT&T. This notebook downloads 'whois' data that lists subnets and their locations in the IBM internal network, including country, state, city, and street address. This data is mapped to longitude and latitude with the Google Maps geocoding service.
#
# The Google Maps geocoding service requires an API key for a Google account. To create a key, do this:
#
# * In a browser, go to [Google](https://www.google.com/) and sign into an existing account or create a new account.
#
# * Go to the [Google Geocoding Service](https://developers.google.com/maps/documentation/javascript/geocoding) page and follow the instructions to create a project and enable the geocoding API.
#
# * Go to [Google Geocoding Service 'Get API Key'](https://developers.google.com/maps/documentation/geocoding/get-api-key), click on 'Get a Key', and then click the 'copy' button.
#
# * paste the copied key into the cell below as the value of the 'googlemapsKey' constant
#
# Google limits usage of their geocoding service to 2,500 requests per day, which is sufficient for two complete runs per day. The responses are cached and reused to avoid unnecessary use of Google's API.
#
# This notebook merges the IBM data into the MaxMind CSV files. It also generates a separate CSV file containing a [geohash code](https://en.wikipedia.org/wiki/Geohash) for each location's latitude/longitude. All of the resulting CSV files are packed into a ZIP file for transfer to Streaming Analytics projects:
#
# * [GeoLite2-City-Blocks-IPv4.csv](merged/GeoLite2-City-Blocks-IPv4.csv)
# * [GeoLite2-City-Blocks-IPv6.csv](merged/GeoLite2-City-Blocks-IPv6.csv)
# * [GeoLite2-City-Locations-en.csv](merged/GeoLite2-City-Locations-en.csv)
# * [GeoLite2-City-Geohashes-en.csv](merged/GeoLite2-City-Geohashes-en.csv)
#
# There are instructions for each step of this notebook in the cells below.

# %% [markdown]
# -----
# Run this cell once to install additional Python packages used in this notebook:

# %%
# !pip install --user googlemaps
# !pip install --user geohash2
# Out:
# Requirement already satisfied: googlemaps in /Users/pring/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: requests<3.0,>=2.11.1 in /Users/pring/anaconda3/lib/python3.6/site-packages (from googlemaps)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/pring/anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/pring/anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/pring/anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pring/anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps)
# You are using pip version 9.0.1, however version 9.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: geohash2 in /Users/pring/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: docutils>=0.3 in /Users/pring/anaconda3/lib/python3.6/site-packages (from geohash2)
# You are using pip version 9.0.1, however version 9.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# -----
# Run this cell each time the notebook is loaded to include Python packages, and define some constants and functions used in this notebook:

# %%
import os
import re
import requests
from requests_file import FileAdapter
import json
import zipfile
import pandas as pd
import numpy as np
from io import BytesIO
from urllib.request import urlopen
import googlemaps
import geohash2
#####import ibm_boto3
#######from ibm_botocore.client import Config

# This constant points to the MaxMind 'GeoLite2' data.

maxmindGeoLite2URL = 'http://geolite.maxmind.com/download/geoip/database/GeoLite2-City-CSV.zip'

# This constant points to the IBM internal 'whois' service.

ibmWhoisLocationURL = 'http://whois.ibm.com:8080/whois/search.json?inverse-attribute=org&type-filter=domain&query-string=ORG-IBM1-IGA'
#ibmWhoisLocationURL = 'file:///Users/pring/git/MyGeohashDSXProject/whois.ibm.com_json_2018-03-23/ibm.domain.json'

# This constant contains a key for the Google Maps geocode API. 
# To create a key, follow the instructions at the top of this notebook.

googlemapsKey = 'AIzaSyAXrKyHrMa98L_e_CLtdi4UnQRPjHAEcYg'

# This constant contains the name of the JSON file where responses from the Google Maps
# geocode service are cached for reuse.

googlemapsCacheFilename = 'googlemaps.cache.json'

# This constant contains the name of a ZIP package that will contain the merged
# IBM and Maxmind data when this notebook has run to completion.

mergedPackageFilename = 'mergedIBMandMaxmindData.zip'

pd.set_option('max_rows', 15)

# This function iterates through the 'whois.ibm.com' data retrieved from the specified URL, 
# returning a 'dictionary' containing one entry each time it is called, until the end of the 
# data is reached, when it returns None.

def getWhoisEntry(url):
    
    # create an HTTP session that can handle a 'file' URL and send the request
    session = requests.Session()
    session.mount('file://', FileAdapter())
    response = session.get(url, stream=True)

    # if the HTTP response does not specify and encoding, force 'UTF-8'
    if response.encoding is None: response.encoding = 'utf-8'
    
    # read the HTTP response one line at a time, looking for the entry delimiters,
    # and returning one entry, converted to a JSON object, each time the function is called,
    # until the end of the response is reached
    body = ''
    state = 'prefix'
    for line in response.iter_lines(decode_unicode=True):
        if not line: continue
        if line == '  "object" : [ {': # starting delimiter for first entry 
            state = 'body'
        elif line == '  }, {': # delimiter between entries
            if len(body)>0: yield json.loads( '{' + body + '}' )
            body = ''
        elif line == '  } ]': # ending delimiter for last entry 
            if len(body)>0:  yield json.loads( '{' + body + '}' )
            state = 'suffix'
            body = ''
        else:
            if state=='body': body += line + '\n'
            
    # return 'None' when the end of the response is reached
    return None

# This function uses the Google Maps geocode API to map an address
# to location data, including latitude and longitude. Google limits 
# use of the API, so its responses are cached in a local file and 
# reused to avoid unnecessary use.

def getGoogleMapsGeocode(address, client, cache, cacheFilename):
    
    ########return None

    # if this address has been found before, return cached data, otherwise ask Google Maps
    # and cache the data
    if address in cache: 
        geocode = cache[address]
    else:
        print('--------------> geocode(' + address + ')')
        geocode = client.geocode(address)
        cache[address] = geocode
        storeObjectToFile(cacheFilename, cache)
    
    # extract address components from geocode data into simple dictionary
    if geocode and len(geocode)>0 and 'address_components' in geocode[0]: 
        result = { component['types'][0]: component['long_name'] for component in geocode[0]['address_components'] }
        result['latitude'] = geocode[0]['geometry']['location']['lat']
        result['longitude'] = geocode[0]['geometry']['location']['lng']
    else:
        result = None
        
    # return simple dictionary of address and location components
    return result

# This function loads a Python object from a JSON file. It used above
# to cache responses from the Google Maps geocode API.

def loadObjectFromFile(filename):
    if os.path.exists(filename):
        with open(filename, 'r') as file: return json.load(file)
    else:
        return {}

# This function stores a Python object in a JSON file. It used above
# to cache responses from the Google Maps geocode API.

def storeObjectToFile(filename, cache):
    if os.path.exists(filename+'.new'): os.remove(filename+'.new')
    with open(filename+'.new', 'w') as file: json.dump(cache, file)
    if os.path.exists(filename+'.old'): os.remove(filename+'.old')
    if os.path.exists(filename): os.rename(filename, filename+'.old')
    os.rename(filename+'.new', filename)
    
# This function replaces any mis-encoded Unicode characters of the form "\xXX"
# in the specified "UTF-8" string with the corresponding Unicode character, 
# properly encoded for "UTF-8"
    
def fixUnicodeCharacters(xxx):
    yyy = re.sub(r'\\x(..)', lambda match: chr(int(match.group(1),16)), xxx)
    return yyy

# %% [markdown]
# -----
# Run the next cell to download all of the 'domain' entries from the IBM 'whois' service into a list. This avoids the 'Connection broken: IncompleteRead' errors from the service that occur after a few hundred iterations when processing while downloading.

# %%
print('running ...')

whoisDomains = []
for whoisEntry in getWhoisEntry(ibmWhoisLocationURL):
    if whoisEntry['type']=='domain': whoisDomains.append(whoisEntry)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# Run the next cell to iterate through the list of 'domain' entries downloaded from the IBM 'whois' service above and collect IBM internal network and location data:

# %%
print('running ...')

# data for IBM networks and locations are collected in these lists
ibmNetworksIPv4 = []
ibmNetworksIPv6 = []
ibmLocations = []

# create a client for the Google Maps geocode service, and load any cached 
# responses from previous runs of this cell
googlemapsClient = googlemaps.Client(key=googlemapsKey)
googlemapsCache = loadObjectFromFile(googlemapsCacheFilename)
        
# iterate through the list of domain entries from IBM's whois' service
# downloaded above, collecting data on its locations and the subnets 
# assigned to each location
for whoisEntry in whoisDomains:

    # collect MaxMind location fields in this dictionary
    location = {}

    # skip 'whois' entries that are not IBM locations
    primaryKey = whoisEntry['primary-key']['attribute'][0]['value']
    if not re.fullmatch(r'[A-Z0-9]{3}', primaryKey): continue
    
    # extract fields of interest from 'whois' entries into a simple dictionary
    whois = {}
    for whoisAttribute in whoisEntry['attributes']['attribute']:  
        if whoisAttribute['name']=='remarks':
            match = re.fullmatch(r'RESO_(\w+)\.... = (.*)', whoisAttribute['value'])
            if match: whois[match.group(1)] = fixUnicodeCharacters(match.group(2))
            match = re.fullmatch(r'Prefix_List\.(\w+)\.... = (.*)', whoisAttribute['value'])
            if match and not match.group(2).endswith('NO_PREFIXES_FOUND'): whois[match.group(1)] = match.group(2).split(', ')
       
    # skip 'whois' entries that are not actual IBM locations
    if 'Country' not in whois: continue
    
    # copy 'whois' fields that correspond to MaxMind location fields
    location['geoname_id'] = primaryKey
    location['country_iso_code'] = whois['Country']
    if 'State' in whois: location['subdivision_1_iso_code'] = whois['State']
    if 'City' in whois: location['city_name'] = whois['City']

    # construct string representation of location address from 'whois' fields
    address = whois['Country']
    if 'State' in whois: address = whois['State'] + ', ' + address        
    if 'City' in whois and whois['City']!='NO CITY': address = whois['City'] + ', ' + address
    if  'Address1' in whois and not whois['Address1'].startswith('NO IBM LOCATION'):
        if 'Address2' in whois: address = whois['Address2'] + ', ' + address
        if 'Address1' in whois: address = whois['Address1'] + ', ' + address
        if 'PostalCode' in whois: address = address  + ', ' + whois['PostalCode']
    print(primaryKey + ': ' + address)
        
    # get geocode data for location from Google Maps    
    geocode = getGoogleMapsGeocode(address, googlemapsClient, googlemapsCache, googlemapsCacheFilename)
    if geocode:
        if 'country' in geocode: location['country_name'] = geocode['country']
        if 'administrative_area_level_1' in geocode: location['subdivision_1_name'] = geocode['administrative_area_level_1']
        if 'locality' in geocode: location['city_name'] = geocode['locality']
    
    # add each IPv4 and IPv6 subnet at this location to their respective lists
    if 'IPv4' in whois:
        for cidr in whois['IPv4']:
            if not cidr.startswith('9.'): continue
            network = { 'network': cidr, 'geoname_id': primaryKey }
            if 'PostalCode' in whois: network['postal_code'] = whois['PostalCode']
            if geocode and 'latitude' in geocode: network['latitude'] = geocode['latitude']
            if geocode and 'longitude' in geocode: network['longitude'] = geocode['longitude']
            ibmNetworksIPv4.append(network)
    if 'IPv6' in whois:
        for cidr in whois['IPv6']:
            if not cidr.startswith('2620:1F7:'): continue
            network = { 'network': cidr, 'geoname_id': primaryKey }
            if 'PostalCode' in whois: network['postal_code'] = whois['PostalCode']
            if geocode and 'latitude' in geocode: network['latitude'] = geocode['latitude']
            if geocode and 'longitude' in geocode: network['longitude'] = geocode['longitude']
            ibmNetworksIPv6.append(network)
            
    # add this location to the list
    ibmLocations.append(location)
        
print('... done')
# Out:
# running ...
# 009: RUA DO PROLETARIADO 14/1, ALFRAGIDE, 11, PT, 2795
# 00A: AVDA DE LA PALMERA 19, SEVILLA, SE, ES, 41013
# 00H: PLAZA CRONOS 1, MADRID, M, ES, 28037
# 00J: C/ SAKURA, 8, SAN FRUITÒS DEL BALGÈS, B, ES, 08202
# 00O: CALLE YECORA 4, MADRID, M, ES, 28022
# 00T: PARCELA PC10601 - PARC DE L'ALBA, CERDANYOLA DEL VALLÉS, BARCELONA, B, ES, 08290
# 00U: GRAN VÍA ASIMA 20, OFICINA 35. POLÍGONO SON CASTEL, PALMA DE MALLORCA, PM, ES, 07009
# 00W: PLAZA EUSKADI 5, BILBAO, PV, ES, 48009
# 01D: AVDA DIAGONAL 571, BARCELONA, B, ES, 08029
# 01E: AVDA DE ALGORTA NO 16, GETXO-VIZCAYA, BI, ES, 48990
# 01G: AV BRUSELAS, 20, ALCOBENDAS, M, ES, 28108
# 01H: TALES DE MILETO 1, ALCALA DE HENARES, M, ES, 28806
# 01I: CALLE MARÍA TUBAU 3, MADRID, M, ES, 28050
# 01J: CALLE MASQUEFA 58, BAJO DERECHA, VALENCIA, V, ES, 46020
# 01K: POLÍGONO DE POCOMACO, SECTOR I-1, N, LA CORUÑA, C, ES, 15190
# 01L: POLÍGONO INDUSTRIAL SANTA CLARA, CALLE B, LOCAL 4, AV/ SANTA CLARA DE CUBA, SEVILLA, SE, ES, 15190
# 01M: CARRER DE LA MORA 33, VIAL D, NAVE, BADALONA, B, ES, 08918
# 046: AVDA ARAGON 30, VALENCIA, V, ES, 46021
# 061: 1301 E EUCLID AVE, SUITE C, DES MOINES, IA, US, 50316-1258
# 068: J. HUIZINGALAAN 765, AMSTERDAM, NL, 1066 VH
# 083: 225 WESTERN AVE, AUGUSTA, ME, US, 04330-6159
# 0AM: STA. HORTENSIA 26-28, MADRID, M, ES, 28002
# 0HF: HAIFA UNIVERSITY, MOUNT CARMEL, HAIFA, HA, IL, 31905
# 0HS: 2, SQUARE RENE CASSIN, RENNES, FR, 35700
# 0IB: SHEIKH ZAYED ROAD, DUBAI INTERNET CITY, BUILDING 5, DUBAI, AE, 27242
# 0IO: SUBRAMANYA ARCADE, GRD-3RD FLRS, NO 12 BANNERGHATTA MAIN ROAD, BANGALORE, KA, IN, 560029
# 0IP: 281 T T K ROAD, 2ND-4TH FLRS, CHENNAI, TN, IN, 600018
# 0IR: 16 CAMAC STREET, L&T CHAMBERS, 2ND FLR, KOLKATA, WB, IN, 700017
# 0IV: THE IL&FS FINANCIAL CENTER, 4TH FLR, BANDRA KURLA COMPLEX, BANDRA (E), MUMBAI, MH, IN, 400051
# 0JB: C/ CANTON PEQUENO NO 13, LA CORUÑA, C, ES, 15003
# 0JS: PIAZZA BORGO PILA 38, CORTE LAMBRUSCHINI, GENOVA, GE, IT, 16129
# 125: 2-2 KITA 5 NISHI 6, CHUO-KU, SAPPORO, JP, 060-0005
# 1AO: 227 - 11TH AVENUE SW, CALGARY, AB, CA, T2R 1R9
# 1AU: 10044-108 ST NW, SUITE, EDMONTON, AB, CA, T5J 3S7
# 1MA: 2-1-10 SHIMONOPPORO TEKUNO PARK, AT, SAPPORO, JP, 004-0015
# 238: 1-4-32 NAKATOURI, AKITA, JP, 010-0001
# 2AC: ONE RESEARCH DR, REGINA, SK, CA, S4S 7H1
# 2AD: 1801 HAMILTON ST, REGINA, SK, CA, S4P 4B4
# 2M8: 2-13-5 HASHIMOTO, AOMORI, JP, 030-0823
# 2P1: 15-20 MORIOKAEKIMAEDORI, MORIOKA, JP, 020-0034
# 341: 1-7-15 SOGAWA, TOYAMA, JP, 930-0083
# 343: 2-1-18 HIGASHIODORI, CHUO-KU, NIIGATA, JP, 950-0087
# 344: 3-1-1 HIROOKA, KANAZAWA, JP, 920-0031
# 345: 2-7-15 OHTE, FUKUI, JP, 910-0005
# 3AE: 400 ELLICE AVE, WINNIPEG, MB, CA, R3B 3M3
# 408: 1-12-1 DOUGENZAKA SHIBUYA-KU, 18FLR SHIBUYA MARK CITY BLDG, TOKYO, JP, 150-0043
# 423: 1-4-73 SANNOMARU, MITO, JP, 310-0011
# 427: 4-7-11 ONOHARA, KAMISU, JP, 314-0144
# 4AI: 690 DALTON ST., KINGSTON, ON, CA, K7M 8N8
# 4AM: 3500 STEELES AVE EAST, MARKHAM, ON, CA, L3R 0X1
# 4AN: 3600 STEELES AVE EAST, MARKHAM, ON, CA, L3R 9Z7
# 4AO: 4175 14TH AVENUE, MARKHAM, ON, CA, L3R 5R5
# 4BY: 100 WYNFORD DR., 2ND FLOOR, TORONTO, ON, CA, M3C 1K4
# 4CG: 151 FRONT STREET, SUITE 200, TORONTO, ON, CA, M5J 2N1
# 4CH: 245 CONSUMERS RD, NORTH YORK, ON, CA, M2J 1R3
# 4CQ: 79 WELLINGTON ST. W., TORONTO, ON, CA, M5K 1B1
# 4EK: 120 BLOOR ST E, GROUND FLOOR, TORONTO, ON, CA, M4W 1B7
# 4EM: 8200 WARDEN AVE, TORONTO LAB, MARKHAM, ON, CA, L6G 1C7
# 4EO: 100 GOUGH ROAD, MARKHAM, ON, CA, L3R 4B7
# 4K2: 733 UEMATSUCHO, SHIMOGYO-KU, KYOTO, JP, 600-8028
# 4MM: 2-6-1 NAKASE,, MIHAMA-KU, CHIBA, JP, 261-7110
# 4N2: 4-1-18 ODORI, UTSUNOMIYA, JP, 320-0811
# 4N5: 1-11-3 SAKURAGICHO OHMIYA-KU, SAITAMA, JP, 330-0854
# 4S6: 19-21 NIHONBASHI-HAKOZAKICHO, CHUO-KU, TOKYO, JP, 103-8510
# 4S8: 1-1 NAKASE, MIHAMAKU, CHIBA, JP, 261-8522
# 4T3: 1-24-13 ASAHICHO, ATSUGI, JP, 243-0014
# 4T8: 1-204 TSUKUBA, KUMAGAYA, JP, 360-0037
# 4T9: 58-1 YASHIMACHO, TAKASAKI, JP, 370-0849
# 4W2: 1-6-1 TAKEZONO, TSUKUBA, JP, 305-0032
# 4WR: 1-1 NIKKOCHO, TOKYO, JP, 183-0044
# 4WS: 1-15-2 OCHIAI, TAMA, JP, 206-0033
# 4Z5: 14-23 WAKITAHONCHO, KAWAGOE, JP, 350-1123
# 502: 3001 HENDERSON DR, SUITE J, CHEYENNE, WY, US, 82001-5840
# 530: 1524-80 HIEKAWA, IZU, JP, 410-2507
# 535: 319-28 KAJIMACHI, NAKA-KU, HAMAMATSU, JP, 430-0933
# 539: 3-1-1 NISHIKI NAKA-KU, NAGOYA, JP, 460-0003
# 542: 2-13-1 TOKIWACHO AOI-KU, SHIZUOKA, JP, 420-0034
# 575: 4 ALLIANCE BOULEVARD, BARRIE, ON, CA, L4M 5J1
# 5AA: 23 BOULEVARD DE L'AEROPORT, BROMONT, QC, CA, J2L 1A3
# 5AB: 200 BOUL BOUCHARD, ROOM 650A, DORVAL, QC, CA, H9S 1A8
# 5AF: 275 RUE VIGER EST, MONTREAL, QC, CA, H2X 3R7
# 5AI: 2700 LAURIER BLVD., TOUR CHAMPLAIN, SAINTE-FOY, QC, CA, G1V 4J9
# 5AP: 140 GRANDE ALLEE EAST, QUEBEC CITY, QC, CA, G1R 5N6
# 5N4: 1-2658-2 JONAN, SUWA, JP, 392-0017
# 5P8: 1-1 SUWASAKAEMACHI, YOKKAICHI, JP, 510-0086
# 5U0: 2-5-2 FUKASHI, MATSUMOTO, JP, 390-0815
# 5U5: 1-179 MIYUKIHONMACHI, TOYOTA, JP, 473-0901
# 5V1: 1-1 SHIBAHONCHO, MISHIMA, JP, 411-0857
# 5V4: 2-8 HASHIMOTOCHO, GIFU, JP, 500-8856
# 612: SECOND TERRACE & COLLINS AVENUE, NASSAU, BS
# 613: COLLYMORE ROCK, ST MICHAEL, BB
# 614: ANASASTRAAT 8, ORANJESTAD, AW
# 616: 52-56 KNUTSFORD BLVD, KINGSTON, JM
# 617: VAN'T HOGERHUYSSTRAAT 9-11, PARAMARIBO, SR
# 618: 91-93 ST VINCENT STREET, FLOORS 1 AND 2, PORT-OF-SPAIN, TT
# A56: 8000 GRAINGER COURT, SPRINGFIELD, VA, US, 22153-3130
# A5Y: 348 EDWARD STREET, BRISBANE, QLD, AU, 4000
# A6S: CNR GEELONG RD & GEAR AVENUE, MT HELEN, BALLARAT, VIC, AU, 3350
# A6X: LAATZENER STR. 1, HANNOVER, DE, 30539
# A78: PLOT NO XI-7, KOLKATA, WB, IN, 700091
# A7X: CARL-BENZ RING 22, GAIMERSHEIM, DE, 85080
# A94: GENERAAL LEMANSTRAAT 69, ANTWERP, BE, 2018
# A9Q: 48 NAVAM MAWATHA, THAAKSHANA MANDIRAYA, COLOMBO, LK, DIST II
# A9V: 23, KASR EL NIL, CAIRO, EG, 9999
# AAG: IBM-ALLEE 1, EHNINGEN, DE, 71139
# AAH: NEUMANN JANOS U.1, BUDAPEST, HU, 1117
# AAM: ALTROTTSTR.31, WALLDORF, DE, 69190
# AAY: SITTARDER STRASSE 31, AACHEN, DE, 52078
# ACT: PJE. ING. ENRIQUE BUTTY 275, CAPITAL FEDERAL, C, AR, C1001AFA
# ADA: 180 GREENHILL ROAD, PARKSIDE, SA, AU, 5063
# ADI: 4600 MCAULEY PLACE, SUITE 200, CINCINNATI, OH, US, 45242-4765
# ADS: BEIM STROHHAUSE 17, HAMBURG, DE, 20097
# ADT: 1000 BELLEVIEW ST, DALLAS, TX, US, 75215-1870
# AFO: 4499 FISHER RD, COLUMBUS, OH, US, 43228-9509
# AIR: 160 AIRPORT RD, WESCHESTER COUNTY AIRPORT, WHITE PLAINS, NY, US, 10604-1219
# ALA: 3500 BLUE LAKE DR, BIRMINGHAM, AL, US, 35243-1900
# ALX: 5, MAHMOUD ABDEL MOMEIM SHAKER, ST, ALEXANDRIA, EG, 9999
# AMA: PTE. HIPOLITO YRIGOYEN 2149, MARTINEZ / SAN ISIDRO, BUENOS AIRES, B, AR, B1640HFQ
# ANY: 80 STATE ST, 4TH FL, ALBANY, NY, US, 12207-2543
# APM: 1000 REPUBLIC DR, SUITE 685, ALLEN PARK, MI, US, 48101-3636
# ASK: MLYNSKE NIVY 49, APOLLO BC II, BLOCK H, BRATISLAVA, SK, 82109
# B6C: VIA SCIANGAI 53, ROMA, RM, IT, 00144
# BAC: 5100 CALIFORNIA AVE, BAKERSFIELD, CA, US, 93309-0715
# BAW: RUA ENG. FRANCISCO DE PITTA BRITO 1, FLOOR SS, TE, 1, 4, & 5, SAO PAULO, SP, BR, 04753-080
# BBN: AL. ARAGUAIA 2044 - 9? ANDAR, CENTRO EMPRESARIAL ARAGUAIA, BARUERI, SP, BR, 06455-000
# BBS: SCN QUADRA 4, BLOCO B, N.100, SALA 601 E 701, BRASILIA, DF, BR, 70714-900
# BBU: AV. DOLORES ALCARAZ CALDAS, 7, 10 &11 FLOORS, PORTO ALEGRE, RS, BR, 90110-180
# BCD: RUA PLACIDO GOMES, BAIRRO ANITA GARIBALDI, JOINVILLE, SC, BR, 89202-050
# BCY: RUA MARIA LUIZA SANTIAGO 200, 3? E 5? ANDARES, BELO HORIZONTE, MG, BR, 30360-740
# BDF: 3 NEW SQUARE, BEDFONT LAKES, FELTHAM, GB, TW14 8HB
# BDO: AV. MINISTRO IVAN LINS, 300, 2O ANDAR, RIO DE JANEIRO, RJ, BR, 22620-110
# BDP: RUA EZEQUIEL RAMOS 3-33, 2 ANDAR - CENTRO BAURU, BAURU, SP, BR, 17010-021
# BDQ: RUA GASPAR VIANA 324, ANDAR SUPERIOR, CAMPINA, BELEM, PA, BR, 66053-090
# BDT: RUA RIO DE JANEIRO, 328, 4 ANDAR - CENTRO, BELO HORIZONTE, MG, BR, 30160-040
# BDU: SCS QUADRA 2 ED. BRADESCO, BLOCO B-81, 2?. ANDAR, BRASILIA, DF, BR, 7039-900
# BDV: AV. DR. MORAES SALES, 668, 4? ANDAR - CENTRO, CAMPINAS, SP, BR, 13010-001
# BDW: ESTRADA CAMPO LIMPO 4519, 1? ANDAR - PIRAJUSSARA, SAO PAULO, SP, BR, 05787-000
# BDX: RUA BARAO DE ITAPAGIPE 225, BLOCO D, T?RREO - R. COMPRIDO, RIO DE JANEIRO, RJ, BR, 20261-005
# BDZ: AV. YARA S/N, CIDADE DE DEUS, PR?DIO AZUL - ANDAR INTERMED., OSASCO, SP, BR, 06000
# BEC: NAHMITZER DAMM 12, BERLIN, DE, 12277
# BEG: AV. XV DE NOVEMBRO 772, 1? ANDAR - PORTO, CUIAB?, MT, BR, 78020-300
# BEH: AV. PRESIDENTE AFFONSO CAMARGO 177, 2? ANDAR, JARDIM BOT?NICO, CURITIBA, PAR, BR, 80060-090
# BEI: RUA FULVIO ADUCCI 809, 1? ANDAR - CENTRO, FLORIANOPOLIS, SC, BR, 88075-001
# BEJ: RUA FLORIANO PEIXOTO 875, 2? ANDAR - CENTRO, FORTALEZA, CE, BR, 60025-1
# BEK: AV. GOIAS, 414, 3? ANDAR CENTRO, GOIANIA, GO, BR, 74010-010
# BEM: AV. SETE DE SETEMBRO 1652/1698, 2? ANDAR - VILA GALV?O, GUARULHOS, SP, BR, 07064-002
# BEN: RUA 12 DE OUTUBRO 125, 4? ANDAR, SAO PAULO, SP, BR, 05073-001
# BEO: RUA SILVA RAMOS, 368 - CENTRO, MANAUS, AM, BR, 69025-030
# BEP: AV. GETULIO VARGAS 115, FUNDOS, 1? ANDAR - CENTRO, MARINGA, PAR, BR, 87013-130
# BEQ: AV. ERNANI DO AMARAL PEIXOTO 211, 2 ANDAR - CENTRO, NITEROI, RJ, BR, 24020-071
# BER: AV. RIO BRANCO 112, 1? E 2? ANDS - CAMPOS EL?SEOS, SAO PAULO, SP, BR, 01206-00
# BES: AV. NOSSA SRA. DA PENHA, 1255, SALAS 101 / 102, VIT?RIA, ES, BR, 29055-131
# BEU: AV. LINS DE VASCONCELOS 2362, 1 ANDAR, VILA MARIANA., SAO PAULO, SP, BR, 04112-001
# BEW: BRADESCO. RUA SAO CRISTOVAO 600, 2? E 3? ANDS - S?O CRISTOVAM, RIO DE JANEIRO, RJ, BR, 20940-000
# BEX: AV DA FRANCA, 409 10 ANDAR, ED. ABELARDO PARENTE COM?RCIO, SALVADOR, BA, BR, 40010-000
# BEY: AV. DR. PEDRO LESSA, 847, 1? ANDAR, BAIRRO PONTA DA PRAIA, SANTOS, SP, BR, 11025-001
# BEZ: AV. DR. RUDGE RAMOS 155, 1?ANDAR - RUDGE RAMOS, SAO BERNARDO DO CAMPO, SP, BR, 09637-000
# BFA: AV. BENEDITO FRIGGI 3330, FUNDOS - BAIRRO VISTA VERDE, SAO JOSE DOS CAMPOS, SP, BR, 12200
# BFB: AV. FARRAPOS 3852, 1? ANDAR - NAVEGANTES, PORTO ALEGRE, RS, BR, 90220-003
# BFC: R. DO MUNIZ, 162? 2? ANDAR, S?O JOS?, RECIFE, PE, BR, 50020-1
# BFD: AV. SAUDADE 935, 2? ANDAR, CAMPOS EL?SIOS, RIBEIRAO PRETO, SP, BR, 14080
# BFE: R. GENERAL OS?RIO 124, 2? ANDAR - CENTRO, VIT?RIA, ES, BR, 29010-035
# BFG: AVENIDA PRESIDENTE JUSCELINO KUBITS, SAO PAULO, SP, BR, 04543-907
# BGN: RUA 6, N.370, 15 ANDAR, SALAS 1506/1507/1508, GOIANIA, GO, BR, 74115-070
# BHA: 3 BROOKHOLLOW AVENUE, NORWEST BUSINESS PARK, BAULKHAM HILLS, NSW, AU, 2153
# BLA: AV. NACOES UNIDAS 12901, 20? E 21? ANDARES - CENU, SAO PAULO, SP, BR, 04578-000
# BLI: AV. SANTOS DUMONT 1789 S.213, FORTALEZA, CE, BR, 61150-060
# BLO: 1615 COMMERCE PKWY, BLOOMINGTON, IL, US, 61704-9608
# BLS: AVENUE DU BOURGET, 42, BRUSSELS, BE, 1130
# BMA: AV. PASTEUR 146 & 138, RIO DE JANEIRO, RJ, BR, 22290-240
# BME: 6710 ROCKLEDGE DR, BETHESDA, MD, US, 20817-1827
# BMM: RD J FCO AGUIRRE PROENCA KM 9, SP101. CHACARA ASSAY, HORTOLANDIA, SP, BR, 13186-900
# BMN: AVE. CONSTANTINO NERY 4165, SALA 104, MANAUS, AM, BR, 69058-795
# BNT: 11501 BURNET RD, AUSTIN, TX, US, 78758-3400
# BOA: SCHOENAICHER STR. 220, BOEBLINGEN, DE, 71032
# BOL: 6300 DIAGONAL HWY, BOULDER, CO, US, 80301-6108
# BPA: AV. GOVERNADOR JOSE MALCHER, BELEM, PA, BR, 66055-260
# BPR: AV. MARECHAL DEODORO, 10? ANDAR, CURITIBA, PR, BR, 80020-320
# BSC: RUA ADOLFO MELO, SALAS 101 / 102, FLORIANOPOLIS, SC, BR, 88015-090
# BTU: RUA TUTOIA 1157, SAO PAULO, SP, BR, 04007-900
# BVA: 2501 SE J ST, BENTONVILLE, AR, US, 72712-3724
# C0A: BORUPVANG 1, BALLERUP, DK, 2750
# C0Z: AV. TANCREDO NEVES 450, SALA 3201 AND 3202, SALVADOR, BA, BR, 41820-020
# C1C: AVE. LIBRAMIENTO APOD, STA ROSA 111, COL. FUTURO APODACA, MONTERREY, NLE, MX, 66600
# C1E: RUA CAIS DO APOLO, 14? ANDAR - RECIFE, RECIFE, PE, BR, 50030-905
# C1F: 505 DOTA, KANI, JP, 509-0206
# C1G: 5-2-48 INOKUCHI, NISHI-KU, HIROSHIMA, JP, 733-0842
# C1L: J. HUIZINGALAAN 759, AMSTERDAM, NL, 1066 VH
# C1M: DAVID RICARDOSTRAAT 2-4, AMSTERDAM, NL, 1066 JS
# C1N: TECHNICKA 23, BRNO, CZ, 61600
# C1S: GROUND FLOOR OF SUB-STATION BUILDIN, 1 MINTO ROAD,DHAKA-1000BANGLADESH, DHAKA, BD, 1000
# C1U: WILHELM-FAY-STR. 30-34, FRANKFURT, DE, 65936
# C1V: HOLLERITHSTR. 1, MÜNCHEN, DE, 81829
# C1Y: KE JI NAN YI LU, SHENZHEN HI-TECH IND PARK, LIMING BUILDING, NANSHAN DISTRICT, SHENZHEN, 44, CN, 518057
# C3B: THE ESTUARIES, CENTURY CITY, NO. 1 OXBOW CRESCENT, CAPE TOWN, ZA, 7441
# C3C: COMMONWEALTH AVENUE, BARANGAY UP DI, UP AYALA LAND TECHNO HUB, QUEZON CITY, 0, PH, 1121
# C3G: ALL, VI
# C3Q: 9 CHANGI BUSINESS PARK CENTRAL 1, SINGAPORE, SG, 486048
# C3R: KOEZTELEK U. 6, CITY GATE, BUDAPEST, HU, 1092
# C3T: NO 7 SONG REN ROAD, 3/F & 4/F, CATHAY FINANCIAL CENTER, TAIPEI, TW, 110
# C3V: 2 KE FA RD, GREAT WALL TECH BLDG,, NORTH AREA, SHENZHEN HI-TECH INDUSTRIAL PARK, NANSHAN DISTRICT,, SHENZHEN, 44, CN, 518057
# C4H: 1 THE SQUARE, TEMPLE QUAY, BRISTOL, GB, BS1 6DG
# C4I: 9 ALLEE ALAN TURING, PARC TECHNOLOGIQUE DE LA PARDIEU, AUBIERE, FR, 63170
# C4J: RUE DE CHANTEMERLE, ZI DE LA COMBAUDE, CLERMONT-FERRAND, FR, 63000
# C4L: EXPLORER, INFORMATION TECHNOLOGY PK, 4TH & 5TH FLRS, WHITEFIELD, BANGALORE, KA, IN, 560066
# C4N: OZONE - 3, SP INFOCITY, SASWAD RD, FURSUNGI VILLAGE, HADAPSAR, PUNE, MH, IN, 412308
# C4P: EMBASSY LINKS, EMBASSY CYPRESS PT, INDIRANAGAR-KORAMANGALA, INTERMEDIATE RING RD, BANGALORE, KA, IN, 560071
# C4S: 102 BOULEVARD DE LA WOLUWE, BRUSSELS, BE, 1200
# C4U: KARLSROGATAN 2, SOLNA, SE, 17065
# C5D: AVE. JOAQUIN ORRANTIA & JUAN TANCA, EXECUTIVE BUILDING, GUAYAQUIL, G, EC, 3686
# C5N: VIA DARWIN,85, SETTIMO MILANESE, MI, IT, 20019
# C5P: DLF SILOKHERA, VILLAGE SILOKHERA, NATIONALL HIGHWAY - 8, HARYANA, GURGAON, HR, IN, 122002
# C6G: SAMPSON HOUSE, 64 HOPTON STREET, LONDON, GB, SE1 9JH
# C6N: BUILDING 2, KELBURN COURT, DATEN PARK, BIRCHWOOD, WARRINGTON, GB, WA3 6JA
# C7C: 3-1-1 KARAKIDA, TAMA, JP, 206-0035
# C7D: 10 PLACE DE LA JOLIETTE, MARSEILLE, FR, 13002
# C7E: 10 PRESNENSKAYA NABEREZHNAYA, MOSCOW, RU, 123112
# C7J: NO 6 SZU WEI 3RD ROAD, 26/F, CATHAY SZU WEI FINANCIAL BLDG, KAOHSIUNG, TW, 802
# C7K: SHEFA TAL ST. GIVATAYIM, TEL AVIV, TA, IL
# C7P: ROAD NUMBER 1702, AL JASRAH TOWER BUILDING 95, 14TH FLOOR, OFFICE 1403, MANAMA, BH, 3214
# C7S: 1-2-13 SHINSENRI NISHIMACHI, TOYONAKA, JP, 560-0083
# C7T: 1-1-25 SHINURASHIMACHO, KANAGAWA-KU, YOKOHAMA, JP, 221-8520
# C7U: 7-2-14 TOYO, KOTO-KU, TOKYO, JP, 135-0016
# C7V: 8-18 AZUMA KAMI-CHOU, KASHIWA, JP, 277-0011
# C7W: 3-4-1 MARUNOUCHI, CHIYODA-KU, TOKYO, JP, 100-0005
# C7Y: 2-14-1 KUMOJI, NAHA, JP, 900-0015
# C7Z: CIRCONVALLAZIONE IDROSCALO, SEGRATE, MI, IT, 20090
# C8A: 1-1 HONKOMORICHO, NARA, JP, 630-8231
# C8O: 804-805 LEVEL 8, JL. PEMUDA 60-70, SURABAYA, JI, ID, 60271
# C8R: NO. 8 NEW LINK RD, 5/F, MAGNUS TOWERS, MINDSPACE, MALAD (WEST), MUMBAI, MH, IN, 400064
# C8X: DEAKVARI FASOR 16-18, VAC, HU, 2600
# C9G: 2-6-6 HAKATAEKIMAE, HAKATA-KU, FUKUOKA, JP, 812-0011
# C9H: 2-16-4,KOHNAN,MINATO-KU, TOKYO, JP, 180-0075
# C9L: 1-20-1 IWAMURADAKITA,, SAKU, JP, 385-0023
# C9Y: PRØVENSVEJ 1, BRØNDBY, DK, 2605
# CAM: VIA MAMELI 191, CAGLIARI, CA, IT, 09100
# CB1: 1302 CONCOURSE DR, STE 110, LINTHICUM, MD, US, 21090-1022
# CBO: CARRERA 53 NUMERO 100-25, BOGOTA, CO, 11001000
# CC5: 333 JOHN CARLYLE ST, SUITE 635, ALEXANDRIA, VA, US, 22314-5767
# CC6: 2101 EXECUTIVE DR, HAMPTON, VA, US, 23666-2404
# CD1: 2500 TECHNOLOGY CIRCLE, SUITE 2, BENTONVILLE, AR, US, 72712-7102
# CE2: 30501 AGOURA RD, SUITE 100, AGOURA HILLS, CA, US, 91301-4323
# CE5: 194 WOOD AVE, ISELIN, NJ, US, 08830-1527
# CEF: 2070 ROUTE 52, HOPEWELL JUNCTION, NY, US, 12533-6683
# CF0: 11511 LUNA ROAD, FARMERS BRANCH, TX, US, 75234-6022
# CF3: 2300 15TH STREET, SUITE 400, DENVER, CO, US, 80202-6106
# CF5: 14001 NORTH DALLAS PARKWAY, SUITE M100, DALLAS, TX, US, 75240-4350
# CF6: 4040 LAFAYETTE CENTER DRIVE, CHANTILLY, VA, US, 20151
# CF8: 44060 DIGITAL LOUDOUN, ASHBURN, VA, US, 20147
# CFA: 55 COONARA AVENUE, WEST PENNANT HILLS, NSW, AU, 2125
# CG2: 550 ASSEMBLY ST, COLUMBIA, SC, US, 29201-4144
# CG6: 505 HOWARD ST, SUITE 600, 700, & 850, SAN FRANCISCO, CA, US, 94105
# CG9: 1100 SPACE PARK DRIVE, SANTA CLARA, CA, US, 95054
# CH0: 75 BINNEY ST, CAMBRIDGE, MA, US, 02142-1123
# CH1: 1500 NORTH 19TH STREET, MONROE, LA, US, 71201
# CH3: 10140 MESA RIM RD, SAN DIEGO, CA, US, 92121
# CH4: 325 BILL FRANCE BLVD, DAYTONA BEACH, FL, US, 32114-1301
# CH5: 900 WALNUT RIDGE DRIVE, HARTLAND, WI, US, 53029
# CH8: 260 FRANKLIN ST, BOSTON, MA, US, 02110
# CH9: 111 WEST JACKSON BLVD, SUITE 2120, CHICAGO, IL, US, 60604
# CHE: RATHAUSSTR. 7, CHEMNITZ, DE, 09111
# CHQ: 1 NEW ORCHARD RD, ARMONK, NY, US, 10504-1722
# CI0: 222 SOUTH RIVERSIDE PLAZA, SUITES 170 & 182, CHICAGO, IL, US, 60606
# CI6: 10 NORTH MARTINGALE RD, WOODFIELD PRESERVE, SCHAUMBURG, IL, US, 60173-2099
# CMA: ONE ROGERS ST, CAMBRIDGE, MA, US, 02142-1203
# CMS: 600 ANTON BLVD, COSTA MESA, CA, US, 92626-7221
# CNE: 300 EAST JIE FA, HUA TIAN HOTEL, RM 61007 & 61008 & 61008A, 10/F, VIP BLDG, HUNAN PROVINCE, CHANGSHA, 43, CN, 410001
# CNY: 1 NORTH CASTLE DR, ARMONK, NY, US, 10504-1784
# CZ9: 23 PARKWAY CIRCLE, UNIT, NEW CASTLE, DE, US, 19720-4019
# CZA: THE PARK, V PARKU 2294/4, BUILDING 2/4, PRAHA, CZ, 14800
# D0I: 2-60 HIGASHIHONMACHI, MATSUE, JP, 690-0842
# D0J: 2-29-2 AIOICHO, KARIYA, JP, 448-0027
# D0L: 3-1 KANAYAMACHO, NAKA-KU, HIROSHIMA, JP, 730-0022
# D0S: 5, RUE ROLAND GARROS, MINIPARC ALPES CONGRES, EYBENS, FR, 38320
# D0X: AMIR TIMUR STREET 107-B, TASHKENT, UZ, 100084
# D1A: SORTEMOSEVEJ 21, ALLEROD, DK, 3450
# D1B: 19 ZHONGGUANCUN SOFTWARE PARK, 8 DONGBEIWANG WESTERN ROAD, HAIDIAN DISTRICT, BEIJING, 11, CN, 100193
# D1E: 25 BARAKHAMBHA ROAD, 1ST FLOOR, BIRLA TOWER, NEW DELHI, DL, IN, 110001
# D1F: KASHI KUNJ ROAD NO. 2, CONTRACTOR'S AREA BISTUPUR, JAMSHEDPUR, JH, IN, 831001
# D1N: AL.ARMII KRAJOWEJ 18, KRAKOW, PL, 30-150
# D1Q: 722 UPPER CHANGI ROAD EAST, SIA COMPUTER CENTRE BUILDING, SINGAPORE, SG, 486854
# D2E: HARRISON CLOSE, POWER HOUSE, KNOWLHILL, MILTON KEYNES, GB, MK5 8RR
# D2U: 3960 QUADRA STREET, QUADRA CENTRE, VICTORIA, BC, CA, V8X 4A3
# D2Z: SEESTRASSE 6, BREGENZ, AT, 6900
# D3D: 1-13-12 SHINBASHI MINATO-KU, TSUTSUMI BLDG, TOKYO, JP, 105-0004
# D3E: MINDSPACE, HI-TECH CITY, MADHAPUR, HYDERABAD, TS, IN, 500081
# D3F: VULKANSTR. 106, ZÜRICH, CH, 8048
# D3J: DLF IT PARK, PLOT NO. 08-MAR, 59.0 M ARTERIAL RD OF NEW TOWN (RAJARHAT), KOLKATA, WB, IN, 700156
# D3W: BUCHAREST BUSINESS PARK, BUCURESTI-PLOIESTI NATIONAL ROAD 1A, BUILDING A2, BUCHAREST, RO, 013681
# D3Y: TECH PARK ONE (PANCHSHILL), OFF AIRPORT ROAD, YERWADA, PUNE, MH, IN, 411006
# D3Z: 4396 WEST SAANICH RD, SUITE 200, VICTORIA, BC, CA, V8Z 3E9
# D4C: 10 KAKI BUKIT AVENUE 1, KAKI BUKIT INDUSTRIAL ESTATE,, SINGAPORE, SG, 417942
# D4E: 15-35 HONCHO, WAKO, JP, 351-0114
# D4H: 1-25-1 NISHISHINJUKU SHINJUKU-KU, TOKYO, JP, 163-0634
# D4I: 4-3-31 TOKAMACHI, YAMAGATA, JP, 990-0031
# D4N: MIRAMARSKA 23, EUROCENTER, ZAGREB, HR, 10000
# D4O: VIRCHOWSTR. 3, WILHELMSHAVEN, DE, 26382
# D4R: ZAC DE CHARBONNIERE, 110, BOULEVARD DE LA SALLE, BOIGNY SUR BIONNE, FR, 45760
# D4T: OUTER RING ROAD, EMBASSY MANYATHA B, RACHENAHALLI & NAGAWARA VILLAGES, BANGALORE, KA, IN, 560045
# D4U: DLF INFINITY TOWERS, PHASE II, DLF CITY, GURGAON, HR, IN, 122022
# D4Y: 189 NANJING ROAD, HEPING DISTRICT UNIT 3401 EXCHANGE PLAZA, TIANJIN, 12, CN, 300051
# D4Z: INVENTOR, INFORMATION TECHNOLOGY PK, WHITEFIELD, BANGALORE, KA, IN, 560066
# D5A: VASTRA VARVSGATAN 19, (MAIL ADDRESS: BOX 4104, 20312 MALMÖ, MALMÖ, SE, 21119
# D5C: STRADA PRIVATA CASCIA 5, MILANO, MI, IT, 20128
# D5Y: 8 FIRST AVENUE, PERSIARAN BANDAR UTAMA, PETALING JAYA, 10, MY, 47800
# D6E: TECHNICKA 21, BRNO, CZ, 61600
# D6J: 340 FINDON RD, KIDMAN PARK, SA, AU, 5025
# D6K: 733 ANN STREET, FORTITUDE VALLEY, QLD, AU, 4006
# D7L: TECHNICKA 19, BRNO, CZ, 61600
# D8A: 9 RUE LINUS CARL PAULING - PARC DE, MONT SAINT AIGNAN, FR, 76130
# D8N: 58 ZHICHUNLU, CHINA AVIATION TECH BLDG, HAIDIAN, BEIJING, 11, CN, 100098
# D8V: 568 JIANSHE AVE, UNIT 3803-3808, NEW WORLD INT'L TRADE CTR TOWER 1, WUHAN, 42, CN, 430022
# D8X: 340/1 AVENUE DE LA MARNE - PARC EUR, MARCQ-EN-BAROEUL, FR, 59700
# D9I: 4A VASILE MILEA BLVD, 6TH DISTRICT, BUCHAREST, RO, 061344
# D9R: BIRCH POINT, UNIT W,, BIRCH INDUSTRIAL ESTATE, WHITTLE LANE, HEYWOOD, ROCHDALE, GB, OL10 2SX
# D9S: MINERVA POINT, WORCESTER ROAD, STOURPORT ON SEVERN, GB, DY13 9AT
# D9T: UNIT Z, SPRINGFIELD BUSINESS PARK, SHEEPSCOTES, CHELMSFORD, GB, CM2 5BB
# D9X: BULEVAR MIHAJLA PUPINA NO. 6, BELGRADE, RS, 11070
# D9Z: 3-6-4 MINATOMIRAI, NISHI-KU, YOKOHAMA, JP, 220-0012
# DA8: 470 SPRINGPARK PL, SUITE 1000A & 950, HERNDON, VA, US, 20170-5253
# DAS: 1503 LYNDON B JOHNSON FREEWAY, DALLAS, TX, US, 75234-6059
# DEV: 4700 S SYRACUSE ST, DENVER, CO, US, 80237-2710
# DFW: 1177 S BELT LINE RD, COPPELL, TX, US, 75019-4642
# DIA: OBERE DONAUSTRASSE 95 (DIANA), WIEN, AT, 1020
# DR8: 6720 VIA AUSTI PARKWAY, SUITE 500, LAS VEGAS, NV, US, 89119
# DRC: FREIBERGER STR.35, DRESDEN, DE, 01067
# DUB: KARL-ARNOLD-PLATZ 1 A, DÜSSELDORF, DE, 40474
# DUH: 4125 S MIAMI BLVD, DURHAM, NC, US, 27703-9139
# E0B: RICHARD-NEUTRA-GASSE 10, WIEN, AT, 1210
# E0D: 1-22 NAKAMACHI, KOHRIYAMA, JP, 963-8004
# E0E: 1-2-31 AIOI, KOFU, JP, 400-0858
# E0H: 5-8-40 KIBA, KOUTOU-KU, TOKYO, JP, 135-0042
# E0J: 250 YORK STREET, SUITE 301, LONDON, ON, CA, N6A 6K2
# E0M: PRASAD TECHNOLOGY PK, PLOT NO. 97, SURVEY NO. 152, EPIP INDUSTRIAL AREA, WHITEFIELD, BANGALORE, KA, IN, 560066
# E0O: 1190 HOMER STREET SUITE 401, VANCOUVER, BC, CA, V6B 2X6
# E1I: 3-9 MORIYACHO, KANAGAWA-KU, YOKOHAMA, JP, 221-0022
# E1J: 3 KIRIHARACHO, FUJISAWA, JP, 252-0811
# E2Q: 1279 NEPEAN HIGHWAY, CHELTENHAM, VIC, AU, 3192
# E2R: 1 MACADAM SQUARE, BRUCEFIELD INDUSTRIAL PARK, LIVINGSTON, GB, EH54 9BY
# E2S: TIANFU AVENUE, A5 BUILDING,TIANFU SOFTWARE PARK, CHENGDU, 51, CN, 610041
# E2T: KINGDOM CENTER, AL URUBAH RD, 23RD FLOOR, P.O BOX 50705, RIYADH, SA, 11533
# E2Y: 2 TONGJIZHONGLU, BEIJING, SOLOON BUILDING, BEIJING, 11, CN, 100176
# E3C: UNITECH CYBER PARK, 60 MTR SECTOR ROAD, SECTOR-39, GURGAON, HR, IN, 122002
# E3G: PLOT NO 4, VASANT KUNJ PHASE II, VASANT VIHAR INSTITUTIONAL AREA, NEW DELHI, DL, IN, 110070
# E3K: 34 COMMERCE CRESCENT, NORTH BAY, ON, CA, P1A 0B4
# E3X: 2-5 MOTOSHIMACHO, SASEBO, JP, 857-0871
# E3Y: 1360-1 SUEHIROCHO, NAGANO, JP, 380-0825
# E4B: BLK 7, 3F & 4F AND BLK 1A, GF &1F,, NANDAMBAKKAM POST, RAMAPURAM, MT PONAMALEE RD, CHENNAI, TN, IN, 600089
# E4C: 83B LY THUONG KIET STREET, UNIT V02, 2/F, HANOI, VN, 10000
# E4D: OLOF PALMESTRAAT 10, DELFT, NL, 2616 LR
# E4R: MIRAMSTRASSE 87, KASSEL, DE, 34123
# E4Y: 35 FU HSING 2ND ROAD, 1F,(R103), 4F & 5F GUEISHAN, LI JIH BUILDING, TAOYUAN, TW, 333
# E5E: TOWER 115, PRIBINOVA 25, FLRS 20, 21, 22, 23, 24, BRATISLAVA, SK, 81109
# E5F: 41 CHRISTOPHOR COLUMB BLVD, PORSCHE CENTER, BLDG 41, SOFIA, BG, 1592
# E5H: NO. 307, SEC. 2 MINSHENG RD, 15F, YUN HE BLDG, WEST CENTRAL DISTRICT, TAINAN, TW, 700
# E5K: 11 BOULEVARD DU MONT D'EST, NOISY-LE-GRAND, FR, 93881
# E5T: PLOT NO 3 EPIP(WHITEFIELD) IND AREA, FIRST TECH PLACE, HOODI VILLAGE, KRISHNARAJAPURAM HUBLI, BANGALORE, KA, IN, 560066
# E5U: PLOT NO. 26 BLK A, SECTOR 62, GAUTAM BUDH NAGAR, NOIDA, UP, IN, 201309
# E6B: 269 WUYI ROAD, NO.16 BUILDING, DALIAN, 21, CN, 110623
# E6G: 1-2-27 SHIROMI CHUO-KU, OSAKA, JP, 540-0001
# E6H: 5 JALAN SS21/39 DAMANSARA UPTOWN, UNITS 901 B, C AND D, PETALING JAYA, 10, MY, 47400
# E6J: IDA BUSINESS PARK, DANGAN, GALWAY, IE
# E6K: 5300 CORK AIRPORT BUSINESS PARK, KINSALE ROAD, CORK, IE
# E6M: UL.ARMII KRAJOWEI 16, KRAKOW, PL, 30150
# E6R: 1-3, KAIGANTOORI, NAKA-KU, YOKOHAMA, JP, 231-0002
# E6S: 1-18-5 TOMIGAYA, SHIBUYA-KU, TOKYO, JP, 151-0063
# E6T: 1-10-5 MARUYAMADAI, WAKOH, JP, 351-0112
# E6Z: 1 BIS AVENUE GULF STREAM, PORNICHET, FR, 44380
# E7A: B4 SURVEY NO 66/1 RAIDURGA VILLAGE, SERILINGAMPALLI MANDAL, RANGA REDDY DISTRICT, HYDERABAD, TS, IN, 500032
# E7B: LEVEL 9, GLOBAL SWITCH HOUSE, 3 NUTMEG LANE, LONDON, GB, E14 2AX
# E7E: 340 ALBERT STREET, 16TH FLOOR, CONSTITUTION SQUARE, TOWER III, OTTAWA, ON, CA, K1R 7Y6
# E7F: RAJIV GANDHI INFOTECH PK PHASE 2, PLOT NO PL-3 MIDC, HINJEWADI, VILLAGE LIMIT OF MARUNJI, PUNE, MH, IN, 411057
# E7L: 4-2-5 MINAMIYAWATA, ICHIKAWA, JP, 272-0023
# E7U: 300 ACACIA ROAD, DARRENWOOD, RANDBURG, ZA, 2198
# E7Y: NEPFÜRDÖ UTCA 22, DUNA TOWER, BUDAPEST, HU, 1138
# E8I: 399 KEYUAN RD, ZHANGJIANG CHUANGXIN, NO. 10 BUILDING, ZHANGJIANG HIGH TECH PARK, SHANGHAI, 31, CN, 201203
# E8L: BUSINESS PARK SOFIA, BUILDING 5, SOFIA, BG, 1715
# E8Q: SAVOY ARCADE, F-11 MARKAZ, 2 ND/ 3 RD FLOOR, ISLAMABAD, PK, 44000
# E8R: HIGH TECH CAMPUS 68, EINDHOVEN, NL, 5656 AE
# E8S: 18-8 KAJIYACHO, KAGOSHIMA, JP, 892-0846
# E9A: AVE GENERAL BARI 85, PROVIDENCIA, SANTIAGO DE CHILE, RM, CL, 750-0261
# E9B: BALCARCE 479, 1ST FLOOR, CAPITAL FEDERAL, C, AR, C1064AAI
# E9C: TECHNICKA 17, BRNO, CZ, 61600
# E9D: EPIGMENIO GONZALEZ ST., COLONIA PARQUES INDUSTRIALES, QUER?TARO, QUE, MX, 76346
# E9E: 700 JINYU ROAD, BUILDING D, 2F, UNIT 201, JINQIAO EXPORT PROCESSING ZONE, PUDONG, SHANGHAI, 31, CN, 201206
# E9F: 17 AVENUE DE L'EUROPE, BOIS COLOMBES CEDEX, FR, 92275
# E9G: 10 CORIOLAN BREDICEANU STR., TIMISOARA, RO, 300011
# E9K: 6 SPARTAKOVSKAYA STREET, 8TH FLOOR, OFFICE 47 - 49, KAZAN, RU, 420107
# E9M: 8-10 AKINE HIGASHIMACHI, SHIMONOSEKI, JP, 751-0877
# E9Q: 3500, JALAN TEKNOKRAT 3, CYBERJAYA, 10, MY, 63000
# E9R: 28 ZHONGGUANCUN SOFTWARE PARK, 8 DONGBEIWANG WESTERN ROAD, 1-3F, NO 28 BUILDING, BEIJING, 11, CN, 100193
# E9S: VISHWAROOP IT PARK, PLOT NOS 34, 35 & 38 IN SECTOR NO. 30/A OF IIP,OPPOSITE VASHI RAILWAY ST, NAVI MUMBAI, MH, IN, 400705
# E9T: BINNINGERSTR. 2, MÜNCHENSTEIN, CH, 4142
# ECL: 21, CHEMIN DE LA SAUVEGARDE, ECULLY, FR, 69132
# ECR: 2929 N CENTRAL AVE, PHOENIX, AZ, US, 85012-2727
# EOP: 100 E PRATT ST, BALTIMORE, MD, US, 21202-1009
# EP3: 160 EMERALD ST, SUITE 10, KEENE, NH, US, 03431-3619
# EQ3: 71 S WACKER DR, CHICAGO, IL, US, 60606-4637
# EQU: AV DIEGO DE ALMAGRO N 32-48 Y WHIM, QUITO, P, EC, 593-2
# ER4: 400 RENAISSANCE CENTER, SUITE 2710, DETROIT, MI, US, 48243-1675
# ER5: 227 W TRADE ST, SUITE 500, CHARLOTTE, NC, US, 28202-1675
# ERA: PARSEVALSTR 8-10, ERFURT, DE, 99092
# EV7: 9598 PROTOTYPE COURT, SUITE B, RENO, NV, US, 89521-3950
# F06: NIEUWBRUGSTRAAT, 91, MACHELEN, BE, 1830
# F0A: 3-69-2 KOJIMACHO, CHOFU, JP, 182-0026
# F0F: 2 RUE MICHAËL FARADAY, IMMEUBLE AMPERE, BT.B, SAINT HERBLAIN, FR, 44800
# F0G: PLOT NO 19 BLOCK B SECTOR 62 GAUTAM, NOIDA, UP, IN, 201309
# F0H: NIRLON KNOWLEDGE PARK PERMANENT SPA, MUMBAI, MH, IN, 400063
# F0S: 1251, CHIPYEONG-DONG SEO-GU, OCEAN BUILDING 8F, GWANGJU, 29, KR, 641744
# F0T: 980-3 YEONGTONG-DONG, YEONGTONG-GU, DIGITAL EMPIRE BUILDING 902,, SUWON, 41, KR, 433702
# F1A: 32ND STREET, BONIFACIO GLOBAL CITY, 28TH FLOOR ONE WORLD PLACE BUILDING, TAGUIG CITY, 00, PH, 1634
# F1B: 8806 MAIN ST, 1ST FLOOR, BLDG A, FLORENCEVILLE, NB, CA, E7L 3G2
# F1C: 35 RUE BECQUEREL, BATIMENT N°13 - RDC, BELFORT, FR, 90000
# F1E: 6-2-12 TOYOSU, KOTO-KU, TOKYO, JP, 135-0061
# F1G: 273 PYRMONT STREET, ULTIMO, SYDNEY, NSW, AU, 2007
# F1H: LEONARD-HEISSWOLF-STRASSE 4, FRANKFURT, DE, 65936
# F1I: PARQUE TECNOL?GICO INNOVACI?N EL MA, KM 2-200, LATERAL CARRETERA ESTATAL 431, QUER?TARO, QUE, MX, 76246
# F1L: 2525 RUE CANADIEN, DRUMMONDVILLE, QC, CA, J2C 7W1
# F1M: VIA MONZORO 101-105, DATA 4, BUILDING DC02, CORNAREDO, MI, IT, 20010
# F1N: RONDEBELTWEG 62, ALMERE, NL, 1329 BG
# F1P: 10 DUNDAS ST. E., SUITE 600, TORONTO, ON, CA, M5B 2G9
# F1R: GABOR DENES UTCA 2, INFOPARK D, BUDAPEST, HU, 1117
# F1V: RESHETNIKOVA STREET, BUILDING 14, LITER A, SAINT PETERSBURG, RU, 196105
# F1W: HIGHVELD TECHNOPARK, 3 BAUHINIA STREET, CENTURION, PRETORIA, ZA, 0157
# F1X: WITS RESEARCH LAB, 47 JUTA STREET, BRAAMFONTEIN, JOHANNESBURG, ZA, 2001
# F1Y: 6303 AIRPORT ROAD, SUITE 500, MISSISSAUGA, ON, CA, L4V 1R8
# F2A: RAS AL KHOR RD, DUBAI DESIGN DISTRICTBUILDING 8, 4TH FLOOR, DUBAI, AE, 27242
# F2C: 2217-11 HAYASHICHO, TAKAMATSU, JP, 761-0301
# F2D: 111 MACQUARIE STREET  , RESERVE BANK BUILDING,LEVEL 6, SUITE 2 & 3  ,, HOBART, TAS, AU, 7000
# F2G: GLOBE HOUSE, PLOT 8 WARWICK TECHNOL, GALLOWS HILL, WARWICK, GB, CV34 6NZ
# F2H: MCKESSON BUILDING. WALKERGATE HOSPI, BENFIELD ROAD, NEWCASTLE UPON TYNE, GB, NE6 4PZ
# F2I: VIA CARLO VENEZIANI 58, ROMA, RM, IT, 00148
# F2J: SKROBARENSKA 1, CTP VELOCITY, BRNO, CZ, 61700
# G8D: CAIRO-ALEXANDRIA ROAD KM 28, CAIRO, EG
# G8H: GRD & 1ST FLOOR, ST ANDREW'S HOUSE, WEST STREET, WOKING, GB, GU21 6EB
# G8J: STRADA CORALILOR 22, SECTOR 1, PETROM, BUCHAREST, RO, 13329
# G8M: 2-27-8 MEIEKI , NISHI-KU, NAGOYA, JP, 451-0045
# G8N: 1-1 TSUKIJI, KISARAZU, JP, 292-0835
# G8O: 55 MOO 7,?SUTHEP SUB DISTRICT, MUANG DISTRICT, CHIANG MAI, 50, TH, 50200
# G8Q: SOLHEIMSGATEN 11, BERGEN, NO, 5058
# G8T: 6 TAMPINES INDUSTRIAL AVENUE 5, SINGAPORE, SG, 528760
# G9C: NORTHERN IRELAND SCIENCE PARK, LEGACY BUILDING, QUEENS ROAD, QUEENS ISLAND, BELFAST, GB, BT3 9DT
# G9J: SURVEY NO 144 /145, SAMRAT ASHOK PA, BUILDING 6, 4TH FLOOR,, PUNE, MH, IN, 411006
# G9O: 27,NORTH 4 RING MID ROAD, BEICHEN X, PANGU PLAZA, BEIJING, 11, CN, 100101
# G9P: YATAI STREET, TONGGANG INTERNATIONA, CHANGCHUN, 22, CN, 130022
# G9T: CHARLES-DARWIN-RING 2, ROSTOCK, DE, 18059
# G9U: 27/29 HONG CHUAN EAST ROAD, GAO XIN, SO2 BUILDING?DALIAN TIAN SOFTPARK, DALIAN, 21, CN, 116044
# G9V: MAGDALENE CENTRE & SADLEY BUILDING, OXFORD SCIENCE PARK, OXFORD, GB, OX4 4GA
# G9W: 2 PLACE DE LA REPUBLIQUE, IMMEUBLE LE REPUBLIQUE, NANCY, FR, 54000
# G9X: ANADOLU CADDESI 12, SALHANE IS MERKEZI, IZMIR, 35, TR, 35220
# G9Z: JINYE FIRST STREET, C, XIAN, 61, CN, 710075
# GBW: 2073 LAWRENCE DR, DE PERE, WI, US, 54115-9106
# GFD: GREENFORD GREEN BUSINESS PARK, GREEN PARK WAY, GREENFORD, GB, UB60AD
# GLN: 400 N BRAND BLVD, GLENDALE, CA, US, 91203-2311
# GR8: 400 N ACADEMY ST, GREENVILLE, SC, US, 29601-2044
# GRB: 284 KIFISSIAS AVE. CHALANDRI, ATHENS, GR, 15232
# GS4: 11550 STONEHOLLOW DR, AUSTIN, TX, US, 78758-3166
# GS9: 257 FULLER ROAD, ALBANY, NY, US, 12203
# GT7: 2300 DULLES STATION BLVD, DULLES STATION WEST FLOORS 1,2,4,5, HERNDON, VA, US, 20171-6133
# GT8: 5325 HELLYER AVE, FLOOR 2, SAN JOSE, CA, US, 95138-1013
# GU0: 11550 ASH STREET, SUITE 350, LEAWOOD, KS, US, 66211-7813
# GU2: 700 LOCUST ST, FLOORS 5-9, DUBUQUE, IA, US, 52001-6838
# GU5: 195 CRESCENT ROAD, EAST LANSING, MI, US, 48824
# GU9: 11111 SUNSET HILLS ROAD, 1ST & 3RD FLOORS, RESTON, VA, US, 20190-5327
# GUA: 120 FATHER DUENAS AV, AGANA, GU, 96910
# GUE: BAHNHOFSTRASSE 4, MATTENHOF WEST, GUEMLIGEN, CH, 3073
# GV8: 2000 N 14TH ST, SUITE 320 COURTHOUSE PLAZA, ARLINGTON, VA, US, 22201-2573
# GW0: 14523 SW MILLIKAN WAY, BEAVERTON, OR, US, 97005-2344
# GW1: 4600 25TH AVENUE, NE, SALEM, OR, US, 97301
# GW3: 600 14TH ST NW, HAMILTON SQUARE FLOORS 2 & 3, WASHINGTON, DC, US, 20005-2012
# GW6: 15036 CONFERENCE CENTER DR, SUITE 406, EAST, CHANTILLY, VA, US, 20151-3849
# GX2: 135 NATIONAL BUSINESS PKWY, SUITE 100, ANNAPOLIS JUNCTION, MD, US, 20701-1019
# GX5: 11300 MARTIN LUTHER KING ST, N, SUITE 315, SAINT PETERSBURG, FL, US, 33716-2325
# GY3: 310 STATE ROUTE 956, HILLTOP OFFICE COMPLEX, ROCKET CENTER, WV, US, 26726-9222
# GZ4: 2810 LEMONE INDUSTRIAL BLVD, COLUMBIA, MO, US, 65201
# GZ6: 4600 LAKEHURST CT, 6060 BRITTON PW, DUBLIN, OH, US, 43016
# GZ7: 4600 LAKEHURST COURT, 6060 BRITTON PW, DUBLIN, OH, US, 43016
# H0D: HAFETZ HAIM 36, NATANIA, M, IL, 42463
# H0E: 9-7-1 TSUKISAMU-HIGASHI 2, TOYOHIRA, SAPPORO, JP, 062-0052
# H0I: UNITECH INFO SPACE, PLOT NO. - 20, SECTOR 135 TAJ EXPRESSWAY, NOIDA, UP, IN, 201304
# H0N: NAN HAI REVENUE, SHE KOU, NAN SHAN, 1057, TECHNOLOGY BUILDING II, SHENZHEN, 44, CN, 518000
# H0Q: AVE. ANDRES ARAMBURU Nº1115-1121-11, URB. EL PALOMAR, SAN ISIDRO, LIMA, LIM, PE
# H0U: WUSI ROAD, SINO PLAZA, FUZHOU, 35, CN, 350001
# H0Y: BISMARCKALLEE 7F, FREIBURG, DE, 79098
# H1D: 3-3-5 TSUBOKAWA, NAHA, JP, 900-0025
# H1H: POLANERBAAN 1, WOERDEN, NL, 3447 GH
# H1I: BULEVARD 21 DECEMBRIE 1989 NO.104, CLUJ-NAPOCA, RO, 400604
# H1P: SCHOTTEGATWEG OOST 18, GROUND FLOOR, WILLEMSTAD, CW
# H1Q: RUA RAINHA GINGA, 87, 10TH FLOOR, DE BEERS BUILDING, LUANDA, AO
# H1S: 90 SHEPPARD AVE E, 5TH FLOOR, TORONTO, ON, CA, M2N 3A1
# H1W: 25 SINMUNNO 1GA JONGNO GU, 5F JUNGWOO BUILDING, SEOUL, 11, KR, 110061
# H2E: MAIN PRAHALADNAGAR CORPORATE ROAD,, TITANIUM, UNIT 001- GROUND FLOOR,, AHMEDABAD, GJ, IN, 380015
# H2F: 999, YANGFAN ROAD, HI-TECH ZONE, BUILDING, NINGBO, 33, CN, 315100
# H2I: 1463-1 WOO DONG, HAEUNDAE GU, CENTUM SCIENCE PARK, 16F, PUSAN, 26, KR, 706715
# H2J: 7-4 YONGHO DONG, UICHANG GU, KYUNGNAM MOOYEOK HOIGWAN, 4F, CHANGWON, 48, KR, 641840
# H2M: DLF IT PARK II, NEW TOWN RAJARHAT, 8TH,9TH,10TH & PART OF 11TH FLOOR,BLOCK - 1, TOWER C, KOLKATA, WB, IN, 700156
# H2Q: 89 RUE PAFEBRUCH, WESTSIDE VILLAGE - IMMEUBLE CYTISE BT.C, CAPELLEN, LU, 8308
# H2R: 45 GODERICH RD, UNIT 7A, HAMILTON, ON, CA, L8E 4W8
# H2S: 17 SAN MIGUEL AVENUE, ORTIGAS CENTE, HANSTON SQUARE, PASIG, 0, PH, 1605
# H2W: 136 CROSBIE RD, ST. JOHN'S, NL, CA, A1B 3K3
# H2Z: 17 RUE DIDIER DAURAT, BATIMENT PLATON SIS PARC DES ALGORITHMES, BLAGNAC, FR, 31700
# H3C: ZHONGSHAN EAST ROAD 303, WORLD TRADE PLAZA HOTEL, SHIJIAZHUANG, 13, CN, 050011
# H3K: OPPOSITE MALAYALA MANORAMA, PANAMPI, FIRST FLOOR, AREEKKAL MANSION, KOCHI, KL, IN, 682036
# H3N: SONGHU ROAD, YANGPU DISTRICT, 308, BUILDING 9, KIC PLAZA, SHANGHAI, 31, CN, 200433
# H3P: 987 BEIJING ROAD, JUN FA CENTER, ZONE B, 7F, YUNNAN PROVINCE, KUNMING, 53, CN, 650225
# H3S: 3 FURZEGROUND WAY, UXBRIDGE, GB, UB11 1EZ
# H3Y: SIVLANDVÆNGET 29, ODENSE, DK, 5260
# H4D: THE ATRIUM L.R. 1/301 LENANA ROAD, KILIMANI, NAIROBI, KE
# H4G: UNIT2 TURING HSE(PRU2), UNIT3, ARKW, FULWOOD CT.FULWOOD BUSINESS PARK. PITTMAN WAY. FULWOOD, PRESTON, GB, PR2 9ZH
# H4I: PA
# H4K: WESTPOINT HOUSE, 5 REDWOOD PLACE, EAST KILBRIDE, GB, G74 5PB
# H4L: E1/1, INFOCITY, CHANDRASEKHARPUR, BHUBANESWAR, OR, IN, 751024
# H4O: PLOT NO. 3, TTC INDUSTRIAL AREA, KA, 6TH OFFICE LEVEL , BUILDING N0.5 THANE, NAVI MUMBAI, MH, IN, 400708
# H4P: LEVEL 5, 204 LYGON STREET, CARLTON,, IBM RESEARCH - AUSTRALIA, LEVEL 5, 204 LYGON STREET, CARLTON, VIC 3053, MELBOURNE, VIC, AU, 3053
# H4Q: POLIZU STREET 56-60, BUCHAREST CORPORATE CENTER, BUCHAREST, RO, 011062
# H4R: TURYNSKA UL. 100, FIAT TYCHY, TYCHY, PL, 43100
# H4S: UL. GRAZYNSKIEGO, 141, FIAT BIELSKO BIALA, FIRST FLOOR, BIELSKO-BIALA, PL, 43300
# H4V: CG
# H5E: 7TH FLOOR, AMANI PLACE, OHIO STREET, DAR ES SALAAM SEAPORT OFFICE PARK, DAR ES SALAAM, TZ
# H5M: 3-1-14 OMORIKITA, OTA-KU, TOKYO, JP, 143-0016
# H5R: 3292 PRODUCTION WAY, BURNABY, BC, CA, V5A 4R4
# H5T: 1-6-1, ROPPONGI MINATO-KU, TOKYO, JP, 106-6018
# HR5: 111 MONUMENT CIRCLE, STE 4450, INDIANAPOLIS, IN, US, 46204-5100
# HR9: 14901 FAA BLVD, FORT WORTH, TX, US, 76155-2220
# HS0: 7700 OLD GEORGETOWN RD, STE 650, BETHESDA, MD, US, 20814-6100
# HS1: 7106 AMBASSADOR RD, STE 110, WINDSOR MILL, MD, US, 21244-2707
# HS2: 6200 S SYRACUSE WAY, STE 300, GREENWOOD VILLAGE, CO, US, 80111-4740
# HS3: 1670 BROADWAY, STE 1000, DENVER, CO, US, 80202-4801
# HS4: 6431 LONGHORN DRIVE, IRVING, TX, US, 75063-2738
# HS5: 500 SANSOME ST, SUITE 450, SAN FRANCISCO, CA, US, 94111-3218
# HS6: 11 E 26TH ST, 21ST FL, NEW YORK, NY, US, 10010-1413
# ...
# J0M: AVENUE KABASELE ( EX AVENUE FLAMBEA, MODERN PARADISE BUILDING, COMMUNE DE LA GOMBE, KINSHASA, CD
# J0P: DOROZHNAYA STR 42, KAZAN, RU, 422624
# J0Q: BM
# J0R: 127 GUO TONG ROAD, TECH CENTER BUILDING 2, SHANGHAI, 31, CN, 200433
# J0T: 28 SYDNEY AVENUE, LEVEL 5, FORREST, ACT, AU, 2603
# J0Y: FOUNTAIN COURT, COX LANE, SUITES 210 AND 230, CHESSINGTON, GB, KT9 1SJ
# J1A: 8-1 FURUJINMACHI, TAKAMATSU, JP, 760-0025
# J1B: JONGRO-47, JONGNO-GU, 12F, STANDARD CHARTERED KOREA HQ BUILDING, SEOUL, 11, KR, 110702
# J1C: 10 GUKJEGEUMYUNG-RO, YEONGDEUNGPO-G, 6F-14F, 3IFC, SEOUL, 11, KR, 150945
# J1D: BEN GURION UNIVERSITY, ALON BUILDING FOR HIGH TECH, FLOOR 5, NEGEV BEER SHEVA, IL, 84105
# J1F: 1-1 KITA 1 JONISHI 7, CHUO-KU, SAPPORO, JP, 060-0001
# J1G: 1, DONG JI AVENUE, SCIENCE AND TECHNOLOGY TRANSFORMATION CENTER BLDG 10, NANJING, 32, CN, 211100
# J1I: 90 GRAYSTON DRIVE, SANDTON, JOHANNESBURG, ZA, 2031
# J1K: RA??NOVO N?B?E?? 42,, PRAHA, CZ, 128 00
# J1O: 72 RADNOR DRIVE, DEER PARK, SUITES 110 AND 130, MELBOURNE, VIC, AU, 3032
# J1Q: 371 GOUGH ROAD, SUITE 130, MARKHAM, ON, CA, L3R 4B6
# J1S: 163 BIS AVENUE DE BRETAGNE, IMMEUBLE LE BRETAGNE, LILLE, FR, 59000
# J1U: INNOVATION CENTRE, KECKWICK LANE, DARESBURY, WARRINGTON, GB, W4A 4AD
# J1X: 11, ZHENG GAO ROAD, CHINA AVIATION CENTER BUILDING B, SHANGHAI, 31, CN, 200433
# J1Y: GODESBERGER ALLEE 125-127, BONN, DE, 53175
# J1Z: AM WEIHER 24, KELSTERBACH, DE, 65451
# J2C: WEG BEIM JÄGER 193, HAMBURG, DE, 22335
# J2D: VON GABLENZ STR. 2-6, KÖLN, DE, 50679
# J2E: NORDALLEE 25, FLUGHAFEN MÜNCHEN, MÜNCHEN, DE, 85356
# J7X: ATRYUM CENTER, RUE DE OUAKAM, 1ST FLOOR, DAKAR, SENEGAL, DAKAR, SN
# J8C: 5 KITA 5 NISHI 2, CHUO-KU, SAPPORO,, SAPPORO, JP, 060-0005
# J8D: 2889 W ASHTON BOULEVARD, SUITE 400, LEHI, UT, US, 84043
# J8F: 082 VODACOM BOULEVARD VODAVALLEY, MIDRAND, ZA, 1687
# J8J: 2-1 KITA1JONISHI, CHUO-KU, SAPPORO, JP, 060-0001
# J8K: AV. D. JO?O II, LOTE 1.04.01, PARQUE DAS NA??ES, LISBOA, 11, PT, 1998 ? 017
# J8L: UNIT 18 BRUNEL WAY, SEGENSWORTH INDUSTRIAL ESTATE, FAREHAM, GB, PO15 5TX
# J8M: PLANGE MÜHLE 1, DÜSSELDORF, DE, 40221
# J8N: LC
# J8S: MEDIMURSKA 28, VARAZDIN, HR, 42000
# J8T: JL. IR. H. JUANDA NO.7 , SENTUL CIT, BOGOR, JB, ID, 16810
# J8V: CARL-BLUM-STR. 3, WELS, AT, 4600
# J8W: N LIBERATION LINK ROAD,, STANBIC HEIGHTS, ACCRA, GH
# J8X: VIA G. ZANCHI 22, BERGAMO, BG, IT, 20068
# J8Y: HEIASVINGEN 9  , FETSUND, NO, 1900
# J8Z: 611-2 SAMPYEONG-DONG BUNDANG-GU , SEONGNAM, 41, KR, 463-400
# J9A: VIA LOMBRADIA 2A , PESCHIERA BORROMEO, MI, IT, 20068
# J9B: KM 3.98, ANILLO VIAL RIO FRIO., ZONA FRANCA SANTANDER. EDIFICIO MACAREGUA., FLORIDABLANCA, CO
# J9C: UNIT 801, EXPO MANSION, NO. 8 BUSINESS OUTER RING, ZHENGDONG NEW DISTRICT, ZHENGZHOU, 41, CN, 450018
# J9D: BLOCK I CHOKKANAHALLI VILLAGE, THANISANDRA MAIN ROAD, BANGALORE, KA, IN, 560064
# J9E: VIA LIVIO CAMBI PANTIGLIATE, MILANO, MI, IT, 20151
# J9F: VIA MONTE BIANCO 18, VERONA, VER, IT, 37132
# J9G: VIA MOLFETTA 101, ROMA, RM, IT, 00171
# J9H: VIA NIZZA 150, TORINO, TO, IT
# J9K: THE CATALYST, BAIRD LANE, HESLINGTO, YORK, GB, YO10 5GA
# J9L: VIA DEL LAVORO 42, BOLOGNA, BO, IT
# J9N: 61 QUAI LAWTON, BORDEAUX, FR, 33300
# JFC: 3220 WEST EDGEWOOD DRIVE, SUITE G, JEFFERSON CITY, MO, US, 65109-6883
# K0C: 1-5-1 WAKINOHAMAKAIGANDORI, CHUO-KU, KOBE, JP, 651-0073
# K0D: VANCE BUSINESS HUB,GACHIBOWLI VILLA, HYDERABAD, TS, IN, 500081
# K0F: RATHAUSSTRASSE 19, FLENSBURG, DE, 24937
# K0G: 2 ARLINGTON SQUARE, DOWNSHIRE WAY, BRACKNELL, GB, RG12 1WA
# K0H: 200 BROOK DRIVE, READING, GB, RG2 6UB
# K0I: 1 FORE STREET, LONDON, GB, EC2Y 9DT
# K0J: CHELTENHAM OFFICE PARK, HATHERLEY LANE, CHELTENHAM, GB, GL51 6SH
# K0M: SANDAKERVEIEN 121, OSLO, NO, N-0483
# K0O: 69/6 SYED MARATIB ALI ROAD, LAHORE, PK, 54660
# K0Q: LEVELS 3 & 4, 30 GAUNT STREET, AUCKLAND, AUK, NZ, 1010
# K0R: 10 RUE DE MONTOYER, BRUSSELS, BE, 1000
# K0S: ZAC DE LA HAUTE DEULE - ILOT 12, RUE DES TEMPLIERS EURATECHNOLOGIES, LILLE, FR, 59000
# K0T: PLOT NO 21 TECHZONE IV, GREATER NOIDA, UP, IN, 201306
# K0W: ANDRASSY UT 39, BUDAPEST, HU, 1061
# K0X: 1 KING STREET WEST, HAMILTON, ON, CA, L8P 1A4
# K0Y: DONAU-CITY-STRASSE 7, WIEN, AT, 1220
# K0Z: 2-13, 1 CHOME, TSUTSUJIGAOKA, MIYAG, SENDAI, JP, 983-0852
# K1B: 101 COLLEGE STREET, TORONTO, ON, CA, M5G 1L7
# K1C: NSL ARENA, BLOCK 1, WING B, 2ND FLO, HYDERABAD, TS, IN, 500039
# K1D: 1649 WEST FRANKFORD ROAD, CARROLLTON, TX, US, 75007
# K1E: 44610 GUILFORD DRIVE, ASHBURN, VA, US, 20147-6057
# K1F: 21741 RED RUM DRIVE, ASHBURN, VA, US, 20147
# K1G: NGD CELTIC WAY, MARSHFIELD, DUFFRYN, NEWPORT, GB, NP10 8BE
# K1H: JL. TEKNO RAYA BLOK D, NO.8, KOMPLE, TANGERANG SELATAN, BAN, ID, 15313
# K1I: 9 ET 10 RUE DE L'ABBE STAHL, MARCQ EN BAROEUL, FR, 59700
# K1J: 1151 CHARLES ST. WEST, KITCHENER, ON, CA, N0B 1K0
# K1K: NO. 2 HANZHONG RD., GULOU DISTRICT, NANJING, 32, CN, 210005
# K1L: BUILDING A102, ARK DATA CENTRES, CO, FARNBOROUGH, GB, GU14 0LH
# K1M: 12 LIVERPOOL ROAD, SLOUGH TRADING E, SLOUGH, GB, SL1 4SS
# K1O: 1275 AVENUE DES CANADIENS-DE-MONTRE, MONTREAL, QC, CA, H3B 5E8
# K1P: 3 BRINDLEY PLACE BIRMINGHAM, WEST M, BIRMINGHAM, GB, B1 2JB
# K1Q: JOSIPA MAROHNI?A 1, ZAGREB, HR, 10000
# K1R: KAREN BLIXENS PLADS 8 KOBENHAVN S, COPENHAGEN, DK, 2300
# K1S: 181 THE CLOUD TOWER A,, RATCHADA-RAMINTRA RD., NUAN, BANGKOK, 10, TH, 10240
# K1T: JL. LURAH KAWI, CILEGONG, JATILUHUR, PURWAKARTA, JB, ID, 41152
# K1V: 1 PLACE VILLE MARIE22ND FLOOR, MONTREAL, QC, CA, H3B 2B6
# K1W: KANALVEIEN 105, BERGEN, NO, 5068
# K1X: GADOLLAPLATZ 1, GRAZ, AT, 8010
# K1Y: REGUS NOTTINGHAM CITY GATE EAST, TOLL HOUSE 6TH FLOOR, TOLLHOUSE HILL, NOTTINGHAM, GB, NG1 5FS
# K1Z: AL RAHA, CANAL STREET, ABU DHABI, AE, 38616
# K2B: 201_201A PRINCES EXCHANGE, PRINCES SQUARE, LEEDS, GB, LS1 4HY
# K2C: GYRON CAMPUS, SPRING WAY, HEMEL HEMPSTEAD, GB, HP2 7TN
# K2D: 441 ST. KILDA ROAD, PART LEVEL 1, MELBOURNE, VIC, AU, VIC 3004
# K2E: 1 TEMPLAR ROAD, ERSKINE PARK, SYDNEY, NSW, AU, 2759
# K2F: BUILDING H, ESCHBORNER LANDSTRASSE, FRANKFURT, DE, 60489
# K2G: WEISSMULLERSTRASSE 40, FRANKFURT, DE, 60314
# K2H: 60 BISHOP DRIVE, FREDERICTON, NB, CA, E3C 1B2
# K2I: EXPO PLAZA 10, HANNOVER, DE, 30539
# K2J: ITSUKAICHIKO, SAEKI-KU, HIROSHIMA, JP, 731-5161
# K2K: JINDRISSK? 937/16, PRAHA, CZ, 11000
# K2L: 3339 - 3403 GRIFFITH STREET, MONTREAL, QC, CA, H4T 1W5
# K2M: 800 DE LA GAUCHETIERE STREET WEST, MONTREAL, QC, CA, H5A 1K6
# K2O: RUE HENRI M. SCHNADT 8, CLOCHE D'OR, LUXEMBOURG, LU, 2530
# K2P: 850 E COLLINS BLVD, RICHARDSON, TX, US, 75081-2250
# K2Q: 77 KING STREET WEST, TORONTO, ON, CA, M5K 1K7
# K2R: HURBANOVA 9A, BANSKA BYSTRICA, SK, 97401
# K2V: 1-20 SAKURAMACHI, CHUO-KU, KUMAMOTO, JP, 860-0805
# K2W: AV. ANTEA 1088, EDIFICIO BUSINESS P, SAN FRANCISCO JURIQUILLA, QUERÉTARO, QUE, MX, 76127
# K2X: NO. 51&53, SEC. 2, GONGYI ROAD, UNI, TAICHUNG, TW, 403
# K2Y: 15C ORHIDEELOR STREET, BUCHAREST, RO, 060071
# K2Z: STR. GARII NR. 21, CLUJ-NAPOCA, RO, 400267
# K3A: CENTRE D'AFFAIRES - LA CONCORDE, 24, RUE LAMARTINE, EYBENS, FR, 38320
# K3D: CENTRE D'AFFAIRES - 7, RUE PIERRE S, REIMS, FR, 51430
# K3E: SUNDTKVARTALET, LAKKEGATA 53, OSLO, NO, 0187
# K3F: KISTAGÅNGEN 6, KISTA, SE, 164 40
# K3G: 484-19 ASAHIMACHI, MATSUE, JP, 690-0003
# K3H: LEVEL 16, CHARLES DARWIN CENTRE, 19 SMITH STREET MALL, DARWIN, NT, AU, 0800
# K3J: VIA G. PERONI 282-296, ROMA, ROM, IT, 00131
# K3K: 3552 JALAN TEKNOKRAT 6, CYBERJAYA, 10, MY, 63000
# K3M: 111-2 ITAYAMACHI, NAKA-KU, HAMAMATSU, JP
# KDC: 1630 LONG POND RD, ROCHESTER, NY, US, 14626-1496
# KGF: HANS-SACHS-STRASSE 16, KLAGENFURT, AT, 9020
# KOL: GUSTAV-HEINEMANN-UFER 120, KÖLN, DE, 50968
# LEK: KOHLGARTENSTRASSE 11, LEIPZIG, DE, 04315
# LRB: 111 CENTER ST, LITTLE ROCK, AR, US, 72201-4402
# PIC: 1551 S WASHINGTON AVE, PISCATAWAY, NJ, US, 08854-6700
# PKS: 145 BOARDMAN RD, POUGHKEEPSIE, NY, US, 12603
# PLA: 11400 BURNET RD, AUSTIN, TX, US, 78758-3493
# PLB: 1000 RIVER ST, ESSEX JUNCTION, VT, US, 05452-4299
# PLE: IBM 1701 NORTH ST, ENDICOTT, NY, US, 13760-5553
# PLL: 745 WEST NEW CIRCLE RD, BUILDING 200 & BUILDING 202, LEXINGTON, KY, US, 40511-1846
# PLM: AV. PROLONGACION JAVIER PRADO ESTE, LA MOLINA, LIMA, LIM, PE, 6230
# PLP: 2455 SOUTH RD, POUGHKEEPSIE, NY, US, 12601-5400
# PLR: 3605 HWY 52 N, ROCHESTER, MN, US, 55901-1407
# PLT: 9000 S RITA RD, TUCSON, AZ, US, 85744-0002
# PNO: 1515 POYDRAS ST, SUITE, NEW ORLEANS, LA, US, 70112-3723
# PNY: 334 ROUTE 9W, PALISADES, NY, US, 10964-1200
# POZ: ZIEBIECKA 35, POZNAN, PL, 60164
# PPT: BOULEVARD POMARE, RESIDENCE PAOFAI, PAPEETE, PF, 98713
# PTK: RUA GONCALO SAMPAIO 157, PORTO, 13, PT, 4150-367
# PTT: 11 STANWIX ST, FLOOR 9, PITTSBURGH, PA, US, 15222-1312
# PUR: 654 MUNOZ RIVERA AVE, 8TH FL, STE 805, HATO REY, PR, 00918
# QIC: ROCADE DE ZEPHIR, CENTRE CIAL DE LA ROCADE, CAYENNE, GF, 97300
# RCX: PO BOX 218, 1101 KITCHAWAN RD, YORKTOWN HEIGHTS, NY, US, 10598
# RDS: 201 W NORTH RIVER DR, SPOKANE, WA, US, 99201-2284
# RET: 11107 SUNSET HILLS RD, RESTON, VA, US, 20190-5309
# RHT: 3222 40TH AVE NW, ROCHESTER, MN, US, 55901-1767
# RIC: 9201 ARBORETUM PKWY, SUITE 300, RICHMOND, VA, US, 23236-5402
# RIG: BAUSKAS STR 58A, RIGA, LV, 1004
# RLO: 8401 GREENSBORO DR, 1ST FL, MCLEAN, VA, US, 22102-3598
# RML: VIA DEI LUCCHESI 26, ROMA, RM, IT, 00187
# RMS: 95/97 BD DU GENERAL LECLERC, REIMS, FR, 51097
# RPL: 3039 E CORNWALLIS RD, P.O. BOX 12195, RESEARCH TRIANGLE PARK, NC, US, 27709-2195
# RSA: 590 MADISON AVE, NEW YORK, NY, US, 10022-2524
# RV3: MUROOR STREET, BUILDING "C" ; 1ST FLOOR, ABU DHABI, AE, 2720
# SAN: 911 CENTRAL PKWY N, SUITE 100, SAN ANTONIO, TX, US, 78232-5053
# SBK: 76 UPPER GROUND, LONDON, GB, SE19PZ
# SBR: 150 KETTLETOWN RD, SOUTHBURY, CT, US, 06488-2600
# SDN: 65 RUE STE MARIE, SAINT-DENIS DE LA REUNION, RE, 97477
# SEA: 1200 5TH AVE, SEATTLE, WA, US, 98101-3132
# SEC: LINDHOLMSALLEN 10, (MAIL ADDRESS:BOX 195, 40123 GÖTEBORG), GÖTEBORG, SE, 41755
# SEI: KISTA ALLÉVÄG 60, (MAIL ADDRESS: 16492 STOCKHOLM), KISTA, SE, 16455
# SEK: STORGATAN 44, (MAIL ADDRESS: 85173 SUNDSVALL), SUNDSVALL, SE, 85230
# SFC: 425 MARKET ST, SAN FRANCISCO, CA, US, 94105-2406
# SGA: W TOWER, 60 CITY RD, SOUTHGATE, MELBOURNE, VIC, AU, 3006
# SHC: 389 GANG AO ROAD, WAI GAO QIAO FREE TRADE ZONE, SHANGHAI, 31, CN, 200131
# SHE: ISTC/ITPC/CPC, GREAT WALL COMPUTER, SCIENCE & INDUSTRY PARK, NANSHAN DIST, SHENZHEN, 44, CN, 518057
# SIO: 4916 TECHNOPOLIS DR, BUILDING, SIOUX FALLS, SD, US, 57106-4230
# SJH: 650 HARRY ROAD, ALMADEN RESEARCH CENTER, SAN JOSE, CA, US, 95120-6099
# SJS: 555 BAILEY AVE, SAN JOSE, CA, US, 95141-1003
# SLM: 325 JAMES S MCDONNELL BLVD, HAZELWOOD, MO, US, 63042-2513
# SMB: 4205 S MIAMI BLVD, DURHAM, NC, US, 27703-9141
# SMT: 2710 S GATEWAY OAKS DR, SUITE 200, SACRAMENTO, CA, US, 95833-4307
# SOB: 36, DRAGAN TZANKOV BLVD, INTERPRED WORLD TRADE CENTER, SOFIA, BG, 1057
# SPM: 3315 E RIDGEVIEW, SPRINGFIELD, MO, US, 65804-4083
# SRN: 4000 EXECUTIVE PKWY, SAN RAMON, CA, US, 94583-2457
# STR: 48 RUE DU FAUBOURG DE SAVERNE, IMMEUBLE L'AVANCE, STRASBOURG, FR, 67084
# SUF: P.O. BOX 700, 299-300 LONG MEADOW RD, STERLING FOREST, NY, US, 10979-0700
# SUM: 1650 SUMMIT LAKE DR, TALLAHASSEE, FL, US, 32317-7936
# SW5: 486 SIN-DONG, YOUNGTONG-GU, 3F, DIGITAL EMPIRE2 BUILDING, SUWON, 41, KR, 443734
# TAA: 3031 N ROCKY POINT DR WEST, SUITE 500, TAMPA, FL, US, 33607-5878
# TAL: TOOMPUIESTEE 33A, TALLIN, EE, 10149
# THA: SP BLDG, 388 PHAHOLYOTHIN ROAD, PHAYATHAI, BANGKOK, 10, TH, 10400
# TKA: 618 S KANSAS AVE, TOPEKA, KS, US, 66603-3839
# TRF: BUYUKDERE CADDESI LEVENT, ISTANBUL, 34, TR, 34330
# TTT: 6,RUE BRINDEJONC-DES-MOULINAIS, TOULOUSE, FR, 31505
# ULS: SYRLINSTRASSE 38, ULM, DE, 89073
# UPL: PLAZA INDEPENDENCIA 721, MONTEVIDEO, MO, UY, 11000
# UX5: VIA DEL CARROCCIO 6, PERO, MI, IT, 20016
# VCH: AV. ERNESTO BLOHM, EDIFICIO IBM, CHUAO, CARACAS, M, VE, 1060
# VIL: SEIMYNISKIU STR 3, VILNIUS, LT, 09312
# W97: 59 RUE DE LA REPUBLIQUE, VALMY, MONTREUIL-SOUS-BOIS, FR, 93100
# WI3: PAULSTRASSE 12, WINTERTHUR, CH, 8400
# WNM: 18000 W 9 MILE RD, SOUTHFIELD, MI, US, 48075-4009
# WWK: BIRMINGHAM ROAD, WARWICK, GB, CV34 5AH
# Z1A: PARK AZORIM 94 EM HAMOSHAVOT ROAD, KYRIAT ARIE - PETACH TIKVA, PETACH TIKVA, M, IL, 49527
# Z1J: L11 & L7 SEABANK, 12-14 MARINE PARADE, SOUTHPORT, QLD, AU, 4215
# Z3O: NAN KANG (SOFTWARE PARK), E9W&E/E10W,, TAIPEI, TW, 115
# ZRL: SAEUMERSTRASSE 4, RUESCHLIKON, CH, 8803
# ... done

# %%
print('running ...')
   
# store IBM location data in a CSV file
columns = ['geoname_id','country_iso_code','country_name','subdivision_1_iso_code','subdivision_1_name','city_name']
pd.DataFrame(ibmLocations).to_csv('test.ibmLocations.csv', index=False, float_format='%.9g', columns=columns)

# store IBM network data in a CSV file
columns = ['network','geoname_id','latitude','longitude','postal_code']
pd.DataFrame(ibmNetworksIPv4).to_csv('test.ibmNetworksIPv4.csv', index=False, float_format='%.9g', columns=columns)
pd.DataFrame(ibmNetworksIPv6).to_csv('test.ibmNetworksIPv6.csv', index=False, float_format='%.9g', columns=columns)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# Run the next cell to download Internet network and location data from MaxMind:

# %%
print('running ...')

with urlopen(maxmindGeoLite2URL) as response:
    with zipfile.ZipFile(BytesIO(response.read())) as file:
        file.extractall()

# find the newest directory, in case there are old directories left over from previous runs
maxmindDirectory = sorted( [ f for f in os.listdir() if os.path.isdir(f) and f.startswith('GeoLite2-City-CSV') ] )[-1]

# load the MaxMind network and location data 
maxmindNetworksIPv4 = pd.read_csv(maxmindDirectory + '/GeoLite2-City-Blocks-IPv4.csv', header=0, dtype=str)
maxmindNetworksIPv6 = pd.read_csv(maxmindDirectory + '/GeoLite2-City-Blocks-IPv6.csv', header=0, dtype=str)
maxmindLocations = pd.read_csv(maxmindDirectory + '/GeoLite2-City-Locations-en.csv', header=0, dtype=str)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# Run the next cell to merge the MaxMind and IBM data. The merged data will be written into CSV files in the 'merged' directory, using the filenames of the original MaxMind CSV files.

# %%
print('running ...')

# create a directory for the merged MaxMind+IBM CSV files
os.makedirs('merged', exist_ok=True)

# merge the MaxMind and IBM network data and store the result in CSV files

maxmindNetworksIPv4 = maxmindNetworksIPv4[ ~ maxmindNetworksIPv4['network'].str.startswith('9.') ]
mergedNetworksIPv4 = maxmindNetworksIPv4.append(ibmNetworksIPv4)
mergedNetworksIPv4.to_csv('merged/GeoLite2-City-Blocks-IPv4.csv', index=False, float_format='%.9g', columns=maxmindNetworksIPv4.columns)

maxmindNetworksIPv6 = maxmindNetworksIPv6[ ~ maxmindNetworksIPv6['network'].str.startswith('2620:1F7:') ]
mergedNetworksIPv6 = maxmindNetworksIPv6.append(ibmNetworksIPv6)
mergedNetworksIPv6.to_csv('merged/GeoLite2-City-Blocks-IPv6.csv', index=False, float_format='%.9g', columns=maxmindNetworksIPv6.columns)

# merge the MaxMind and IBM location data and store the result in a CSV file
mergedLocations = maxmindLocations.append(ibmLocations)
mergedLocations.to_csv('merged/GeoLite2-City-Locations-en.csv', index=False, float_format='%.9g', columns=maxmindLocations.columns)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# Run the next cell to calculate [geohash codes](https://en.wikipedia.org/wiki/Geohash) for the latitude/longitude coordinates of merged MaxMind and IBM locations. The geohashes, coordinates, and location data will be written into a CSV file in the 'merged' directory named 'GeoLite2-City-Geohashes-en.csv'.

# %%
# %%script false
#
# print('running ...')
#
# # create a frame of locations indexed by ID number
# mergedLocationsIndexed = mergedLocations.set_index('geoname_id')
#
# # create a frame of geographical coordinates, that is, ID number, latitude, and longitude
# mergedCoordinates = mergedNetworks[['geoname_id','latitude','longitude']].drop_duplicates()
#
# # merge location and coordinate data and calculate geohash for each location's coordinates
# mergedGeohashes = mergedCoordinates.join(mergedLocationsIndexed, on='geoname_id')
# mergedGeohashes['geohash'] = mergedGeohashes.apply(lambda row: geohash2.encode(row['latitude'],row['longitude'],precision=6),axis=1)
#
# # store the result in a CSV file
# columns = ['geohash','latitude','longitude','geoname_id','country_iso_code','country_name','subdivision_1_iso_code','subdivision_1_name','subdivision_2_iso_code','subdivision_2_name','city_name']
# mergedGeohashes.to_csv('merged/GeoLite2-City-Geohashes-en.csv', index=False, float_format='%.9g', columns=columns)
#
# print('... done')

# %% [markdown]
# -----
# Run the next cell to pack the merged CSV files in the 'merged' directory into a ZIP file for export to systems running IBM Streams applications with the IPAddressLocation operator:

# %%
print('running ...')

# pack all result files into a ZIP package
with zipfile.ZipFile(mergedPackageFilename, 'w', compression=zipfile.ZIP_DEFLATED) as zipFile:
    for file in os.listdir('merged'):
        zipFile.write('merged/'+file, file)

print('... done')
# Out:
# running ...
# ... done

# %% [markdown]
# -----
# Run the next cell to upload the ZIP package containing the merged CSV files from DSX to IBM Cloud Object Storage:

# %%
# %%script false
#
# # credentials for bucket in IBM Cloud Object Store
# credentials = {
#     'IBM_API_KEY_ID': 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx',
#     'IAM_SERVICE_ID': 'iam-ServiceId-xxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxxxxxx',
#     'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
#     'IBM_AUTH_ENDPOINT': 'https://iam.ng.bluemix.net/oidc/token',
#     'BUCKET': 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx',
#     'FILE': 'report_IGA_Global_Q1_2016.xlsx'
# }
#
# # create a Cloud Object Store HTTP client with the bucket's credentials
# cosClient = ibm_boto3.client(service_name='s3',
#     ibm_api_key_id=credentials['IBM_API_KEY_ID'],
#     ibm_service_instance_id=credentials['IAM_SERVICE_ID'],
#     ibm_auth_endpoint=credentials['IBM_AUTH_ENDPOINT'],
#     config=Config(signature_version='oauth'),
#     endpoint_url=credentials['ENDPOINT'])
#
# # write the ZIP file to the notebook's bucket in Cloud Object Storage
# cosClient.upload_file(Filename=mergedPackageFilename, Bucket=credentials['BUCKET'], Key=mergedPackageFilename)

# %% [markdown]
# -----
# To download the ZIP package containing the merged CSV files from DSX to your laptop, do this:
#
# * In a browser, go to this notebook's project page
#
# * open the 'Files' panel by clicking the 'Find and Add Data' icon in the upper-right corner of the project page,
#
# * check the box next to 'mergedIBMandMaxmindData.zip'
#
# * select 'Download' from the pop-up menu in the 'Files' panel

# %% [markdown]
# \/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/
